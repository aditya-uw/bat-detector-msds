# %% [markdown]
# # Methods Notebook: Extracting Call Samples for KMeans Clustering

# %% [markdown]
# ## Imports Section:

# %%
import numpy as np
import pandas as pd
import random
import scipy
from scipy import stats
import datetime as dt
import dask.dataframe as dd

# %%
import librosa
import warnings

# %%
import glob
import matplotlib.pyplot as plt
from matplotlib import colors
import soundfile as sf
import matplotlib.patches as patches
from pathlib import Path

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
import sys

# append the path of the
# parent directory
sys.path.append('..')
sys.path.append('../src/')
sys.path.append('../src/models/bat_call_detector/batdetect2/')

import src.batdt2_pipeline as batdetect2_pipeline
import src.file_dealer as file_dealer
from bat_detect.detector import models
from cfg import get_config
from pipeline import pipeline
from utils.utils import gen_empty_df, convert_df_ravenpro
from bat_detect.utils import wavfile
import bat_detect.utils.detector_utils as du
import bat_detect.detector.compute_features as feats
import bat_detect.detector.post_process as pp

# %% [markdown]
# ## Function Definitions (most important functions are in `src/`)
# ### Below are the functions used for plotting and visualization

# %%
def plot_audio_seg(audio_features, spec_features):
    audio_seg = audio_features['audio_seg']
    fs = audio_features['sample_rate']
    start = audio_features['start']
    duration = audio_features['duration']

    vmax = spec_features['vmax']
    vmin = spec_features['vmin']
    cmap = spec_features['cmap']
    nfft = spec_features['NFFT']

    plt.figure(figsize=(15, 5))
    plt.rcParams.update({'font.size': 24})
    plt.title(spec_features['plot_title'], fontsize=24)
    plt.specgram(audio_seg, NFFT=nfft, cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks(ticks=np.linspace(0, 1, 6), labels=np.linspace(0, fs/2000, 6).astype('int'))
    plot_xtype = 'float'
    if (duration > 60):
        plot_xtype = 'int'
    plt.xticks(ticks=np.linspace(0, duration*(fs/2), 11), 
               labels=np.round(np.linspace(start, start+duration, 11, dtype=plot_xtype), 2), rotation=30)
    plt.ylabel("Frequency (kHz)")
    plt.xlabel("Time (s)")
    plt.show()


def plot_dets_over_audio(audio_features, spec_features, plot_dets):
    audio_seg = audio_features['audio_seg']
    fs = audio_features['sample_rate']
    start = audio_features['start']
    duration = audio_features['duration']

    vmax = spec_features['vmax']
    vmin = spec_features['vmin']
    cmap = spec_features['cmap']
    nfft = spec_features['NFFT']

    plt.figure(figsize=(10, 5))
    plt.rcParams.update({'font.size': 24})
    plt.title(spec_features['plot_title'], fontsize=24)
    plt.specgram(audio_seg, NFFT=nfft, cmap=cmap, vmin=vmin, vmax=vmax)

    ax = plt.gca()
    for i, row in plot_dets.iterrows():
        rect = patches.Rectangle(((row['start_time'] - start)*(fs/2), row['low_freq']/(fs/2)), 
                        (row['end_time'] - row['start_time'])*(fs/2), (row['high_freq'] - row['low_freq'])/(fs/2), 
                        linewidth=1.5, edgecolor='yellow', facecolor='none', alpha=0.8)
        ax.add_patch(rect)

    plt.yticks(ticks=np.linspace(0, 1, 6), labels=np.linspace(0, fs/2000, 6).astype('int'))
    plt.ylabel("Frequency (kHz)")
    plot_xtype = 'float'
    if (duration > 60):
        plot_xtype = 'int'
    plt.xticks(ticks=np.linspace(0, duration*(fs/2), 6), 
               labels=np.linspace(0, duration, 6, dtype=plot_xtype), rotation=0)
    plt.xlabel("Time (s)")
    plt.twinx(ax=ax)
    plt.yticks(ticks=np.linspace(0, 1, 6), labels=np.linspace(0, fs/2000, 6).astype('int'))
    plt.ylabel("Frequency (kHz)")

    plt.show()

# %%
def convert_nabatdf_to_ravenprodf(df):
    raven_df = pd.DataFrame()
    raven_df['Begin Time (s)'] =  (df['peak_time_ms']-50)/1000
    raven_df['End Time (s)'] = (df['peak_time_ms']-40)/1000
    raven_df['Low Freq (Hz)'] = df['peak_freq_hz']-2000
    raven_df['High Freq (Hz)'] = df['peak_freq_hz']+2000
    raven_df['prediction'] = df['prediction']
    raven_df['score'] = df['score']
    raven_df.sort_values('Begin Time (s)', inplace=True)
    raven_df.insert(0, 'Selection', np.arange(len(raven_df)).astype(int)+1)

    raventxt_df = pd.DataFrame(np.repeat(raven_df.values, 2, axis=0))
    raventxt_df.columns = raven_df.columns
    raventxt_df['Selection'] = raventxt_df['Selection'].astype(int)
    raventxt_df.insert(1, 'Channel', [1]*raventxt_df.shape[0])
    views = np.array(['Waveform 1']*raventxt_df.shape[0], dtype='object')
    views[1::2] = 'Spectrogram 1'
    raventxt_df.insert(1, 'View', views)

    return raventxt_df

def convert_nabatdf_to_bd2df(df):
    bd2_df = pd.DataFrame()
    bd2_df['start_time'] = (df['peak_time_ms']-50)/1000
    bd2_df['end_time'] = (df['peak_time_ms']-40)/1000
    bd2_df['low_freq'] = df['peak_freq_hz']-2000
    bd2_df['high_freq'] = df['peak_freq_hz']+2000
    bd2_df['prediction'] = df['prediction']
    bd2_df['score'] = df['score']
    bd2_df.sort_values('start_time', inplace=True)
    
    return bd2_df

def convert_kaleidoscopedf_to_ravenprodf(df):
    raven_df = pd.DataFrame()
    raven_df['Begin Time (s)'] = df['OFFSET']
    raven_df['End Time (s)'] = df['OFFSET'] + df['DURATION']
    raven_df['Low Freq (Hz)'] = df['Fmin']
    raven_df['High Freq (Hz)'] = df['Fmax']
    raven_df['input_file'] = df['IN FILE']
    raven_df['input_dir'] = df['INDIR']
    raven_df['mean_freq'] = df['Fmean']
    if 'TOP1MATCH*' in df.columns:
        raven_df['TOP1MATCH*'] = df['TOP1MATCH*']
    if 'TOP1MATCH' in df.columns:
        raven_df['TOP1MATCH'] = df['TOP1MATCH']
    raven_df['TOP1DIST'] = df['TOP1DIST']
    raven_df['TOP2MATCH'] = df['TOP2MATCH']
    raven_df['TOP2DIST'] = df['TOP2DIST']
    raven_df['TOP3MATCH'] = df['TOP3MATCH']
    raven_df['TOP3DIST'] = df['TOP3DIST']
    raven_df.sort_values('Begin Time (s)', inplace=True)
    raven_df.insert(0, 'Selection', np.arange(len(raven_df)).astype(int)+1)

    raventxt_df = pd.DataFrame(np.repeat(raven_df.values, 2, axis=0))
    raventxt_df.columns = raven_df.columns
    raventxt_df['Selection'] = raventxt_df['Selection'].astype(int)
    raventxt_df.insert(1, 'Channel', [1]*raventxt_df.shape[0])
    views = np.array(['Waveform 1']*raventxt_df.shape[0], dtype='object')
    views[1::2] = 'Spectrogram 1'
    raventxt_df.insert(1, 'View', views)

    return raventxt_df

def convert_kaleidoscopedf_to_bd2df(df):
    bd2_df = pd.DataFrame()
    bd2_df['start_time'] = df['OFFSET']
    bd2_df['end_time'] = df['OFFSET'] + df['DURATION']
    bd2_df['low_freq'] = df['Fmin']
    bd2_df['high_freq'] = df['Fmax']
    bd2_df['input_file'] = df['IN FILE']
    bd2_df['input_dir'] = df['INDIR']
    bd2_df['mean_freq'] = df['Fmean']
    if 'TOP1MATCH*' in df.columns:
        bd2_df['TOP1MATCH*'] = df['TOP1MATCH*']
    if 'TOP1MATCH' in df.columns:
        bd2_df['TOP1MATCH'] = df['TOP1MATCH']
    bd2_df['TOP1DIST'] = df['TOP1DIST']
    bd2_df['TOP2MATCH'] = df['TOP2MATCH']
    bd2_df['TOP2DIST'] = df['TOP2DIST']
    bd2_df['TOP3MATCH'] = df['TOP3MATCH']
    bd2_df['TOP3DIST'] = df['TOP3DIST']
    bd2_df.sort_values('start_time', inplace=True)
    
    return bd2_df

def convert_raventxtdf_to_bd2df(raventxt_df):
    bd2_human_df = raventxt_df[::2].copy()
    bd2_human_df = bd2_human_df.drop(columns=['Selection', 'View', 'Channel'])
    bd2_human_df.rename(columns={'Begin Time (s)':'start_time',
                                'End Time (s)':'end_time',
                                'Low Freq (Hz)':'low_freq',
                                'High Freq (Hz)':'high_freq'}, inplace=True)
    bd2_human_df.sort_values('start_time', inplace=True)
    
    return bd2_human_df

# %%
wav_filename = '20220826_070000'
site = 'Central'
plot_file = Path(f'../../Documents/{wav_filename}/input/{wav_filename}.WAV')

# %%
kaleido_df = pd.read_csv(f'../../Documents/{wav_filename}/output/cluster.csv')
bd2_kaleido_df = convert_kaleidoscopedf_to_bd2df(kaleido_df)
bd2_kaleido_df
# Out:
#       start_time     end_time   low_freq  high_freq           input_file  \
# 0       4.851936     4.854150  49390.242  57189.543  20220826_070000.WAV
# 1       5.005365     5.006396  45977.012  47619.047  20220826_070000.WAV
# 2       5.785726     5.786784  47905.906  51615.051  20220826_070000.WAV
# 3      38.635807    38.641656  25236.844  27118.957  20220826_070000.WAV
# 4      39.376575    39.379396  25157.232  26144.906  20220826_070000.WAV
# ..           ...          ...        ...        ...                  ...
# 555  1776.757446  1776.759058  41026.719  45199.184  20220826_070000.WAV
# 556  1776.854004  1776.855824  40004.000  44200.242  20220826_070000.WAV
# 557  1777.039062  1777.042574  39230.770  44200.242  20220826_070000.WAV
# 558  1777.271484  1777.272512  42109.930  44444.445  20220826_070000.WAV
# 559  1777.462769  1777.464887  40618.555  48486.629  20220826_070000.WAV
#
#                                              input_dir  mean_freq TOP1MATCH*  \
# 0    /Users/adityakrishna/Documents/20220826_070000...  52390.625  nocluster
# 1    /Users/adityakrishna/Documents/20220826_070000...  46551.992  nocluster
# 2    /Users/adityakrishna/Documents/20220826_070000...  49152.609  nocluster
# 3    /Users/adityakrishna/Documents/20220826_070000...  25987.514  nocluster
# 4    /Users/adityakrishna/Documents/20220826_070000...  25527.117  nocluster
# ..                                                 ...        ...        ...
# 555  /Users/adityakrishna/Documents/20220826_070000...  42182.492  nocluster
# 556  /Users/adityakrishna/Documents/20220826_070000...  41756.090  nocluster
# 557  /Users/adityakrishna/Documents/20220826_070000...  40997.746  nocluster
# 558  /Users/adityakrishna/Documents/20220826_070000...  42786.316  nocluster
# 559  /Users/adityakrishna/Documents/20220826_070000...  43445.566  nocluster
#
#      TOP1DIST  TOP2MATCH  TOP2DIST  TOP3MATCH  TOP3DIST
# 0           0        NaN         0        NaN         0
# 1           0        NaN         0        NaN         0
# 2           0        NaN         0        NaN         0
# 3           0        NaN         0        NaN         0
# 4           0        NaN         0        NaN         0
# ..        ...        ...       ...        ...       ...
# 555         0        NaN         0        NaN         0
# 556         0        NaN         0        NaN         0
# 557         0        NaN         0        NaN         0
# 558         0        NaN         0        NaN         0
# 559         0        NaN         0        NaN         0
#
# [560 rows x 13 columns]

# %%
raventxt_human_df = pd.read_csv(f'{Path.home()}/Documents/mila-human-wav-txt/{wav_filename}_manually_verified_by_AK.txt', sep='\t')
bd2_human_df = convert_raventxtdf_to_bd2df(raventxt_human_df)
bd2_human_df.reset_index(inplace=True, drop=True)
bd2_human_df
# Out:
#        start_time     end_time   low_freq  high_freq  Delta Time (s)  \
# 0        3.770500     3.777100  45234.000  54096.000          0.0066
# 1        3.911402     3.918947  43903.720  56927.790          0.0075
# 2        4.161126     4.170934  43903.720  56507.659          0.0098
# 3        4.308500     4.314000  46093.000  59238.000          0.0055
# 4        4.440252     4.452032  42018.237  53398.176          0.0118
# ...           ...          ...        ...        ...             ...
# 4121  1787.774500  1787.784900  37500.000  46675.000          0.0104
# 4122  1787.959500  1787.969400  37500.000  45913.000          0.0099
# 4123  1788.212500  1788.221200  39218.000  48186.000          0.0087
# 4124  1788.413500  1788.422500  40078.000  49982.000          0.0090
# 4125  1788.495500  1788.503400  38359.000  47881.000          0.0079
#
#            Annotation  detection_confidence           input_file
# 0        Echolocation                 0.512  20220826_070000.WAV
# 1     AK_echolocation                   NaN                  NaN
# 2     AK_echolocation                   NaN                  NaN
# 3        Echolocation                 0.542  20220826_070000.WAV
# 4                   e                   NaN                  NaN
# ...               ...                   ...                  ...
# 4121     Echolocation                 0.587  20220826_070000.WAV
# 4122     Echolocation                 0.591  20220826_070000.WAV
# 4123     Echolocation                 0.544  20220826_070000.WAV
# 4124     Echolocation                 0.566  20220826_070000.WAV
# 4125     Echolocation                 0.560  20220826_070000.WAV
#
# [4126 rows x 8 columns]

# %%
def return_confusion_matrix_from_comparing_two_detectors(human_df, machine_df):
    false_positives = 0 ## machine made detection that human did not make
    true_positives = 0  ## machine made detection that human made
    true_negatives = 0  ## machine did not make detection that human also did not make
    false_negatives = 0 ## machine did not make detection that human made
    human_ind = 0
    machine_ind = 0

    while (human_ind < len(human_df))&(machine_ind < len(machine_df)):
        human_det = human_df.iloc[human_ind]
        machine_det = machine_df.iloc[machine_ind]

        machine_det_start_in_human_det_bounds = ((machine_det['start_time']>=human_det['start_time'])&(machine_det['start_time']<=human_det['end_time']))
        machine_det_end_in_human_det_bounds = ((machine_det['end_time']>=human_det['start_time'])&(machine_det['end_time']<=human_det['end_time']))
        human_det_start_in_machine_det_bounds = ((human_det['start_time']>=machine_det['start_time'])&(human_det['start_time']<=machine_det['end_time']))
        human_det_end_in_machine_det_bounds = ((human_det['end_time']>=machine_det['start_time'])&(human_det['end_time']<=machine_det['end_time']))
        machine_det_time_in_human_bounds = machine_det_start_in_human_det_bounds|machine_det_end_in_human_det_bounds
        human_det_time_in_machine_bounds = human_det_start_in_machine_det_bounds|human_det_end_in_machine_det_bounds

        machine_det_low_in_human_det_bounds = ((machine_det['low_freq']>=human_det['low_freq'])&(machine_det['low_freq']<=human_det['high_freq']))
        machine_det_high_in_human_det_bounds = ((machine_det['high_freq']>=human_det['low_freq'])&(machine_det['high_freq']<=human_det['high_freq']))
        human_det_low_in_machine_det_bounds = ((human_det['low_freq']>=machine_det['low_freq'])&(human_det['low_freq']<=machine_det['high_freq']))
        human_det_high_in_machine_det_bounds = ((human_det['high_freq']>=machine_det['low_freq'])&(human_det['high_freq']<=machine_det['high_freq']))
        machine_det_freq_in_human_bounds = machine_det_low_in_human_det_bounds|machine_det_high_in_human_det_bounds
        human_det_freq_in_machine_bounds = human_det_low_in_machine_det_bounds|human_det_high_in_machine_det_bounds

        machine_det_time_matches_human_time = (machine_det_time_in_human_bounds|human_det_time_in_machine_bounds)
        machine_det_freq_matches_human_time = (machine_det_freq_in_human_bounds|human_det_freq_in_machine_bounds)
        machine_detection_corresponds_to_human = machine_det_time_matches_human_time&machine_det_freq_matches_human_time

        if len(human_df) < 100:
            print(f'HI:{human_ind}, MI:{machine_ind}, TP:{true_positives}, FP:{false_positives}, FN:{false_negatives}, TN:{true_negatives}')
            print(f'Dets match time: {machine_det_time_matches_human_time}, Dets match freq: {machine_det_freq_matches_human_time}')

        if (machine_detection_corresponds_to_human):
            true_positives += 1
            machine_ind+=1
            human_ind+=1
        else:
            ## Machine detection is referring to call not detected by human (thus, it detected a non-bat call)
            false_positive_same_group_before_human_det = (machine_det['end_time']<=human_det['start_time'])&(machine_det_freq_matches_human_time)
            false_positive_diff_group_before_human_det = (machine_det['start_time']<=human_det['start_time'])&(~machine_det_freq_matches_human_time)

            false_negative_same_group_before_human_det = (machine_det['start_time']>human_det['end_time'])&(machine_det_freq_matches_human_time)
            false_negative_diff_group_before_human_det = (machine_det['start_time']>human_det['start_time'])&(~machine_det_freq_matches_human_time)

            if len(human_df) < 100:
                print(f'FP same group: {false_positive_same_group_before_human_det}, FP diff group: {false_positive_diff_group_before_human_det}')
                print(f'FN same group: {false_negative_same_group_before_human_det}, FN diff group: {false_negative_diff_group_before_human_det}')
            if (false_positive_same_group_before_human_det|false_positive_diff_group_before_human_det):
                false_positives += 1
                machine_ind+=1
            ## Machine has skipped a human-annotated call in detection (thus, it did not detect a bat call)
            elif (false_negative_same_group_before_human_det|false_negative_diff_group_before_human_det):
                false_negatives += 1
                human_ind+=1
            else:
                true_negatives += 1

    if (machine_ind<len(machine_df)):
        false_positives += (len(machine_df) - (machine_ind))
    if (human_ind<len(human_df)):
        false_negatives += (len(human_df) - (human_ind))

    assert((true_positives+false_negatives)==len(human_df))
    assert((false_positives+true_positives)==len(machine_df))

    return {'true_positives':true_positives, 'false_positives':false_positives, 'false_negatives':false_negatives, 'true_negatives':true_negatives}

# %% [markdown]
# ## Following the confusion matrix structure shown below

# %% [markdown]
# ![image](example_confusion_matrix.png)

# %%
return_confusion_matrix_from_comparing_two_detectors(bd2_human_df, bd2_kaleido_df)
# Out:
# {'true_positives': 545,
#  'false_positives': 15,
#  'false_negatives': 3581,
#  'true_negatives': 0}

# %%
# Below we filter our detections dataframe to only get the detections corresponding to the above audio file
audio_file = sf.SoundFile(plot_file)
fs = audio_file.samplerate
start = 360
duration = 15
audio_file.seek(int(fs*start))
audio_seg = audio_file.read(int(fs*duration))
vmin = -60
vmax = 0
audio_features = dict()
audio_features['file_path'] = Path(plot_file)
audio_features['audio_seg'] = audio_seg
audio_features['sample_rate'] = fs
audio_features['start'] = start
audio_features['duration'] = duration

spec_features = dict()
spec_features['NFFT'] = 1024 # When segments are short, NFFT should also be small to best see calls (must always be > 128)
spec_features['cmap'] = 'jet' # This colormap shows best contrast between noise and signals
spec_features['vmin'] = vmin
spec_features['vmax'] = vmax


spec_features['plot_title'] = f"{audio_features['file_path'].name} in {site}"
plot_dets_over_audio(audio_features, spec_features, pd.DataFrame())
spec_features['plot_title'] = f"Human-made detections"
plot_dets_over_audio(audio_features, spec_features, bd2_human_df)

thresh = 0.18
args = dict()
args['chunk_size'] = 2
args['detection_threshold'] = round(thresh, 2)

ones = int(args['detection_threshold'])
decimals = int(int(100*(args['detection_threshold'])) % 100)
threshold_tag = f"threshold{ones}p{decimals:02}"
save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{plot_file.name.split('.')[0]}.csv")

save_dir = Path(f'{Path.home()}/Documents/bd2__det_thresh_sweep_{wav_filename}')
filepath = save_dir / save_loc
batdetect2_df = pd.read_csv(filepath, sep=',', index_col=0)
spec_features['plot_title'] = f"Batdetect2 detections"
plot_dets_over_audio(audio_features, spec_features, batdetect2_df)

# %%
save_dir = Path(f'{Path.home()}/Documents/bd2__det_thresh_sweep_{wav_filename}')
batdetect2_cf_matrices = dict()

increment = 0.01
thresholds = np.arange(0.05, 0.57+increment, increment)
for i, thresh in enumerate(thresholds):
    args = dict()
    args['chunk_size'] = 2
    args['detection_threshold'] = round(thresh, 2)

    ones = int(args['detection_threshold'])
    decimals = int(int(100*(args['detection_threshold'])) % 100)
    threshold_tag = f"threshold{ones}p{decimals:02}"
    save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{plot_file.name.split('.')[0]}.csv")

    filepath = save_dir / save_loc
    batdetect2_df = pd.read_csv(filepath, sep=',', index_col=0)
    print(f'Batdetect2 confusion matrix {threshold_tag}')
    file_batdetect2_cf = return_confusion_matrix_from_comparing_two_detectors(bd2_human_df, batdetect2_df)
    print(file_batdetect2_cf)
    batdetect2_cf_matrices[save_loc] = file_batdetect2_cf
# Out:
# Batdetect2 confusion matrix threshold0p05
# {'true_positives': 4024, 'false_positives': 4514, 'false_negatives': 102, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p06
# {'true_positives': 4004, 'false_positives': 2909, 'false_negatives': 122, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p07
# {'true_positives': 3988, 'false_positives': 2139, 'false_negatives': 138, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p08
# {'true_positives': 3955, 'false_positives': 1658, 'false_negatives': 171, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p09
# {'true_positives': 3930, 'false_positives': 1348, 'false_negatives': 196, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p10
# {'true_positives': 3907, 'false_positives': 1128, 'false_negatives': 219, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p11
# {'true_positives': 3888, 'false_positives': 975, 'false_negatives': 238, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p12
# {'true_positives': 3860, 'false_positives': 849, 'false_negatives': 266, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p13
# {'true_positives': 3837, 'false_positives': 749, 'false_negatives': 289, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p14
# {'true_positives': 3802, 'false_positives': 681, 'false_negatives': 324, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p15
# {'true_positives': 3771, 'false_positives': 631, 'false_negatives': 355, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p16
# {'true_positives': 3749, 'false_positives': 572, 'false_negatives': 377, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p17
# {'true_positives': 3709, 'false_positives': 519, 'false_negatives': 417, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p18
# {'true_positives': 3683, 'false_positives': 470, 'false_negatives': 443, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p19
# {'true_positives': 3653, 'false_positives': 437, 'false_negatives': 473, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p20
# {'true_positives': 3611, 'false_positives': 399, 'false_negatives': 515, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p21
# {'true_positives': 3567, 'false_positives': 369, 'false_negatives': 559, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p22
# {'true_positives': 3512, 'false_positives': 339, 'false_negatives': 614, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p23
# {'true_positives': 3457, 'false_positives': 309, 'false_negatives': 669, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p24
# {'true_positives': 3418, 'false_positives': 289, 'false_negatives': 708, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p25
# {'true_positives': 3366, 'false_positives': 268, 'false_negatives': 760, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p26
# {'true_positives': 3325, 'false_positives': 254, 'false_negatives': 801, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p27
# {'true_positives': 3277, 'false_positives': 242, 'false_negatives': 849, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 3155, 'false_positives': 206, 'false_negatives': 971, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 3155, 'false_positives': 206, 'false_negatives': 971, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p30
# {'true_positives': 3105, 'false_positives': 183, 'false_negatives': 1021, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p31
# {'true_positives': 3049, 'false_positives': 174, 'false_negatives': 1077, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p32
# {'true_positives': 2985, 'false_positives': 158, 'false_negatives': 1141, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p33
# {'true_positives': 2922, 'false_positives': 137, 'false_negatives': 1204, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p34
# {'true_positives': 2853, 'false_positives': 120, 'false_negatives': 1273, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p35
# {'true_positives': 2775, 'false_positives': 106, 'false_negatives': 1351, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p36
# {'true_positives': 2703, 'false_positives': 94, 'false_negatives': 1423, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p37
# {'true_positives': 2639, 'false_positives': 87, 'false_negatives': 1487, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p38
# {'true_positives': 2575, 'false_positives': 75, 'false_negatives': 1551, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p39
# {'true_positives': 2505, 'false_positives': 62, 'false_negatives': 1621, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p40
# {'true_positives': 2421, 'false_positives': 53, 'false_negatives': 1705, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p41
# {'true_positives': 2347, 'false_positives': 50, 'false_negatives': 1779, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p42
# {'true_positives': 2264, 'false_positives': 37, 'false_negatives': 1862, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p43
# {'true_positives': 2191, 'false_positives': 24, 'false_negatives': 1935, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p44
# {'true_positives': 2124, 'false_positives': 15, 'false_negatives': 2002, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p45
# {'true_positives': 2037, 'false_positives': 13, 'false_negatives': 2089, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p46
# {'true_positives': 1951, 'false_positives': 12, 'false_negatives': 2175, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p47
# {'true_positives': 1871, 'false_positives': 10, 'false_negatives': 2255, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p48
# {'true_positives': 1764, 'false_positives': 7, 'false_negatives': 2362, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p49
# {'true_positives': 1692, 'false_positives': 4, 'false_negatives': 2434, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p50
# {'true_positives': 1597, 'false_positives': 0, 'false_negatives': 2529, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p51
# {'true_positives': 1501, 'false_positives': 0, 'false_negatives': 2625, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p52
# {'true_positives': 1389, 'false_positives': 0, 'false_negatives': 2737, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p53
# {'true_positives': 1277, 'false_positives': 0, 'false_negatives': 2849, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p54
# {'true_positives': 1158, 'false_positives': 0, 'false_negatives': 2968, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p55
# {'true_positives': 1047, 'false_positives': 0, 'false_negatives': 3079, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 963, 'false_positives': 0, 'false_negatives': 3163, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 963, 'false_positives': 0, 'false_negatives': 3163, 'true_negatives': 0}

# %%
precisions_per_thresh = np.zeros(len(thresholds))
recalls_per_thresh = np.zeros(len(thresholds))
for i, thresh in enumerate(thresholds):
    args = dict()
    args['chunk_size'] = 2
    args['detection_threshold'] = round(thresh, 2)

    ones = int(args['detection_threshold'])
    decimals = int(int(100*(args['detection_threshold'])) % 100)
    threshold_tag = f"threshold{ones}p{decimals:02}"
    save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{plot_file.name.split('.')[0]}.csv")

    file_batdetect2_cf = batdetect2_cf_matrices[save_loc]
    precision = file_batdetect2_cf['true_positives'] / (file_batdetect2_cf['true_positives'] + file_batdetect2_cf['false_positives'])
    recall = file_batdetect2_cf['true_positives'] / (file_batdetect2_cf['true_positives'] + file_batdetect2_cf['false_negatives'])

    precisions_per_thresh[i] = precision
    recalls_per_thresh[i] = recall

# %%
plt.figure(figsize=(6,6))
plt.rcParams.update({'font.size':14})
plt.plot(recalls_per_thresh, precisions_per_thresh)
common_max = (precisions_per_thresh * recalls_per_thresh).argmax()
plt.scatter(recalls_per_thresh[common_max], precisions_per_thresh[common_max], color='r', label=f'Threshold={round(thresholds[common_max], 3)}', zorder=2)
spec_thresh = 0.5
plt.scatter(recalls_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], precisions_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], 
            facecolor='orange', edgecolor='k', label=f'Threshold={round(spec_thresh,2)}', zorder=2)

spec_thresh = 0.05
plt.scatter(recalls_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], precisions_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], 
            facecolor='brown', edgecolor='k', label=f'Threshold={round(spec_thresh,2)}', zorder=2)
plt.grid(which='both')
plt.xlim(0,1.05)
plt.ylim(0,1.05)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show()

# %%
file_sites = {'20220730_053000':'Carp',
 '20220826_070000':'Central',
 '20220727_083000':'Foliage',
 '20220829_090000':'Foliage'}

file_keys = list(file_sites.keys())
file_keys
# Out:
# ['20220730_053000', '20220826_070000', '20220727_083000', '20220829_090000']

# %%
kaleido_cf_matrices = {'true_positives':0, 'false_positives':0, 'false_negatives':0, 'true_negatives':0}
batdetect2_cf_matrices = {'true_positives':0, 'false_positives':0, 'false_negatives':0, 'true_negatives':0}

for file_key in file_keys:
    wav_filename = file_key
    site = file_sites[file_key]
    print(wav_filename, site)

    kaleido_df = pd.read_csv(f'{Path.home()}/Documents/{wav_filename}/output/cluster.csv')
    bd2_kaleido_df = convert_kaleidoscopedf_to_bd2df(kaleido_df)

    raventxt_human_df = pd.read_csv(f'{Path.home()}/Documents/mila-human-wav-txt/{wav_filename}_manually_verified_by_AK.txt', sep='\t')
    bd2_human_df = convert_raventxtdf_to_bd2df(raventxt_human_df)
    bd2_human_df.reset_index(inplace=True, drop=True)
    print(len(bd2_human_df))
# Out:
# 20220730_053000 Carp
# 806
# 20220826_070000 Central
# 4126
# 20220727_083000 Foliage
# 173
# 20220829_090000 Foliage
# 160

# %%
SITE_NAMES = {'Carp':'Carp Pond', 'Foliage':'Foliage', 'Central':'Central Pond'}

# %%
for file_key in file_keys:
    wav_filename = file_key
    site = file_sites[file_key]
    plot_file = Path(f'{Path.home()}/Documents/{wav_filename}/input/{wav_filename}.WAV')

    raventxt_human_df = pd.read_csv(f'{Path.home()}/Documents/mila-human-wav-txt/{wav_filename}_manually_verified_by_AK.txt', sep='\t')
    bd2_human_df = convert_raventxtdf_to_bd2df(raventxt_human_df)
    bd2_human_df.reset_index(inplace=True, drop=True)

    save_dir = Path(f'{Path.home()}/Documents/bd2__det_thresh_sweep_{wav_filename}')
    batdetect2_cf_matrices = dict()

    increment = 0.01
    thresholds = np.arange(0.05, 0.57+increment, increment)
    for i, thresh in enumerate(thresholds):
        args = dict()
        args['chunk_size'] = 2
        args['detection_threshold'] = round(thresh, 2)

        ones = int(args['detection_threshold'])
        decimals = int(int(100*(args['detection_threshold'])) % 100)
        threshold_tag = f"threshold{ones}p{decimals:02}"
        save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{plot_file.name.split('.')[0]}.csv")

        filepath = save_dir / save_loc
        batdetect2_df = pd.read_csv(filepath, sep=',', index_col=0)
        print(f'Batdetect2 confusion matrix {threshold_tag}')
        file_batdetect2_cf = return_confusion_matrix_from_comparing_two_detectors(bd2_human_df, batdetect2_df)
        print(file_batdetect2_cf)
        batdetect2_cf_matrices[save_loc] = file_batdetect2_cf
    
    precisions_per_thresh = np.zeros(len(thresholds))
    recalls_per_thresh = np.zeros(len(thresholds))
    for i, thresh in enumerate(thresholds):
        args = dict()
        args['chunk_size'] = 2
        args['detection_threshold'] = round(thresh, 2)

        ones = int(args['detection_threshold'])
        decimals = int(int(100*(args['detection_threshold'])) % 100)
        threshold_tag = f"threshold{ones}p{decimals:02}"
        save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{plot_file.name.split('.')[0]}.csv")

        file_batdetect2_cf = batdetect2_cf_matrices[save_loc]
        precision = file_batdetect2_cf['true_positives'] / (file_batdetect2_cf['true_positives'] + file_batdetect2_cf['false_positives'])
        recall = file_batdetect2_cf['true_positives'] / (file_batdetect2_cf['true_positives'] + file_batdetect2_cf['false_negatives'])

        precisions_per_thresh[i] = precision
        recalls_per_thresh[i] = recall

    plt.figure(figsize=(6,6))
    plt.rcParams.update({'font.size':14})
    plt.title(f'{wav_filename}.WAV from {SITE_NAMES[site]}')
    plt.plot(recalls_per_thresh, precisions_per_thresh)
    common_max = (precisions_per_thresh * recalls_per_thresh).argmax()
    plt.scatter(recalls_per_thresh[common_max], precisions_per_thresh[common_max], color='r', label=f'Threshold={round(thresholds[common_max], 3)}', zorder=2)
    spec_thresh = 0.5
    plt.scatter(recalls_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], precisions_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], 
                facecolor='orange', edgecolor='k', label=f'Threshold={round(spec_thresh,2)}', zorder=2)

    spec_thresh = 0.05
    plt.scatter(recalls_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], precisions_per_thresh[np.where(np.isclose(thresholds, spec_thresh))[0][0]], 
                facecolor='brown', edgecolor='k', label=f'Threshold={round(spec_thresh,2)}', zorder=2)
    plt.grid(which='both')
    plt.xlim(0,1.05)
    plt.ylim(0,1.05)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend(loc='lower left')
    plt.show()
# Out:
# Batdetect2 confusion matrix threshold0p05
# {'true_positives': 770, 'false_positives': 1596, 'false_negatives': 36, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p06
# {'true_positives': 767, 'false_positives': 833, 'false_negatives': 39, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p07
# {'true_positives': 765, 'false_positives': 519, 'false_negatives': 41, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p08
# {'true_positives': 766, 'false_positives': 344, 'false_negatives': 40, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p09
# {'true_positives': 764, 'false_positives': 250, 'false_negatives': 42, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p10
# {'true_positives': 756, 'false_positives': 194, 'false_negatives': 50, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p11
# {'true_positives': 754, 'false_positives': 165, 'false_negatives': 52, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p12
# {'true_positives': 752, 'false_positives': 127, 'false_negatives': 54, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p13
# {'true_positives': 749, 'false_positives': 111, 'false_negatives': 57, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p14
# {'true_positives': 745, 'false_positives': 94, 'false_negatives': 61, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p15
# {'true_positives': 741, 'false_positives': 84, 'false_negatives': 65, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p16
# {'true_positives': 739, 'false_positives': 73, 'false_negatives': 67, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p17
# {'true_positives': 730, 'false_positives': 66, 'false_negatives': 76, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p18
# {'true_positives': 726, 'false_positives': 58, 'false_negatives': 80, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p19
# {'true_positives': 720, 'false_positives': 48, 'false_negatives': 86, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p20
# {'true_positives': 713, 'false_positives': 42, 'false_negatives': 93, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p21
# {'true_positives': 707, 'false_positives': 37, 'false_negatives': 99, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p22
# {'true_positives': 704, 'false_positives': 31, 'false_negatives': 102, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p23
# {'true_positives': 697, 'false_positives': 26, 'false_negatives': 109, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p24
# {'true_positives': 690, 'false_positives': 24, 'false_negatives': 116, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p25
# {'true_positives': 686, 'false_positives': 23, 'false_negatives': 120, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p26
# {'true_positives': 681, 'false_positives': 22, 'false_negatives': 125, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p27
# {'true_positives': 676, 'false_positives': 20, 'false_negatives': 130, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 670, 'false_positives': 19, 'false_negatives': 136, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 670, 'false_positives': 19, 'false_negatives': 136, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p30
# {'true_positives': 652, 'false_positives': 14, 'false_negatives': 154, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p31
# {'true_positives': 639, 'false_positives': 13, 'false_negatives': 167, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p32
# {'true_positives': 633, 'false_positives': 11, 'false_negatives': 173, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p33
# {'true_positives': 625, 'false_positives': 11, 'false_negatives': 181, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p34
# {'true_positives': 616, 'false_positives': 11, 'false_negatives': 190, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p35
# {'true_positives': 605, 'false_positives': 9, 'false_negatives': 201, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p36
# {'true_positives': 596, 'false_positives': 9, 'false_negatives': 210, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p37
# {'true_positives': 582, 'false_positives': 8, 'false_negatives': 224, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p38
# {'true_positives': 561, 'false_positives': 8, 'false_negatives': 245, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p39
# {'true_positives': 552, 'false_positives': 8, 'false_negatives': 254, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p40
# {'true_positives': 538, 'false_positives': 7, 'false_negatives': 268, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p41
# {'true_positives': 516, 'false_positives': 7, 'false_negatives': 290, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p42
# {'true_positives': 499, 'false_positives': 6, 'false_negatives': 307, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p43
# {'true_positives': 489, 'false_positives': 6, 'false_negatives': 317, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p44
# {'true_positives': 472, 'false_positives': 5, 'false_negatives': 334, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p45
# {'true_positives': 453, 'false_positives': 3, 'false_negatives': 353, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p46
# {'true_positives': 433, 'false_positives': 2, 'false_negatives': 373, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p47
# {'true_positives': 411, 'false_positives': 1, 'false_negatives': 395, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p48
# {'true_positives': 384, 'false_positives': 1, 'false_negatives': 422, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p49
# {'true_positives': 357, 'false_positives': 1, 'false_negatives': 449, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p50
# {'true_positives': 344, 'false_positives': 0, 'false_negatives': 462, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p51
# {'true_positives': 319, 'false_positives': 0, 'false_negatives': 487, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p52
# {'true_positives': 285, 'false_positives': 0, 'false_negatives': 521, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p53
# {'true_positives': 263, 'false_positives': 0, 'false_negatives': 543, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p54
# {'true_positives': 238, 'false_positives': 0, 'false_negatives': 568, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p55
# {'true_positives': 210, 'false_positives': 0, 'false_negatives': 596, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 181, 'false_positives': 0, 'false_negatives': 625, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 181, 'false_positives': 0, 'false_negatives': 625, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p05
# {'true_positives': 4024, 'false_positives': 4514, 'false_negatives': 102, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p06
# {'true_positives': 4004, 'false_positives': 2909, 'false_negatives': 122, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p07
# {'true_positives': 3988, 'false_positives': 2139, 'false_negatives': 138, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p08
# {'true_positives': 3955, 'false_positives': 1658, 'false_negatives': 171, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p09
# {'true_positives': 3930, 'false_positives': 1348, 'false_negatives': 196, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p10
# {'true_positives': 3907, 'false_positives': 1128, 'false_negatives': 219, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p11
# {'true_positives': 3888, 'false_positives': 975, 'false_negatives': 238, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p12
# {'true_positives': 3860, 'false_positives': 849, 'false_negatives': 266, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p13
# {'true_positives': 3837, 'false_positives': 749, 'false_negatives': 289, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p14
# {'true_positives': 3802, 'false_positives': 681, 'false_negatives': 324, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p15
# {'true_positives': 3771, 'false_positives': 631, 'false_negatives': 355, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p16
# {'true_positives': 3749, 'false_positives': 572, 'false_negatives': 377, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p17
# {'true_positives': 3709, 'false_positives': 519, 'false_negatives': 417, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p18
# {'true_positives': 3683, 'false_positives': 470, 'false_negatives': 443, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p19
# {'true_positives': 3653, 'false_positives': 437, 'false_negatives': 473, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p20
# {'true_positives': 3611, 'false_positives': 399, 'false_negatives': 515, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p21
# {'true_positives': 3567, 'false_positives': 369, 'false_negatives': 559, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p22
# {'true_positives': 3512, 'false_positives': 339, 'false_negatives': 614, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p23
# {'true_positives': 3457, 'false_positives': 309, 'false_negatives': 669, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p24
# {'true_positives': 3418, 'false_positives': 289, 'false_negatives': 708, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p25
# {'true_positives': 3366, 'false_positives': 268, 'false_negatives': 760, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p26
# {'true_positives': 3325, 'false_positives': 254, 'false_negatives': 801, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p27
# {'true_positives': 3277, 'false_positives': 242, 'false_negatives': 849, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 3155, 'false_positives': 206, 'false_negatives': 971, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 3155, 'false_positives': 206, 'false_negatives': 971, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p30
# {'true_positives': 3105, 'false_positives': 183, 'false_negatives': 1021, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p31
# {'true_positives': 3049, 'false_positives': 174, 'false_negatives': 1077, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p32
# {'true_positives': 2985, 'false_positives': 158, 'false_negatives': 1141, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p33
# {'true_positives': 2922, 'false_positives': 137, 'false_negatives': 1204, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p34
# {'true_positives': 2853, 'false_positives': 120, 'false_negatives': 1273, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p35
# {'true_positives': 2775, 'false_positives': 106, 'false_negatives': 1351, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p36
# {'true_positives': 2703, 'false_positives': 94, 'false_negatives': 1423, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p37
# {'true_positives': 2639, 'false_positives': 87, 'false_negatives': 1487, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p38
# {'true_positives': 2575, 'false_positives': 75, 'false_negatives': 1551, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p39
# {'true_positives': 2505, 'false_positives': 62, 'false_negatives': 1621, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p40
# {'true_positives': 2421, 'false_positives': 53, 'false_negatives': 1705, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p41
# {'true_positives': 2347, 'false_positives': 50, 'false_negatives': 1779, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p42
# {'true_positives': 2264, 'false_positives': 37, 'false_negatives': 1862, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p43
# {'true_positives': 2191, 'false_positives': 24, 'false_negatives': 1935, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p44
# {'true_positives': 2124, 'false_positives': 15, 'false_negatives': 2002, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p45
# {'true_positives': 2037, 'false_positives': 13, 'false_negatives': 2089, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p46
# {'true_positives': 1951, 'false_positives': 12, 'false_negatives': 2175, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p47
# {'true_positives': 1871, 'false_positives': 10, 'false_negatives': 2255, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p48
# {'true_positives': 1764, 'false_positives': 7, 'false_negatives': 2362, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p49
# {'true_positives': 1692, 'false_positives': 4, 'false_negatives': 2434, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p50
# {'true_positives': 1597, 'false_positives': 0, 'false_negatives': 2529, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p51
# {'true_positives': 1501, 'false_positives': 0, 'false_negatives': 2625, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p52
# {'true_positives': 1389, 'false_positives': 0, 'false_negatives': 2737, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p53
# {'true_positives': 1277, 'false_positives': 0, 'false_negatives': 2849, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p54
# {'true_positives': 1158, 'false_positives': 0, 'false_negatives': 2968, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p55
# {'true_positives': 1047, 'false_positives': 0, 'false_negatives': 3079, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 963, 'false_positives': 0, 'false_negatives': 3163, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 963, 'false_positives': 0, 'false_negatives': 3163, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p05
# {'true_positives': 135, 'false_positives': 5170, 'false_negatives': 38, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p06
# {'true_positives': 131, 'false_positives': 2277, 'false_negatives': 42, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p07
# {'true_positives': 127, 'false_positives': 1236, 'false_negatives': 46, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p08
# {'true_positives': 123, 'false_positives': 759, 'false_negatives': 50, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p09
# {'true_positives': 120, 'false_positives': 522, 'false_negatives': 53, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p10
# {'true_positives': 116, 'false_positives': 359, 'false_negatives': 57, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p11
# {'true_positives': 114, 'false_positives': 259, 'false_negatives': 59, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p12
# {'true_positives': 108, 'false_positives': 199, 'false_negatives': 65, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p13
# {'true_positives': 107, 'false_positives': 162, 'false_negatives': 66, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p14
# {'true_positives': 103, 'false_positives': 136, 'false_negatives': 70, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p15
# {'true_positives': 102, 'false_positives': 119, 'false_negatives': 71, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p16
# {'true_positives': 99, 'false_positives': 90, 'false_negatives': 74, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p17
# {'true_positives': 93, 'false_positives': 79, 'false_negatives': 80, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p18
# {'true_positives': 92, 'false_positives': 64, 'false_negatives': 81, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p19
# {'true_positives': 88, 'false_positives': 53, 'false_negatives': 85, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p20
# {'true_positives': 85, 'false_positives': 46, 'false_negatives': 88, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p21
# {'true_positives': 82, 'false_positives': 39, 'false_negatives': 91, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p22
# {'true_positives': 79, 'false_positives': 34, 'false_negatives': 94, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p23
# {'true_positives': 78, 'false_positives': 29, 'false_negatives': 95, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p24
# {'true_positives': 76, 'false_positives': 23, 'false_negatives': 97, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p25
# {'true_positives': 76, 'false_positives': 18, 'false_negatives': 97, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p26
# {'true_positives': 74, 'false_positives': 16, 'false_negatives': 99, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p27
# {'true_positives': 74, 'false_positives': 12, 'false_negatives': 99, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 73, 'false_positives': 10, 'false_negatives': 100, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 73, 'false_positives': 10, 'false_negatives': 100, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p30
# {'true_positives': 70, 'false_positives': 9, 'false_negatives': 103, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p31
# {'true_positives': 67, 'false_positives': 8, 'false_negatives': 106, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p32
# {'true_positives': 65, 'false_positives': 7, 'false_negatives': 108, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p33
# {'true_positives': 60, 'false_positives': 6, 'false_negatives': 113, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p34
# {'true_positives': 59, 'false_positives': 6, 'false_negatives': 114, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p35
# {'true_positives': 56, 'false_positives': 5, 'false_negatives': 117, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p36
# {'true_positives': 53, 'false_positives': 5, 'false_negatives': 120, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p37
# {'true_positives': 51, 'false_positives': 4, 'false_negatives': 122, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p38
# {'true_positives': 49, 'false_positives': 4, 'false_negatives': 124, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p39
# {'true_positives': 46, 'false_positives': 4, 'false_negatives': 127, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p40
# {'true_positives': 45, 'false_positives': 1, 'false_negatives': 128, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p41
# {'true_positives': 42, 'false_positives': 1, 'false_negatives': 131, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p42
# {'true_positives': 39, 'false_positives': 1, 'false_negatives': 134, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p43
# {'true_positives': 37, 'false_positives': 1, 'false_negatives': 136, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p44
# {'true_positives': 34, 'false_positives': 1, 'false_negatives': 139, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p45
# {'true_positives': 32, 'false_positives': 1, 'false_negatives': 141, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p46
# {'true_positives': 31, 'false_positives': 1, 'false_negatives': 142, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p47
# {'true_positives': 30, 'false_positives': 1, 'false_negatives': 143, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p48
# {'true_positives': 27, 'false_positives': 1, 'false_negatives': 146, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p49
# {'true_positives': 24, 'false_positives': 1, 'false_negatives': 149, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p50
# {'true_positives': 23, 'false_positives': 0, 'false_negatives': 150, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p51
# {'true_positives': 20, 'false_positives': 0, 'false_negatives': 153, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p52
# {'true_positives': 18, 'false_positives': 0, 'false_negatives': 155, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p53
# {'true_positives': 15, 'false_positives': 0, 'false_negatives': 158, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p54
# {'true_positives': 15, 'false_positives': 0, 'false_negatives': 158, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p55
# {'true_positives': 13, 'false_positives': 0, 'false_negatives': 160, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 12, 'false_positives': 0, 'false_negatives': 161, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 12, 'false_positives': 0, 'false_negatives': 161, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p05
# {'true_positives': 148, 'false_positives': 2347, 'false_negatives': 12, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p06
# {'true_positives': 146, 'false_positives': 931, 'false_negatives': 14, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p07
# {'true_positives': 145, 'false_positives': 452, 'false_negatives': 15, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p08
# {'true_positives': 144, 'false_positives': 269, 'false_negatives': 16, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p09
# {'true_positives': 145, 'false_positives': 175, 'false_negatives': 15, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p10
# {'true_positives': 142, 'false_positives': 127, 'false_negatives': 18, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p11
# {'true_positives': 139, 'false_positives': 89, 'false_negatives': 21, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p12
# {'true_positives': 138, 'false_positives': 66, 'false_negatives': 22, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p13
# {'true_positives': 137, 'false_positives': 49, 'false_negatives': 23, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p14
# {'true_positives': 134, 'false_positives': 36, 'false_negatives': 26, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p15
# {'true_positives': 133, 'false_positives': 24, 'false_negatives': 27, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p16
# {'true_positives': 130, 'false_positives': 24, 'false_negatives': 30, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p17
# {'true_positives': 128, 'false_positives': 18, 'false_negatives': 32, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p18
# {'true_positives': 128, 'false_positives': 13, 'false_negatives': 32, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p19
# {'true_positives': 126, 'false_positives': 12, 'false_negatives': 34, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p20
# {'true_positives': 124, 'false_positives': 12, 'false_negatives': 36, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p21
# {'true_positives': 122, 'false_positives': 10, 'false_negatives': 38, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p22
# {'true_positives': 121, 'false_positives': 7, 'false_negatives': 39, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p23
# {'true_positives': 120, 'false_positives': 6, 'false_negatives': 40, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p24
# {'true_positives': 120, 'false_positives': 4, 'false_negatives': 40, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p25
# {'true_positives': 120, 'false_positives': 4, 'false_negatives': 40, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p26
# {'true_positives': 119, 'false_positives': 4, 'false_negatives': 41, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p27
# {'true_positives': 116, 'false_positives': 3, 'false_negatives': 44, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 112, 'false_positives': 3, 'false_negatives': 48, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p28
# {'true_positives': 112, 'false_positives': 3, 'false_negatives': 48, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p30
# {'true_positives': 107, 'false_positives': 3, 'false_negatives': 53, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p31
# {'true_positives': 104, 'false_positives': 2, 'false_negatives': 56, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p32
# {'true_positives': 101, 'false_positives': 2, 'false_negatives': 59, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p33
# {'true_positives': 97, 'false_positives': 2, 'false_negatives': 63, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p34
# {'true_positives': 95, 'false_positives': 2, 'false_negatives': 65, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p35
# {'true_positives': 91, 'false_positives': 1, 'false_negatives': 69, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p36
# {'true_positives': 89, 'false_positives': 1, 'false_negatives': 71, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p37
# {'true_positives': 87, 'false_positives': 1, 'false_negatives': 73, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p38
# {'true_positives': 81, 'false_positives': 1, 'false_negatives': 79, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p39
# {'true_positives': 77, 'false_positives': 1, 'false_negatives': 83, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p40
# {'true_positives': 74, 'false_positives': 0, 'false_negatives': 86, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p41
# {'true_positives': 67, 'false_positives': 0, 'false_negatives': 93, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p42
# {'true_positives': 59, 'false_positives': 0, 'false_negatives': 101, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p43
# {'true_positives': 56, 'false_positives': 0, 'false_negatives': 104, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p44
# {'true_positives': 54, 'false_positives': 0, 'false_negatives': 106, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p45
# {'true_positives': 51, 'false_positives': 0, 'false_negatives': 109, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p46
# {'true_positives': 49, 'false_positives': 0, 'false_negatives': 111, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p47
# {'true_positives': 49, 'false_positives': 0, 'false_negatives': 111, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p48
# {'true_positives': 45, 'false_positives': 0, 'false_negatives': 115, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p49
# {'true_positives': 41, 'false_positives': 0, 'false_negatives': 119, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p50
# {'true_positives': 38, 'false_positives': 0, 'false_negatives': 122, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p51
# {'true_positives': 33, 'false_positives': 0, 'false_negatives': 127, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p52
# {'true_positives': 31, 'false_positives': 0, 'false_negatives': 129, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p53
# {'true_positives': 28, 'false_positives': 0, 'false_negatives': 132, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p54
# {'true_positives': 24, 'false_positives': 0, 'false_negatives': 136, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p55
# {'true_positives': 15, 'false_positives': 0, 'false_negatives': 145, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 11, 'false_positives': 0, 'false_negatives': 149, 'true_negatives': 0}
# Batdetect2 confusion matrix threshold0p56
# {'true_positives': 11, 'false_positives': 0, 'false_negatives': 149, 'true_negatives': 0}
