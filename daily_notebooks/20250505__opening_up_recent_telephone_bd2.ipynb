# %%
import pandas as pd

# %%
dets = pd.read_csv('../../Downloads/bd2__recover-20250502_UBNA_028.csv')

# %%
new_dets = dets[dets['det_prob']>=0.30].copy().reset_index(drop=True)

# %%
new_dets.to_csv('bd2__recover-20250502_UBNA_028.csv', sep=',', index=False)
