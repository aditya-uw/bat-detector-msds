# %%
from pathlib import Path
from torch import multiprocessing
import os
import torch
from tqdm import tqdm
import soundfile as sf

# %%
import numpy as np
import pandas as pd
import time
import io

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import colors
import datetime as dt

# %%
import sys

# append the path of the
# parent directory
sys.path.append('..')
sys.path.append('../src/')
sys.path.append('../src/models/bat_call_detector/batdetect2/')

import src.batdt2_pipeline as batdetect2_pipeline
from pipeline import pipeline
from utils.utils import gen_empty_df
from cfg import get_config
from bat_detect.detector import models
import bat_detect.utils.detector_utils as du
import bat_detect.detector.compute_features as feats
import bat_detect.detector.post_process as pp
import bat_detect.utils.audio_utils as au

# %%
def run_models(file_mappings):
    """
    Runs the batdetect2 model to detect bat search-phase calls in the provided audio segments and saves detections into a .csv.

    Parameters
    ------------
    file_mappings : `List`
        - List of dictionaries generated by initialize_mappings()

    Returns
    ------------
    bd_dets : `pandas.DataFrame`
        - A DataFrame of detections that will also be saved in the provided output_dir under the above csv_name
        - 7 columns in this DataFrame: start_time, end_time, low_freq, high_freq, detection_confidence, event, input_file
        - Detections are always specified w.r.t their input_file; earliest start_time can be 0 and latest end_time can be 1795.
        - Events are always "Echolocation" as we are using a model that only detects search-phase calls.
    """

    bd_dets = pd.DataFrame()
    for i in tqdm(range(len(file_mappings))):
        cur_seg = file_mappings[i]
        bd_annotations_df = cur_seg['model']._run_batdetect(cur_seg['audio_seg']['audio_file'])
        bd_offsetted = pipeline._correct_annotation_offsets(
                bd_annotations_df,
                cur_seg['original_file_name'],
                cur_seg['audio_seg']['offset']
            )
        bd_dets = pd.concat([bd_dets, bd_offsetted])
        
    return bd_dets

def apply_models(file_path_mappings, cfg):
    """
    Runs the batdetect2 model to detect bat search-phase calls in the provided audio segments and saves detections into a dataframe

    Parameters
    ------------
    file_mappings : `List`
        - List of dictionaries generated by initialize_mappings()
    cfg : `dict`
        - A dictionary of pipeline parameters:
        - models is the models in the pipeline that are being used.

    Returns
    ------------
    bd_preds : `pandas.DataFrame`
        - A DataFrame of detections that will also be saved in the provided output_dir under the above csv_name
        - 7 columns in this DataFrame: start_time, end_time, low_freq, high_freq, detection_confidence, event, input_file
        - Detections are always specified w.r.t their input_file; earliest start_time can be 0 and latest end_time can be 1795.
        - Events are always "Echolocation" as we are using a model that only detects search-phase calls.
    """

    process_pool = multiprocessing.Pool(cfg['num_processes'])

    bd_dets = tqdm(
            process_pool.imap(apply_model, file_path_mappings, chunksize=1), 
            desc=f"Applying BatDetect2",
            total=len(file_path_mappings),
        )
    
    bd_preds = gen_empty_df() 
    bd_preds = pd.concat(bd_dets, ignore_index=True)
    
    return bd_preds

def apply_model(file_mapping):
    """
    Runs the batdetect2 model on a single provided audio segmens and corrects the offsets according the segment.

    Parameters
    ------------
    file_mappings : `List`
        - List of dictionaries generated by initialize_mappings()

    Returns
    ------------
    corrected_bd_dets : `pandas.DataFrame`
        - A DataFrame of detections that will also be saved in the provided output_dir under the above csv_name
        - 7 columns in this DataFrame: start_time, end_time, low_freq, high_freq, detection_confidence, event, input_file
        - Detections are always specified w.r.t their input_file; earliest start_time can be 0 and latest end_time can be 1795.
        - Events are always "Echolocation" as we are using a model that only detects search-phase calls.
    """

    bd_dets = file_mapping['model']._run_batdetect(file_mapping['audio_seg']['audio_file'])
    corrected_bd_dets = pipeline._correct_annotation_offsets(
                                                            bd_dets,
                                                            file_mapping['original_file_name'],
                                                            file_mapping['audio_seg']['offset']
                                                            )

    return corrected_bd_dets

# %%
def run_pipeline_on_file(file, cfg):
    bd_preds = pd.DataFrame()

    if not cfg['output_dir'].is_dir():
        cfg['output_dir'].mkdir(parents=True, exist_ok=True)
    if not cfg['tmp_dir'].is_dir():
        cfg['tmp_dir'].mkdir(parents=True, exist_ok=True)

    cfg["csv_filename"] = f"batdetect2_pipeline_{file.name.split('.')[0]}"
    print(f"Generating detections for {file.name}")
    segmented_file_paths = batdetect2_pipeline.generate_segmented_paths([file], cfg)
    file_path_mappings = batdetect2_pipeline.initialize_mappings(segmented_file_paths, cfg)
    bd_preds = run_models(file_path_mappings)
    if cfg['save']:
        batdetect2_pipeline._save_predictions(bd_preds, cfg['output_dir'], cfg)
    batdetect2_pipeline.delete_segments(segmented_file_paths)

    return bd_preds

def apply_pipeline_on_file(file, cfg):
    bd_preds = pd.DataFrame()

    if not cfg['output_dir'].is_dir():
        cfg['output_dir'].mkdir(parents=True, exist_ok=True)
    if not cfg['tmp_dir'].is_dir():
        cfg['tmp_dir'].mkdir(parents=True, exist_ok=True)

    cfg["csv_filename"] = f"batdetect2_pipeline_{file.name.split('.')[0]}"
    print(f"Generating detections for {file.name}")
    segmented_file_paths = batdetect2_pipeline.generate_segmented_paths([file], cfg)
    file_path_mappings = batdetect2_pipeline.initialize_mappings(segmented_file_paths, cfg)
    bd_preds = apply_models(file_path_mappings, cfg)
    if cfg['save']:
        batdetect2_pipeline._save_predictions(bd_preds, cfg['output_dir'], cfg)
    batdetect2_pipeline.delete_segments(segmented_file_paths)

    return bd_preds

# %%
input_file = Path('../../Documents/20220728_080000.WAV')

cfg = get_config()
cfg['segment_duration'] = 30.0
cfg['input_audio'] = input_file
cfg['tmp_dir'] = Path('../output')
cfg['output_dir'] = Path('../output_dir')
cfg['run_model'] = True
cfg['num_processes'] = 4
cfg['should_csv'] = False
cfg['save'] = True

# apply_pipeline_on_file(input_file, cfg)
print(f"Generating detections for {input_file.name}")
segmented_file_paths = batdetect2_pipeline.generate_segmented_paths([input_file], cfg)
file_path_mappings = batdetect2_pipeline.initialize_mappings(segmented_file_paths, cfg)
# Out:
# Generating detections for 20220728_080000.WAV

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if os.path.isfile(file_path_mappings[0]['model'].model_path):
    NET_PARAMS = torch.load(file_path_mappings[0]['model'].model_path, map_location=DEVICE)

# %%
def load_model():
    params = NET_PARAMS['params']
    params['device'] = DEVICE
    if params['model_name'] == 'Net2DFast':
        model = models.Net2DFast(params['num_filters'], num_classes=len(params['class_names']),
                                    emb_dim=params['emb_dim'], ip_height=params['ip_height'],
                                    resize_factor=params['resize_factor'])
    elif params['model_name'] == 'Net2DFastNoAttn':
        model = models.Net2DFastNoAttn(params['num_filters'], num_classes=len(params['class_names']),
                                    emb_dim=params['emb_dim'], ip_height=params['ip_height'],
                                    resize_factor=params['resize_factor'])
    elif params['model_name'] == 'Net2DFastNoCoordConv':
        model = models.Net2DFastNoCoordConv(params['num_filters'], num_classes=len(params['class_names']),
                                    emb_dim=params['emb_dim'], ip_height=params['ip_height'],
                                    resize_factor=params['resize_factor'])
    else:
        print('Error: unknown model.')
    model.load_state_dict(NET_PARAMS['state_dict'])

    model = model.to(params['device'])
    model.eval()

    return model, params

# %%
model, params = load_model()

# %%
params
# Out:
# {'data_dir': '/data1/bat_data/data/',
#  'ann_dir': '/data1/bat_data/annotations/anns_same/',
#  'train_split': 'same',
#  'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#  'model_name': 'Net2DFast',
#  'num_filters': 128,
#  'experiment': '../../experiments/2021_12_13__20_20_37/',
#  'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#  'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#  'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#  'notes': '',
#  'target_samp_rate': 256000,
#  'fft_win_length': 0.002,
#  'fft_overlap': 0.75,
#  'max_freq': 120000,
#  'min_freq': 10000,
#  'resize_factor': 0.5,
#  'spec_height': 256,
#  'spec_train_width': 512,
#  'spec_divide_factor': 32,
#  'denoise_spec_avg': True,
#  'scale_raw_audio': False,
#  'max_scale_spec': False,
#  'spec_scale': 'pcen',
#  'detection_overlap': 0.01,
#  'ignore_start_end': 0.01,
#  'detection_threshold': 0.01,
#  'nms_kernel_size': 9,
#  'nms_top_k_per_sec': 200,
#  'target_sigma': 2.0,
#  'aug_prob': 0.2,
#  'augment_at_train': True,
#  'augment_at_train_combine': True,
#  'echo_max_delay': 0.005,
#  'stretch_squeeze_delta': 0.04,
#  'mask_max_time_perc': 0.05,
#  'mask_max_freq_perc': 0.1,
#  'spec_amp_scaling': 2.0,
#  'aug_sampling_rates': [220500,
#   256000,
#   300000,
#   312500,
#   384000,
#   441000,
#   500000],
#  'train_loss': 'focal',
#  'det_loss_weight': 1.0,
#  'size_loss_weight': 0.1,
#  'class_loss_weight': 2.0,
#  'individual_loss_weight': 0.0,
#  'emb_dim': 0,
#  'lr': 0.001,
#  'batch_size': 8,
#  'num_workers': 4,
#  'num_epochs': 200,
#  'num_eval_epochs': 5,
#  'device': device(type='cpu'),
#  'save_test_image_during_train': False,
#  'save_test_image_after_train': True,
#  'convert_to_genus': False,
#  'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#  'class_names': ['Barbastellus barbastellus',
#   'Eptesicus serotinus',
#   'Myotis alcathoe',
#   'Myotis bechsteinii',
#   'Myotis brandtii',
#   'Myotis daubentonii',
#   'Myotis mystacinus',
#   'Myotis nattereri',
#   'Nyctalus leisleri',
#   'Nyctalus noctula',
#   'Pipistrellus nathusii',
#   'Pipistrellus pipistrellus',
#   'Pipistrellus pygmaeus',
#   'Plecotus auritus',
#   'Plecotus austriacus',
#   'Rhinolophus ferrumequinum',
#   'Rhinolophus hipposideros'],
#  'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#  'generic_class': ['Bat'],
#  'events_of_interest': ['Echolocation'],
#  'standardize_classs_names': ['Rhinolophus ferrumequinum',
#   'Rhinolophus hipposideros'],
#  'train_sets': [{'dataset_name': 'BatDetective',
#    'is_test': False,
#    'is_binary': True,
#    'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#    'wav_path': 'bat_detective/audio/'},
#   {'dataset_name': 'bat_logger_qeop_empty',
#    'is_test': False,
#    'is_binary': True,
#    'ann_path': 'bat_logger_qeop_empty.json',
#    'wav_path': 'bat_logger_qeop_empty/audio/'},
#   {'dataset_name': 'bat_logger_2016_empty',
#    'is_test': False,
#    'is_binary': True,
#    'ann_path': 'train_set_bat_logger_2016_empty.json',
#    'wav_path': 'bat_logger_2016/audio/'},
#   {'dataset_name': 'echobank',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'Echobank_train_expert_TRAIN.json',
#    'wav_path': 'echobank/audio/'},
#   {'dataset_name': 'sn_scot_nor',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#    'wav_path': 'sn_scot_nor/audio/'},
#   {'dataset_name': 'BCT_1_sec',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#    'wav_path': 'BCT_1_sec/audio/'},
#   {'dataset_name': 'bcireland',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'bcireland_expert_TRAIN.json',
#    'wav_path': 'bcireland/audio/'},
#   {'dataset_name': 'rhinolophus_steve_BCT',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#    'wav_path': 'rhinolophus_steve_BCT/audio/'},
#   {'dataset_name': 'bat_data_martyn_2018',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#    'wav_path': 'bat_data_martyn_2018/audio/'},
#   {'dataset_name': 'bat_data_martyn_2018_test',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#    'wav_path': 'bat_data_martyn_2018_test/audio/'},
#   {'dataset_name': 'bat_data_martyn_2019',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#    'wav_path': 'bat_data_martyn_2019/audio/'},
#   {'dataset_name': 'bat_data_martyn_2019_test',
#    'is_test': False,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#    'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#  'test_sets': [{'dataset_name': 'echobank',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'Echobank_train_expert_TEST.json',
#    'wav_path': 'echobank/audio/'},
#   {'dataset_name': 'sn_scot_nor',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#    'wav_path': 'sn_scot_nor/audio/'},
#   {'dataset_name': 'BCT_1_sec',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#    'wav_path': 'BCT_1_sec/audio/'},
#   {'dataset_name': 'bcireland',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'bcireland_expert_TEST.json',
#    'wav_path': 'bcireland/audio/'},
#   {'dataset_name': 'rhinolophus_steve_BCT',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#    'wav_path': 'rhinolophus_steve_BCT/audio/'},
#   {'dataset_name': 'bat_data_martyn_2018',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#    'wav_path': 'bat_data_martyn_2018/audio/'},
#   {'dataset_name': 'bat_data_martyn_2018_test',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#    'wav_path': 'bat_data_martyn_2018_test/audio/'},
#   {'dataset_name': 'bat_data_martyn_2019',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#    'wav_path': 'bat_data_martyn_2019/audio/'},
#   {'dataset_name': 'bat_data_martyn_2019_test',
#    'is_test': True,
#    'is_binary': False,
#    'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#    'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#  'class_inv_freq': [1.9637118577957153,
#   0.7146786451339722,
#   2.441218852996826,
#   2.6182825565338135,
#   0.955857515335083,
#   0.29615065455436707,
#   0.6982086896896362,
#   0.7116808295249939,
#   1.6066733598709106,
#   5.473054885864258,
#   1.386149525642395,
#   1.0264047384262085,
#   0.7815048694610596,
#   1.8502148389816284,
#   2.458908796310425,
#   0.885977566242218,
#   0.8449437618255615],
#  'genus_names': ['Barbastellus',
#   'Eptesicus',
#   'Myotis',
#   'Nyctalus',
#   'Pipistrellus',
#   'Plecotus',
#   'Rhinolophus'],
#  'class_names_short': ['Bar bar',
#   'Ept ser',
#   'Myo alc',
#   'Myo bec',
#   'Myo bra',
#   'Myo dau',
#   'Myo mys',
#   'Myo nat',
#   'Nyc lei',
#   'Nyc noc',
#   'Pip nat',
#   'Pip pip',
#   'Pip pyg',
#   'Ple aur',
#   'Ple aus',
#   'Rhi fer',
#   'Rhi hip'],
#  'ip_height': 128}

# %%
def process_file(audio_file, model, params, args, time_exp=None, top_n=5, return_raw_preds=False, max_duration=False):

    # store temporary results here
    predictions = []
    spec_feats  = []
    cnn_feats   = []
    spec_slices = []

    # get time expansion  factor
    if time_exp is None:
        time_exp = args['time_expansion_factor']

    params['detection_threshold'] = args['detection_threshold']

    # load audio file
    sampling_rate, audio_full = au.load_audio_file(audio_file, time_exp,
                                   params['target_samp_rate'], params['scale_raw_audio'])
    
    duration_full = audio_full.shape[0] / float(sampling_rate)

    return_np_spec = args['spec_features'] or args['spec_slices']

    # loop through larger file and split into chunks
    # TODO fix so that it overlaps correctly and takes care of duplicate detections at borders
    num_chunks = int(np.ceil(duration_full/args['chunk_size']))
    for chunk_id in range(num_chunks):

        # chunk
        chunk_time   = args['chunk_size']*chunk_id
        chunk_length = int(sampling_rate*args['chunk_size'])
        start_sample = chunk_id*chunk_length
        end_sample   = np.minimum((chunk_id+1)*chunk_length, audio_full.shape[0])
        audio = audio_full[start_sample:end_sample]

        # load audio file and compute spectrogram
        duration, spec, spec_np = du.compute_spectrogram(audio, sampling_rate, params, return_np_spec)

        # evaluate model
        with torch.no_grad():
            outputs = model(spec, return_feats=args['cnn_features'])
        
        # run non-max suppression
        pred_nms, features = pp.run_nms(outputs, params, np.array([float(sampling_rate)]))
        pred_nms = pred_nms[0]
        pred_nms['start_times'] += chunk_time
        pred_nms['end_times'] += chunk_time

        # if we have a background class
        if pred_nms['class_probs'].shape[0] > len(params['class_names']):
            pred_nms['class_probs'] = pred_nms['class_probs'][:-1, :]

        predictions.append(pred_nms)

        # extract features - if there are any calls detected
        if (pred_nms['det_probs'].shape[0] > 0):
            if args['spec_features']:
                spec_feats.append(feats.get_feats(spec_np, pred_nms, params))

            if args['cnn_features']:
                cnn_feats.append(features[0])

            if args['spec_slices']:
                spec_slices.extend(feats.extract_spec_slices(spec_np, pred_nms, params))

    # convert the predictions into output dictionary
    file_id = os.path.basename(audio_file)
    predictions, spec_feats, cnn_feats, spec_slices =\
              du.merge_results(predictions, spec_feats, cnn_feats, spec_slices)
    results = du.convert_results(file_id, time_exp, duration_full, params,
                              predictions, spec_feats, cnn_feats, spec_slices)

    # summarize results
    if not args['quiet']:
        num_detections = len(results['pred_dict']['annotation'])
        print('{}'.format(num_detections) + ' call(s) detected above the threshold.')

    # print results for top n classes
    if not args['quiet'] and (num_detections > 0):
        class_overall = pp.overall_class_pred(predictions['det_probs'], predictions['class_probs'])
        print('species name'.ljust(30) + 'probablity present')
        for cc in np.argsort(class_overall)[::-1][:top_n]:
            print(params['class_names'][cc].ljust(30) + str(round(class_overall[cc], 3)))

    if return_raw_preds:
        return predictions
    else:
        return results

# %%
def _run_batdetect(model_obj, audio_file): #
    """
    Parameters:: 
        audio_file: a path containing the post-processed wav file.

    Returns:: a pd.Dataframe containing the bat calls detections
    """

    model, params = load_model()

    # Suppress output from this call
    text_trap = io.StringIO()
    sys.stdout = text_trap

    model_output = process_file(
        audio_file=audio_file,
        model=model,
        params=params,
        args= {
            'detection_threshold': model_obj.detection_threshold,
            'spec_slices': model_obj.spec_slices,
            'chunk_size': model_obj.chunk_size,
            'quiet': model_obj.quiet,
            'spec_features' : False,
            'cnn_features': model_obj.cnn_features,
        },
        time_exp=model_obj.time_expansion_factor,
    )
    annotations = model_output['pred_dict']['annotation']

    # Restore stdout
    sys.stdout = sys.__stdout__

    out_df = gen_empty_df()
    if annotations:
        out_df = pd.DataFrame.from_records(annotations) 
        # out_df['detection_confidence'] = out_df['det_prob']
        # out_df.drop(columns = ['class', 'class_prob', 'det_prob','individual'], inplace=True)
    return out_df


def apply_model(file_mapping):
    """
    Runs the batdetect2 model on a single provided audio segmens and corrects the offsets according the segment.

    Parameters
    ------------
    file_mappings : `List`
        - List of dictionaries generated by initialize_mappings()

    Returns
    ------------
    corrected_bd_dets : `pandas.DataFrame`
        - A DataFrame of detections that will also be saved in the provided output_dir under the above csv_name
        - 7 columns in this DataFrame: start_time, end_time, low_freq, high_freq, detection_confidence, event, input_file
        - Detections are always specified w.r.t their input_file; earliest start_time can be 0 and latest end_time can be 1795.
        - Events are always "Echolocation" as we are using a model that only detects search-phase calls.
    """

    bd_dets = _run_batdetect(file_mapping['model'], file_mapping['audio_seg']['audio_file'])
    corrected_bd_dets = pipeline._correct_annotation_offsets(
                                                            bd_dets,
                                                            file_mapping['original_file_name'],
                                                            file_mapping['audio_seg']['offset']
                                                            )

    return corrected_bd_dets

# %%
input = file_path_mappings[:4]
num_rows = min(len(input), multiprocessing.cpu_count())
num_cols = len(input)
time_taken_test3 = np.zeros((num_rows, num_cols))
for i in range(num_rows):
    for j in range(num_cols):
        num_processes = int(i+1)
        pool = multiprocessing.Pool(processes=num_processes)
        chunksize_custom = int(j+1)
        print(f'Parsing {len(input)} chunks with {num_processes} processors and {chunksize_custom} chunks per processor')
        start = time.time()
        results = pool.map(apply_model, input, chunksize=chunksize_custom)
        bd_preds = gen_empty_df() 
        bd_preds = pd.concat(results, ignore_index=True)
        end = time.time()
        time_taken_test3[i,j] = end-start
# Out:
# Parsing 4 chunks with 1 processors and 1 chunks per processor
# Parsing 4 chunks with 1 processors and 2 chunks per processor
# Parsing 4 chunks with 1 processors and 3 chunks per processor
# Parsing 4 chunks with 1 processors and 4 chunks per processor
# Parsing 4 chunks with 2 processors and 1 chunks per processor
# Parsing 4 chunks with 2 processors and 2 chunks per processor
# Parsing 4 chunks with 2 processors and 3 chunks per processor
# Parsing 4 chunks with 2 processors and 4 chunks per processor
# Parsing 4 chunks with 3 processors and 1 chunks per processor
# Parsing 4 chunks with 3 processors and 2 chunks per processor
# Parsing 4 chunks with 3 processors and 3 chunks per processor
# Parsing 4 chunks with 3 processors and 4 chunks per processor
# Parsing 4 chunks with 4 processors and 1 chunks per processor
# Parsing 4 chunks with 4 processors and 2 chunks per processor
# Parsing 4 chunks with 4 processors and 3 chunks per processor
# Parsing 4 chunks with 4 processors and 4 chunks per processor

# %%
time_taken_test3
# Out:
# array([[13.39124942, 13.08490515, 13.81375408, 13.18254256],
#        [36.94008565, 33.83232522, 24.64717197, 13.20165777],
#        [38.05795646, 34.39519143, 24.61158085, 12.15549445],
#        [43.58649564, 37.67900062, 24.27335048, 12.95368958]])

# %%
plt.plot(time_taken_test3.T, marker='.')
plt.xlabel('Chunksize (chunks per processor)')
plt.ylabel('Time taken (s)')
line_labs = []
for p in range(num_rows):
    line_labs+=[f'{int(p+1)} processes']
plt.legend(line_labs)
plt.xticks(np.arange(4), np.arange(4)+1)
plt.grid(which='both')
plt.show()

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if os.path.isfile(file_path_mappings[0]['model'].model_path):
    NET_PARAMS = torch.load(file_path_mappings[0]['model'].model_path, map_location=DEVICE)
    
if NET_PARAMS['params']['model_name'] == 'Net2DFast':
    MODEL = models.Net2DFast(NET_PARAMS['params']['num_filters'], num_classes=len(NET_PARAMS['params']['class_names']),
                                emb_dim=NET_PARAMS['params']['emb_dim'], ip_height=NET_PARAMS['params']['ip_height'],
                                resize_factor=NET_PARAMS['params']['resize_factor'])
elif NET_PARAMS['params']['model_name'] == 'Net2DFastNoAttn':
    MODEL = models.Net2DFastNoAttn(NET_PARAMS['params']['num_filters'], num_classes=len(NET_PARAMS['params']['class_names']),
                                emb_dim=NET_PARAMS['params']['emb_dim'], ip_height=NET_PARAMS['params']['ip_height'],
                                resize_factor=NET_PARAMS['params']['resize_factor'])
elif NET_PARAMS['params']['model_name'] == 'Net2DFastNoCoordConv':
    MODEL = models.Net2DFastNoCoordConv(NET_PARAMS['params']['num_filters'], num_classes=len(NET_PARAMS['params']['class_names']),
                                emb_dim=NET_PARAMS['params']['emb_dim'], ip_height=NET_PARAMS['params']['ip_height'],
                                resize_factor=NET_PARAMS['params']['resize_factor'])
else:
    print('Error: unknown model.')
MODEL.load_state_dict(NET_PARAMS['state_dict'])
# Out:
# <All keys matched successfully>

# %%
def load_model():
    params = NET_PARAMS['params']
    params['device'] = DEVICE
    model = MODEL.to(params['device'])
    model.eval()

    return model, params

# %%
def process_file(audio_file, model, params, args, time_exp=None, top_n=5, return_raw_preds=False, max_duration=False):

    # store temporary results here
    predictions = []
    spec_feats  = []
    cnn_feats   = []
    spec_slices = []

    # get time expansion  factor
    if time_exp is None:
        time_exp = args['time_expansion_factor']

    params['detection_threshold'] = args['detection_threshold']

    # load audio file
    sampling_rate, audio_full = au.load_audio_file(audio_file, time_exp,
                                   params['target_samp_rate'], params['scale_raw_audio'])
    
    duration_full = audio_full.shape[0] / float(sampling_rate)

    return_np_spec = args['spec_features'] or args['spec_slices']

    # loop through larger file and split into chunks
    # TODO fix so that it overlaps correctly and takes care of duplicate detections at borders
    num_chunks = int(np.ceil(duration_full/args['chunk_size']))
    for chunk_id in range(num_chunks):

        # chunk
        chunk_time   = args['chunk_size']*chunk_id
        chunk_length = int(sampling_rate*args['chunk_size'])
        start_sample = chunk_id*chunk_length
        end_sample   = np.minimum((chunk_id+1)*chunk_length, audio_full.shape[0])
        audio = audio_full[start_sample:end_sample]

        # load audio file and compute spectrogram
        duration, spec, spec_np = du.compute_spectrogram(audio, sampling_rate, params, return_np_spec)

        # print(f'feeding {chunk_id} for {audio_file} in model')

        # # evaluate model
        # with torch.no_grad():
        #     outputs = model(spec, return_feats=args['cnn_features'])
        
        # print(model)

    #     # run non-max suppression
    #     pred_nms, features = pp.run_nms(outputs, params, np.array([float(sampling_rate)]))
    #     pred_nms = pred_nms[0]
    #     pred_nms['start_times'] += chunk_time
    #     pred_nms['end_times'] += chunk_time

    #     # if we have a background class
    #     if pred_nms['class_probs'].shape[0] > len(params['class_names']):
    #         pred_nms['class_probs'] = pred_nms['class_probs'][:-1, :]

    #     predictions.append(pred_nms)

    #     # extract features - if there are any calls detected
    #     if (pred_nms['det_probs'].shape[0] > 0):
    #         if args['spec_features']:
    #             spec_feats.append(feats.get_feats(spec_np, pred_nms, params))

    #         if args['cnn_features']:
    #             cnn_feats.append(features[0])

    #         if args['spec_slices']:
    #             spec_slices.extend(feats.extract_spec_slices(spec_np, pred_nms, params))

    # print('processed 2-sec chunks')
    # # convert the predictions into output dictionary
    # file_id = os.path.basename(audio_file)
    # predictions, spec_feats, cnn_feats, spec_slices =\
    #           du.merge_results(predictions, spec_feats, cnn_feats, spec_slices)
    # results = du.convert_results(file_id, time_exp, duration_full, params,
    #                           predictions, spec_feats, cnn_feats, spec_slices)

    # # # summarize results
    # # if not args['quiet']:
    # #     num_detections = len(results['pred_dict']['annotation'])
    # #     print('{}'.format(num_detections) + ' call(s) detected above the threshold.')

    # # # print results for top n classes
    # # if not args['quiet'] and (num_detections > 0):
    # #     class_overall = pp.overall_class_pred(predictions['det_probs'], predictions['class_probs'])
    # #     print('species name'.ljust(30) + 'probablity present')
    # #     for cc in np.argsort(class_overall)[::-1][:top_n]:
    # #         print(params['class_names'][cc].ljust(30) + str(round(class_overall[cc], 3)))

    # if return_raw_preds:
    #     return predictions
    # else:
    #     return results

# %%
def _run_batdetect(model_obj, audio_file): #
    """
    Parameters:: 
        audio_file: a path containing the post-processed wav file.

    Returns:: a pd.Dataframe containing the bat calls detections
    """

    model, params = load_model()

    model_output = process_file(
        audio_file=audio_file,
        model=model,
        params=params,
        args= {
            'detection_threshold': model_obj.detection_threshold,
            'spec_slices': model_obj.spec_slices,
            'chunk_size': model_obj.chunk_size,
            'quiet': model_obj.quiet,
            'spec_features' : False,
            'cnn_features': model_obj.cnn_features,
        },
        time_exp=model_obj.time_expansion_factor,
    )
    # annotations = model_output['pred_dict']['annotation']

    out_df = gen_empty_df()
    # if annotations:
    #     out_df = pd.DataFrame.from_records(annotations) 
        # out_df['detection_confidence'] = out_df['det_prob']
        # out_df.drop(columns = ['class', 'class_prob', 'det_prob','individual'], inplace=True)
    return out_df


def apply_model(file_mapping):
    """
    Runs the batdetect2 model on a single provided audio segmens and corrects the offsets according the segment.

    Parameters
    ------------
    file_mappings : `List`
        - List of dictionaries generated by initialize_mappings()

    Returns
    ------------
    corrected_bd_dets : `pandas.DataFrame`
        - A DataFrame of detections that will also be saved in the provided output_dir under the above csv_name
        - 7 columns in this DataFrame: start_time, end_time, low_freq, high_freq, detection_confidence, event, input_file
        - Detections are always specified w.r.t their input_file; earliest start_time can be 0 and latest end_time can be 1795.
        - Events are always "Echolocation" as we are using a model that only detects search-phase calls.
    """

    bd_dets = _run_batdetect(file_mapping['model'], file_mapping['audio_seg']['audio_file'])
    corrected_bd_dets = pipeline._correct_annotation_offsets(
                                                            bd_dets,
                                                            file_mapping['original_file_name'],
                                                            file_mapping['audio_seg']['offset']
                                                            )

    return corrected_bd_dets

# %%
input = file_path_mappings[:4]
num_rows = min(len(input), multiprocessing.cpu_count())
num_cols = len(input)
time_taken_test3 = np.zeros((num_rows, num_cols))
for i in range(num_rows):
    for j in range(num_cols):
        num_processes = int(i+1)
        pool = multiprocessing.Pool(processes=num_processes)
        chunksize_custom = int(j+1)
        print(f'Parsing {len(input)} chunks with {num_processes} processors and {chunksize_custom} chunks per processor')
        start = time.time()
        results = pool.map(apply_model, input, chunksize=chunksize_custom)
        bd_preds = gen_empty_df() 
        bd_preds = pd.concat(results, ignore_index=True)
        end = time.time()
        time_taken_test3[i,j] = end-start
# Out:
# Parsing 4 chunks with 1 processors and 1 chunks per processor
# Parsing 4 chunks with 1 processors and 2 chunks per processor
# Parsing 4 chunks with 1 processors and 3 chunks per processor
# Parsing 4 chunks with 1 processors and 4 chunks per processor
# Parsing 4 chunks with 2 processors and 1 chunks per processor
# Parsing 4 chunks with 2 processors and 2 chunks per processor
# Parsing 4 chunks with 2 processors and 3 chunks per processor
# Parsing 4 chunks with 2 processors and 4 chunks per processor
# Parsing 4 chunks with 3 processors and 1 chunks per processor
# Parsing 4 chunks with 3 processors and 2 chunks per processor
# Parsing 4 chunks with 3 processors and 3 chunks per processor
# Parsing 4 chunks with 3 processors and 4 chunks per processor
# Parsing 4 chunks with 4 processors and 1 chunks per processor
# Parsing 4 chunks with 4 processors and 2 chunks per processor
# Parsing 4 chunks with 4 processors and 3 chunks per processor
# Parsing 4 chunks with 4 processors and 4 chunks per processor

# %%
time_taken_test3
# Out:
# array([[4.86956573, 4.92413831, 4.65292454, 4.65177965],
#        [2.49199915, 2.65934014, 3.58001018, 4.59482884],
#        [2.45246696, 2.50190163, 3.62147331, 4.70688534],
#        [1.486305  , 2.50963974, 3.59477687, 4.58298063]])

# %%
plt.plot(time_taken_test3.T, marker='.')
plt.xlabel('Chunksize (chunks per processor)')
plt.ylabel('Time taken (s)')
line_labs = []
for p in range(num_rows):
    line_labs+=[f'{int(p+1)} processes']
plt.legend(line_labs)
plt.xticks(np.arange(4), np.arange(4)+1)
plt.grid(which='both')
plt.show()

# %%
new_loaded_fp_mappings = []
for i in range(len(file_path_mappings)):
    new_loaded_fp_mapping = file_path_mappings[i]

    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    if os.path.isfile(new_loaded_fp_mapping['model'].model_path):
        NET_PARAMS = torch.load(new_loaded_fp_mapping['model'].model_path, map_location=DEVICE)
        
    if NET_PARAMS['params']['model_name'] == 'Net2DFast':
        MODEL = models.Net2DFast(NET_PARAMS['params']['num_filters'], num_classes=len(NET_PARAMS['params']['class_names']),
                                    emb_dim=NET_PARAMS['params']['emb_dim'], ip_height=NET_PARAMS['params']['ip_height'],
                                    resize_factor=NET_PARAMS['params']['resize_factor'])
    elif NET_PARAMS['params']['model_name'] == 'Net2DFastNoAttn':
        MODEL = models.Net2DFastNoAttn(NET_PARAMS['params']['num_filters'], num_classes=len(NET_PARAMS['params']['class_names']),
                                    emb_dim=NET_PARAMS['params']['emb_dim'], ip_height=NET_PARAMS['params']['ip_height'],
                                    resize_factor=NET_PARAMS['params']['resize_factor'])
    elif NET_PARAMS['params']['model_name'] == 'Net2DFastNoCoordConv':
        MODEL = models.Net2DFastNoCoordConv(NET_PARAMS['params']['num_filters'], num_classes=len(NET_PARAMS['params']['class_names']),
                                    emb_dim=NET_PARAMS['params']['emb_dim'], ip_height=NET_PARAMS['params']['ip_height'],
                                    resize_factor=NET_PARAMS['params']['resize_factor'])
    else:
        print('Error: unknown model.')
    MODEL.load_state_dict(NET_PARAMS['state_dict'])

    params = NET_PARAMS['params']
    params['device'] = DEVICE
    model = MODEL.to(params['device'])
    model.eval()

    new_loaded_fp_mapping['loaded_model'] = model
    new_loaded_fp_mapping['params'] = params

    new_loaded_fp_mappings += [new_loaded_fp_mapping]

# %%
new_loaded_fp_mappings
# Out:
# [{'audio_seg': {'input_filepath': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#    'audio_file': PosixPath('../output/20220728_080000__0.00_30.00.wav'),
#    'offset': 0.0},
#   'model': <models.bat_call_detector.model_detector.BatCallDetector at 0x703b2c9960a0>,
#   'original_file_name': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#   'loaded_model': Net2DFast(
#     (conv_dn_0): ConvBlockDownCoordF(
#       (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_1): ConvBlockDownCoordF(
#       (conv): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_2): ConvBlockDownCoordF(
#       (conv): Conv2d(65, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_dn_3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_1d): Conv2d(256, 256, kernel_size=(16, 1), stride=(1, 1))
#     (conv_1d_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (att): SelfAttention(
#       (key_fun): Linear(in_features=256, out_features=256, bias=True)
#       (val_fun): Linear(in_features=256, out_features=256, bias=True)
#       (que_fun): Linear(in_features=256, out_features=256, bias=True)
#       (pro_fun): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (conv_up_2): ConvBlockUpF(
#       (conv): Conv2d(257, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_3): ConvBlockUpF(
#       (conv): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_4): ConvBlockUpF(
#       (conv): Conv2d(33, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_op): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_op_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_size_op): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (conv_classes_op): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#   ),
#   'params': {'data_dir': '/data1/bat_data/data/',
#    'ann_dir': '/data1/bat_data/annotations/anns_same/',
#    'train_split': 'same',
#    'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#    'model_name': 'Net2DFast',
#    'num_filters': 128,
#    'experiment': '../../experiments/2021_12_13__20_20_37/',
#    'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#    'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#    'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#    'notes': '',
#    'target_samp_rate': 256000,
#    'fft_win_length': 0.002,
#    'fft_overlap': 0.75,
#    'max_freq': 120000,
#    'min_freq': 10000,
#    'resize_factor': 0.5,
#    'spec_height': 256,
#    'spec_train_width': 512,
#    'spec_divide_factor': 32,
#    'denoise_spec_avg': True,
#    'scale_raw_audio': False,
#    'max_scale_spec': False,
#    'spec_scale': 'pcen',
#    'detection_overlap': 0.01,
#    'ignore_start_end': 0.01,
#    'detection_threshold': 0.01,
#    'nms_kernel_size': 9,
#    'nms_top_k_per_sec': 200,
#    'target_sigma': 2.0,
#    'aug_prob': 0.2,
#    'augment_at_train': True,
#    'augment_at_train_combine': True,
#    'echo_max_delay': 0.005,
#    'stretch_squeeze_delta': 0.04,
#    'mask_max_time_perc': 0.05,
#    'mask_max_freq_perc': 0.1,
#    'spec_amp_scaling': 2.0,
#    'aug_sampling_rates': [220500,
#     256000,
#     300000,
#     312500,
#     384000,
#     441000,
#     500000],
#    'train_loss': 'focal',
#    'det_loss_weight': 1.0,
#    'size_loss_weight': 0.1,
#    'class_loss_weight': 2.0,
#    'individual_loss_weight': 0.0,
#    'emb_dim': 0,
#    'lr': 0.001,
#    'batch_size': 8,
#    'num_workers': 4,
#    'num_epochs': 200,
#    'num_eval_epochs': 5,
#    'device': device(type='cpu'),
#    'save_test_image_during_train': False,
#    'save_test_image_after_train': True,
#    'convert_to_genus': False,
#    'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#    'class_names': ['Barbastellus barbastellus',
#     'Eptesicus serotinus',
#     'Myotis alcathoe',
#     'Myotis bechsteinii',
#     'Myotis brandtii',
#     'Myotis daubentonii',
#     'Myotis mystacinus',
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TRAIN.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'test_sets': [{'dataset_name': 'echobank',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TEST.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TEST.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'class_inv_freq': [1.9637118577957153,
#     0.7146786451339722,
#     2.441218852996826,
#     2.6182825565338135,
#     0.955857515335083,
#     0.29615065455436707,
#     0.6982086896896362,
#     0.7116808295249939,
#     1.6066733598709106,
#     5.473054885864258,
#     1.386149525642395,
#     1.0264047384262085,
#     0.7815048694610596,
#     1.8502148389816284,
#     2.458908796310425,
#     0.885977566242218,
#     0.8449437618255615],
#    'genus_names': ['Barbastellus',
#     'Eptesicus',
#     'Myotis',
#     'Nyctalus',
#     'Pipistrellus',
#     'Plecotus',
#     'Rhinolophus'],
#    'class_names_short': ['Bar bar',
#     'Ept ser',
#     'Myo alc',
#     'Myo bec',
#     'Myo bra',
#     'Myo dau',
#     'Myo mys',
#     'Myo nat',
#     'Nyc lei',
#     'Nyc noc',
#     'Pip nat',
#     'Pip pip',
#     'Pip pyg',
#     'Ple aur',
#     'Ple aus',
#     'Rhi fer',
#     'Rhi hip'],
#    'ip_height': 128}},
#  {'audio_seg': {'input_filepath': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#    'audio_file': PosixPath('../output/20220728_080000__30.00_60.00.wav'),
#    'offset': 30.0},
#   'model': <models.bat_call_detector.model_detector.BatCallDetector at 0x703b2c9960a0>,
#   'original_file_name': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#   'loaded_model': Net2DFast(
#     (conv_dn_0): ConvBlockDownCoordF(
#       (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_1): ConvBlockDownCoordF(
#       (conv): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_2): ConvBlockDownCoordF(
#       (conv): Conv2d(65, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_dn_3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_1d): Conv2d(256, 256, kernel_size=(16, 1), stride=(1, 1))
#     (conv_1d_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (att): SelfAttention(
#       (key_fun): Linear(in_features=256, out_features=256, bias=True)
#       (val_fun): Linear(in_features=256, out_features=256, bias=True)
#       (que_fun): Linear(in_features=256, out_features=256, bias=True)
#       (pro_fun): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (conv_up_2): ConvBlockUpF(
#       (conv): Conv2d(257, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_3): ConvBlockUpF(
#       (conv): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_4): ConvBlockUpF(
#       (conv): Conv2d(33, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_op): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_op_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_size_op): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (conv_classes_op): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#   ),
#   'params': {'data_dir': '/data1/bat_data/data/',
#    'ann_dir': '/data1/bat_data/annotations/anns_same/',
#    'train_split': 'same',
#    'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#    'model_name': 'Net2DFast',
#    'num_filters': 128,
#    'experiment': '../../experiments/2021_12_13__20_20_37/',
#    'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#    'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#    'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#    'notes': '',
#    'target_samp_rate': 256000,
#    'fft_win_length': 0.002,
#    'fft_overlap': 0.75,
#    'max_freq': 120000,
#    'min_freq': 10000,
#    'resize_factor': 0.5,
#    'spec_height': 256,
#    'spec_train_width': 512,
#    'spec_divide_factor': 32,
#    'denoise_spec_avg': True,
#    'scale_raw_audio': False,
#    'max_scale_spec': False,
#    'spec_scale': 'pcen',
#    'detection_overlap': 0.01,
#    'ignore_start_end': 0.01,
#    'detection_threshold': 0.01,
#    'nms_kernel_size': 9,
#    'nms_top_k_per_sec': 200,
#    'target_sigma': 2.0,
#    'aug_prob': 0.2,
#    'augment_at_train': True,
#    'augment_at_train_combine': True,
#    'echo_max_delay': 0.005,
#    'stretch_squeeze_delta': 0.04,
#    'mask_max_time_perc': 0.05,
#    'mask_max_freq_perc': 0.1,
#    'spec_amp_scaling': 2.0,
#    'aug_sampling_rates': [220500,
#     256000,
#     300000,
#     312500,
#     384000,
#     441000,
#     500000],
#    'train_loss': 'focal',
#    'det_loss_weight': 1.0,
#    'size_loss_weight': 0.1,
#    'class_loss_weight': 2.0,
#    'individual_loss_weight': 0.0,
#    'emb_dim': 0,
#    'lr': 0.001,
#    'batch_size': 8,
#    'num_workers': 4,
#    'num_epochs': 200,
#    'num_eval_epochs': 5,
#    'device': device(type='cpu'),
#    'save_test_image_during_train': False,
#    'save_test_image_after_train': True,
#    'convert_to_genus': False,
#    'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#    'class_names': ['Barbastellus barbastellus',
#     'Eptesicus serotinus',
#     'Myotis alcathoe',
#     'Myotis bechsteinii',
#     'Myotis brandtii',
#     'Myotis daubentonii',
#     'Myotis mystacinus',
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TRAIN.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'test_sets': [{'dataset_name': 'echobank',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TEST.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TEST.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'class_inv_freq': [1.9637118577957153,
#     0.7146786451339722,
#     2.441218852996826,
#     2.6182825565338135,
#     0.955857515335083,
#     0.29615065455436707,
#     0.6982086896896362,
#     0.7116808295249939,
#     1.6066733598709106,
#     5.473054885864258,
#     1.386149525642395,
#     1.0264047384262085,
#     0.7815048694610596,
#     1.8502148389816284,
#     2.458908796310425,
#     0.885977566242218,
#     0.8449437618255615],
#    'genus_names': ['Barbastellus',
#     'Eptesicus',
#     'Myotis',
#     'Nyctalus',
#     'Pipistrellus',
#     'Plecotus',
#     'Rhinolophus'],
#    'class_names_short': ['Bar bar',
#     'Ept ser',
#     'Myo alc',
#     'Myo bec',
#     'Myo bra',
#     'Myo dau',
#     'Myo mys',
#     'Myo nat',
#     'Nyc lei',
#     'Nyc noc',
#     'Pip nat',
#     'Pip pip',
#     'Pip pyg',
#     'Ple aur',
#     'Ple aus',
#     'Rhi fer',
#     'Rhi hip'],
#    'ip_height': 128}},
#  {'audio_seg': {'input_filepath': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#    'audio_file': PosixPath('../output/20220728_080000__60.00_90.00.wav'),
#    'offset': 60.0},
#   'model': <models.bat_call_detector.model_detector.BatCallDetector at 0x703b2c9960a0>,
#   'original_file_name': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#   'loaded_model': Net2DFast(
#     (conv_dn_0): ConvBlockDownCoordF(
#       (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_1): ConvBlockDownCoordF(
#       (conv): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_2): ConvBlockDownCoordF(
#       (conv): Conv2d(65, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_dn_3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_1d): Conv2d(256, 256, kernel_size=(16, 1), stride=(1, 1))
#     (conv_1d_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (att): SelfAttention(
#       (key_fun): Linear(in_features=256, out_features=256, bias=True)
#       (val_fun): Linear(in_features=256, out_features=256, bias=True)
#       (que_fun): Linear(in_features=256, out_features=256, bias=True)
#       (pro_fun): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (conv_up_2): ConvBlockUpF(
#       (conv): Conv2d(257, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_3): ConvBlockUpF(
#       (conv): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_4): ConvBlockUpF(
#       (conv): Conv2d(33, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_op): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_op_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_size_op): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (conv_classes_op): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#   ),
#   'params': {'data_dir': '/data1/bat_data/data/',
#    'ann_dir': '/data1/bat_data/annotations/anns_same/',
#    'train_split': 'same',
#    'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#    'model_name': 'Net2DFast',
#    'num_filters': 128,
#    'experiment': '../../experiments/2021_12_13__20_20_37/',
#    'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#    'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#    'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#    'notes': '',
#    'target_samp_rate': 256000,
#    'fft_win_length': 0.002,
#    'fft_overlap': 0.75,
#    'max_freq': 120000,
#    'min_freq': 10000,
#    'resize_factor': 0.5,
#    'spec_height': 256,
#    'spec_train_width': 512,
#    'spec_divide_factor': 32,
#    'denoise_spec_avg': True,
#    'scale_raw_audio': False,
#    'max_scale_spec': False,
#    'spec_scale': 'pcen',
#    'detection_overlap': 0.01,
#    'ignore_start_end': 0.01,
#    'detection_threshold': 0.01,
#    'nms_kernel_size': 9,
#    'nms_top_k_per_sec': 200,
#    'target_sigma': 2.0,
#    'aug_prob': 0.2,
#    'augment_at_train': True,
#    'augment_at_train_combine': True,
#    'echo_max_delay': 0.005,
#    'stretch_squeeze_delta': 0.04,
#    'mask_max_time_perc': 0.05,
#    'mask_max_freq_perc': 0.1,
#    'spec_amp_scaling': 2.0,
#    'aug_sampling_rates': [220500,
#     256000,
#     300000,
#     312500,
#     384000,
#     441000,
#     500000],
#    'train_loss': 'focal',
#    'det_loss_weight': 1.0,
#    'size_loss_weight': 0.1,
#    'class_loss_weight': 2.0,
#    'individual_loss_weight': 0.0,
#    'emb_dim': 0,
#    'lr': 0.001,
#    'batch_size': 8,
#    'num_workers': 4,
#    'num_epochs': 200,
#    'num_eval_epochs': 5,
#    'device': device(type='cpu'),
#    'save_test_image_during_train': False,
#    'save_test_image_after_train': True,
#    'convert_to_genus': False,
#    'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#    'class_names': ['Barbastellus barbastellus',
#     'Eptesicus serotinus',
#     'Myotis alcathoe',
#     'Myotis bechsteinii',
#     'Myotis brandtii',
#     'Myotis daubentonii',
#     'Myotis mystacinus',
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TRAIN.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'test_sets': [{'dataset_name': 'echobank',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TEST.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TEST.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'class_inv_freq': [1.9637118577957153,
#     0.7146786451339722,
#     2.441218852996826,
#     2.6182825565338135,
#     0.955857515335083,
#     0.29615065455436707,
#     0.6982086896896362,
#     0.7116808295249939,
#     1.6066733598709106,
#     5.473054885864258,
#     1.386149525642395,
#     1.0264047384262085,
#     0.7815048694610596,
#     1.8502148389816284,
#     2.458908796310425,
#     0.885977566242218,
#     0.8449437618255615],
#    'genus_names': ['Barbastellus',
#     'Eptesicus',
#     'Myotis',
#     'Nyctalus',
#     'Pipistrellus',
#     'Plecotus',
#     'Rhinolophus'],
#    'class_names_short': ['Bar bar',
#     'Ept ser',
#     'Myo alc',
#     'Myo bec',
#     'Myo bra',
#     'Myo dau',
#     'Myo mys',
#     'Myo nat',
#     'Nyc lei',
#     'Nyc noc',
#     'Pip nat',
#     'Pip pip',
#     'Pip pyg',
#     'Ple aur',
#     'Ple aus',
#     'Rhi fer',
#     'Rhi hip'],
#    'ip_height': 128}},
#  {'audio_seg': {'input_filepath': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#    'audio_file': PosixPath('../output/20220728_080000__90.00_120.00.wav'),
#    'offset': 90.0},
#   'model': <models.bat_call_detector.model_detector.BatCallDetector at 0x703b2c9960a0>,
#   'original_file_name': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#   'loaded_model': Net2DFast(
#     (conv_dn_0): ConvBlockDownCoordF(
#       (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_1): ConvBlockDownCoordF(
#       (conv): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_2): ConvBlockDownCoordF(
#       (conv): Conv2d(65, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_dn_3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_1d): Conv2d(256, 256, kernel_size=(16, 1), stride=(1, 1))
#     (conv_1d_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (att): SelfAttention(
#       (key_fun): Linear(in_features=256, out_features=256, bias=True)
#       (val_fun): Linear(in_features=256, out_features=256, bias=True)
#       (que_fun): Linear(in_features=256, out_features=256, bias=True)
#       (pro_fun): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (conv_up_2): ConvBlockUpF(
#       (conv): Conv2d(257, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_3): ConvBlockUpF(
#       (conv): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_4): ConvBlockUpF(
#       (conv): Conv2d(33, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_op): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_op_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_size_op): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (conv_classes_op): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#   ),
#   'params': {'data_dir': '/data1/bat_data/data/',
#    'ann_dir': '/data1/bat_data/annotations/anns_same/',
#    'train_split': 'same',
#    'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#    'model_name': 'Net2DFast',
#    'num_filters': 128,
#    'experiment': '../../experiments/2021_12_13__20_20_37/',
#    'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#    'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#    'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#    'notes': '',
#    'target_samp_rate': 256000,
#    'fft_win_length': 0.002,
#    'fft_overlap': 0.75,
#    'max_freq': 120000,
#    'min_freq': 10000,
#    'resize_factor': 0.5,
#    'spec_height': 256,
#    'spec_train_width': 512,
#    'spec_divide_factor': 32,
#    'denoise_spec_avg': True,
#    'scale_raw_audio': False,
#    'max_scale_spec': False,
#    'spec_scale': 'pcen',
#    'detection_overlap': 0.01,
#    'ignore_start_end': 0.01,
#    'detection_threshold': 0.01,
#    'nms_kernel_size': 9,
#    'nms_top_k_per_sec': 200,
#    'target_sigma': 2.0,
#    'aug_prob': 0.2,
#    'augment_at_train': True,
#    'augment_at_train_combine': True,
#    'echo_max_delay': 0.005,
#    'stretch_squeeze_delta': 0.04,
#    'mask_max_time_perc': 0.05,
#    'mask_max_freq_perc': 0.1,
#    'spec_amp_scaling': 2.0,
#    'aug_sampling_rates': [220500,
#     256000,
#     300000,
#     312500,
#     384000,
#     441000,
#     500000],
#    'train_loss': 'focal',
#    'det_loss_weight': 1.0,
#    'size_loss_weight': 0.1,
#    'class_loss_weight': 2.0,
#    'individual_loss_weight': 0.0,
#    'emb_dim': 0,
#    'lr': 0.001,
#    'batch_size': 8,
#    'num_workers': 4,
#    'num_epochs': 200,
#    'num_eval_epochs': 5,
#    'device': device(type='cpu'),
#    'save_test_image_during_train': False,
#    'save_test_image_after_train': True,
#    'convert_to_genus': False,
#    'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#    'class_names': ['Barbastellus barbastellus',
#     'Eptesicus serotinus',
#     'Myotis alcathoe',
#     'Myotis bechsteinii',
#     'Myotis brandtii',
#     'Myotis daubentonii',
#     'Myotis mystacinus',
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TRAIN.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'test_sets': [{'dataset_name': 'echobank',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TEST.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TEST.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'class_inv_freq': [1.9637118577957153,
#     0.7146786451339722,
#     2.441218852996826,
#     2.6182825565338135,
#     0.955857515335083,
#     0.29615065455436707,
#     0.6982086896896362,
#     0.7116808295249939,
#     1.6066733598709106,
#     5.473054885864258,
#     1.386149525642395,
#     1.0264047384262085,
#     0.7815048694610596,
#     1.8502148389816284,
#     2.458908796310425,
#     0.885977566242218,
#     0.8449437618255615],
#    'genus_names': ['Barbastellus',
#     'Eptesicus',
#     'Myotis',
#     'Nyctalus',
#     'Pipistrellus',
#     'Plecotus',
#     'Rhinolophus'],
#    'class_names_short': ['Bar bar',
#     'Ept ser',
#     'Myo alc',
#     'Myo bec',
#     'Myo bra',
#     'Myo dau',
#     'Myo mys',
#     'Myo nat',
#     'Nyc lei',
#     'Nyc noc',
#     'Pip nat',
#     'Pip pip',
#     'Pip pyg',
#     'Ple aur',
#     'Ple aus',
#     'Rhi fer',
#     'Rhi hip'],
#    'ip_height': 128}},
#  {'audio_seg': {'input_filepath': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#    'audio_file': PosixPath('../output/20220728_080000__120.00_150.00.wav'),
#    'offset': 120.0},
#   'model': <models.bat_call_detector.model_detector.BatCallDetector at 0x703b2c9960a0>,
#   'original_file_name': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#   'loaded_model': Net2DFast(
#     (conv_dn_0): ConvBlockDownCoordF(
#       (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_1): ConvBlockDownCoordF(
#       (conv): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_2): ConvBlockDownCoordF(
#       (conv): Conv2d(65, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_dn_3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_1d): Conv2d(256, 256, kernel_size=(16, 1), stride=(1, 1))
#     (conv_1d_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (att): SelfAttention(
#       (key_fun): Linear(in_features=256, out_features=256, bias=True)
#       (val_fun): Linear(in_features=256, out_features=256, bias=True)
#       (que_fun): Linear(in_features=256, out_features=256, bias=True)
#       (pro_fun): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (conv_up_2): ConvBlockUpF(
#       (conv): Conv2d(257, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_3): ConvBlockUpF(
#       (conv): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_4): ConvBlockUpF(
#       (conv): Conv2d(33, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_op): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_op_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_size_op): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (conv_classes_op): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#   ),
#   'params': {'data_dir': '/data1/bat_data/data/',
#    'ann_dir': '/data1/bat_data/annotations/anns_same/',
#    'train_split': 'same',
#    'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#    'model_name': 'Net2DFast',
#    'num_filters': 128,
#    'experiment': '../../experiments/2021_12_13__20_20_37/',
#    'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#    'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#    'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#    'notes': '',
#    'target_samp_rate': 256000,
#    'fft_win_length': 0.002,
#    'fft_overlap': 0.75,
#    'max_freq': 120000,
#    'min_freq': 10000,
#    'resize_factor': 0.5,
#    'spec_height': 256,
#    'spec_train_width': 512,
#    'spec_divide_factor': 32,
#    'denoise_spec_avg': True,
#    'scale_raw_audio': False,
#    'max_scale_spec': False,
#    'spec_scale': 'pcen',
#    'detection_overlap': 0.01,
#    'ignore_start_end': 0.01,
#    'detection_threshold': 0.01,
#    'nms_kernel_size': 9,
#    'nms_top_k_per_sec': 200,
#    'target_sigma': 2.0,
#    'aug_prob': 0.2,
#    'augment_at_train': True,
#    'augment_at_train_combine': True,
#    'echo_max_delay': 0.005,
#    'stretch_squeeze_delta': 0.04,
#    'mask_max_time_perc': 0.05,
#    'mask_max_freq_perc': 0.1,
#    'spec_amp_scaling': 2.0,
#    'aug_sampling_rates': [220500,
#     256000,
#     300000,
#     312500,
#     384000,
#     441000,
#     500000],
#    'train_loss': 'focal',
#    'det_loss_weight': 1.0,
#    'size_loss_weight': 0.1,
#    'class_loss_weight': 2.0,
#    'individual_loss_weight': 0.0,
#    'emb_dim': 0,
#    'lr': 0.001,
#    'batch_size': 8,
#    'num_workers': 4,
#    'num_epochs': 200,
#    'num_eval_epochs': 5,
#    'device': device(type='cpu'),
#    'save_test_image_during_train': False,
#    'save_test_image_after_train': True,
#    'convert_to_genus': False,
#    'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#    'class_names': ['Barbastellus barbastellus',
#     'Eptesicus serotinus',
#     'Myotis alcathoe',
#     'Myotis bechsteinii',
#     'Myotis brandtii',
#     'Myotis daubentonii',
#     'Myotis mystacinus',
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
# ...
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TRAIN.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'test_sets': [{'dataset_name': 'echobank',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TEST.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TEST.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'class_inv_freq': [1.9637118577957153,
#     0.7146786451339722,
#     2.441218852996826,
#     2.6182825565338135,
#     0.955857515335083,
#     0.29615065455436707,
#     0.6982086896896362,
#     0.7116808295249939,
#     1.6066733598709106,
#     5.473054885864258,
#     1.386149525642395,
#     1.0264047384262085,
#     0.7815048694610596,
#     1.8502148389816284,
#     2.458908796310425,
#     0.885977566242218,
#     0.8449437618255615],
#    'genus_names': ['Barbastellus',
#     'Eptesicus',
#     'Myotis',
#     'Nyctalus',
#     'Pipistrellus',
#     'Plecotus',
#     'Rhinolophus'],
#    'class_names_short': ['Bar bar',
#     'Ept ser',
#     'Myo alc',
#     'Myo bec',
#     'Myo bra',
#     'Myo dau',
#     'Myo mys',
#     'Myo nat',
#     'Nyc lei',
#     'Nyc noc',
#     'Pip nat',
#     'Pip pip',
#     'Pip pyg',
#     'Ple aur',
#     'Ple aus',
#     'Rhi fer',
#     'Rhi hip'],
#    'ip_height': 128}},
#  {'audio_seg': {'input_filepath': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#    'audio_file': PosixPath('../output/20220728_080000__1770.00_1795.00.wav'),
#    'offset': 1770.0},
#   'model': <models.bat_call_detector.model_detector.BatCallDetector at 0x703b2c9960a0>,
#   'original_file_name': PosixPath('../../Downloads/recover-20220728/Carp/20220728_080000.WAV'),
#   'loaded_model': Net2DFast(
#     (conv_dn_0): ConvBlockDownCoordF(
#       (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_1): ConvBlockDownCoordF(
#       (conv): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_2): ConvBlockDownCoordF(
#       (conv): Conv2d(65, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_dn_3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_dn_3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_1d): Conv2d(256, 256, kernel_size=(16, 1), stride=(1, 1))
#     (conv_1d_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (att): SelfAttention(
#       (key_fun): Linear(in_features=256, out_features=256, bias=True)
#       (val_fun): Linear(in_features=256, out_features=256, bias=True)
#       (que_fun): Linear(in_features=256, out_features=256, bias=True)
#       (pro_fun): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (conv_up_2): ConvBlockUpF(
#       (conv): Conv2d(257, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_3): ConvBlockUpF(
#       (conv): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_up_4): ConvBlockUpF(
#       (conv): Conv2d(33, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv_op): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_op_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_size_op): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (conv_classes_op): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#   ),
#   'params': {'data_dir': '/data1/bat_data/data/',
#    'ann_dir': '/data1/bat_data/annotations/anns_same/',
#    'train_split': 'same',
#    'standardize_classs_names_ip': 'Rhinolophus ferrumequinum;Rhinolophus hipposideros',
#    'model_name': 'Net2DFast',
#    'num_filters': 128,
#    'experiment': '../../experiments/2021_12_13__20_20_37/',
#    'model_file_name': '../../experiments/2021_12_13__20_20_37/2021_12_13__20_20_37.pth.tar',
#    'op_im_dir': '../../experiments/2021_12_13__20_20_37/op_ims/',
#    'op_im_dir_test': '../../experiments/2021_12_13__20_20_37/op_ims_test/',
#    'notes': '',
#    'target_samp_rate': 256000,
#    'fft_win_length': 0.002,
#    'fft_overlap': 0.75,
#    'max_freq': 120000,
#    'min_freq': 10000,
#    'resize_factor': 0.5,
#    'spec_height': 256,
#    'spec_train_width': 512,
#    'spec_divide_factor': 32,
#    'denoise_spec_avg': True,
#    'scale_raw_audio': False,
#    'max_scale_spec': False,
#    'spec_scale': 'pcen',
#    'detection_overlap': 0.01,
#    'ignore_start_end': 0.01,
#    'detection_threshold': 0.01,
#    'nms_kernel_size': 9,
#    'nms_top_k_per_sec': 200,
#    'target_sigma': 2.0,
#    'aug_prob': 0.2,
#    'augment_at_train': True,
#    'augment_at_train_combine': True,
#    'echo_max_delay': 0.005,
#    'stretch_squeeze_delta': 0.04,
#    'mask_max_time_perc': 0.05,
#    'mask_max_freq_perc': 0.1,
#    'spec_amp_scaling': 2.0,
#    'aug_sampling_rates': [220500,
#     256000,
#     300000,
#     312500,
#     384000,
#     441000,
#     500000],
#    'train_loss': 'focal',
#    'det_loss_weight': 1.0,
#    'size_loss_weight': 0.1,
#    'class_loss_weight': 2.0,
#    'individual_loss_weight': 0.0,
#    'emb_dim': 0,
#    'lr': 0.001,
#    'batch_size': 8,
#    'num_workers': 4,
#    'num_epochs': 200,
#    'num_eval_epochs': 5,
#    'device': device(type='cpu'),
#    'save_test_image_during_train': False,
#    'save_test_image_after_train': True,
#    'convert_to_genus': False,
#    'genus_mapping': [0, 1, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6],
#    'class_names': ['Barbastellus barbastellus',
#     'Eptesicus serotinus',
#     'Myotis alcathoe',
#     'Myotis bechsteinii',
#     'Myotis brandtii',
#     'Myotis daubentonii',
#     'Myotis mystacinus',
#     'Myotis nattereri',
#     'Nyctalus leisleri',
#     'Nyctalus noctula',
#     'Pipistrellus nathusii',
#     'Pipistrellus pipistrellus',
#     'Pipistrellus pygmaeus',
#     'Plecotus auritus',
#     'Plecotus austriacus',
#     'Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'classes_to_ignore': ['', ' ', 'Unknown', 'Not Bat'],
#    'generic_class': ['Bat'],
#    'events_of_interest': ['Echolocation'],
#    'standardize_classs_names': ['Rhinolophus ferrumequinum',
#     'Rhinolophus hipposideros'],
#    'train_sets': [{'dataset_name': 'BatDetective',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bulgaria_batdetective_with_bbs.json',
#      'wav_path': 'bat_detective/audio/'},
#     {'dataset_name': 'bat_logger_qeop_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'bat_logger_qeop_empty.json',
#      'wav_path': 'bat_logger_qeop_empty/audio/'},
#     {'dataset_name': 'bat_logger_2016_empty',
#      'is_test': False,
#      'is_binary': True,
#      'ann_path': 'train_set_bat_logger_2016_empty.json',
#      'wav_path': 'bat_logger_2016/audio/'},
#     {'dataset_name': 'echobank',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TRAIN.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TRAIN.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TRAIN.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TRAIN.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': False,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TRAIN.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'test_sets': [{'dataset_name': 'echobank',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'Echobank_train_expert_TEST.json',
#      'wav_path': 'echobank/audio/'},
#     {'dataset_name': 'sn_scot_nor',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'sn_scot_nor_0.5_expert_TEST.json',
#      'wav_path': 'sn_scot_nor/audio/'},
#     {'dataset_name': 'BCT_1_sec',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BCT_1_sec_train_expert_TEST.json',
#      'wav_path': 'BCT_1_sec/audio/'},
#     {'dataset_name': 'bcireland',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'bcireland_expert_TEST.json',
#      'wav_path': 'bcireland/audio/'},
#     {'dataset_name': 'rhinolophus_steve_BCT',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'rhinolophus_steve_BCT_expert_TEST.json',
#      'wav_path': 'rhinolophus_steve_BCT/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018/audio/'},
#     {'dataset_name': 'bat_data_martyn_2018_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2018_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2018_test/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_train_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019/audio/'},
#     {'dataset_name': 'bat_data_martyn_2019_test',
#      'is_test': True,
#      'is_binary': False,
#      'ann_path': 'BritishBatCalls_MartynCooke_2019_1_sec_test_expert_TEST.json',
#      'wav_path': 'bat_data_martyn_2019_test/audio/'}],
#    'class_inv_freq': [1.9637118577957153,
#     0.7146786451339722,
#     2.441218852996826,
#     2.6182825565338135,
#     0.955857515335083,
#     0.29615065455436707,
#     0.6982086896896362,
#     0.7116808295249939,
#     1.6066733598709106,
#     5.473054885864258,
#     1.386149525642395,
#     1.0264047384262085,
#     0.7815048694610596,
#     1.8502148389816284,
#     2.458908796310425,
#     0.885977566242218,
#     0.8449437618255615],
#    'genus_names': ['Barbastellus',
#     'Eptesicus',
#     'Myotis',
#     'Nyctalus',
#     'Pipistrellus',
#     'Plecotus',
#     'Rhinolophus'],
#    'class_names_short': ['Bar bar',
#     'Ept ser',
#     'Myo alc',
#     'Myo bec',
#     'Myo bra',
#     'Myo dau',
#     'Myo mys',
#     'Myo nat',
#     'Nyc lei',
#     'Nyc noc',
#     'Pip nat',
#     'Pip pip',
#     'Pip pyg',
#     'Ple aur',
#     'Ple aus',
#     'Rhi fer',
#     'Rhi hip'],
#    'ip_height': 128}}]

# %%
torch.set_num_threads(1)

# %%
def process_file(audio_file, model, params, args, time_exp=None, top_n=5, return_raw_preds=False, max_duration=False):

    # store temporary results here
    predictions = []
    spec_feats  = []
    cnn_feats   = []
    spec_slices = []

    # get time expansion  factor
    if time_exp is None:
        time_exp = args['time_expansion_factor']

    params['detection_threshold'] = args['detection_threshold']

    # load audio file
    sampling_rate, audio_full = au.load_audio_file(audio_file, time_exp,
                                   params['target_samp_rate'], params['scale_raw_audio'])
    
    duration_full = audio_full.shape[0] / float(sampling_rate)

    return_np_spec = args['spec_features'] or args['spec_slices']

    # loop through larger file and split into chunks
    # TODO fix so that it overlaps correctly and takes care of duplicate detections at borders
    num_chunks = int(np.ceil(duration_full/args['chunk_size']))
    for chunk_id in range(num_chunks):

        # chunk
        chunk_time   = args['chunk_size']*chunk_id
        chunk_length = int(sampling_rate*args['chunk_size'])
        start_sample = chunk_id*chunk_length
        end_sample   = np.minimum((chunk_id+1)*chunk_length, audio_full.shape[0])
        audio = audio_full[start_sample:end_sample]

        # load audio file and compute spectrogram
        duration, spec, spec_np = du.compute_spectrogram(audio, sampling_rate, params, return_np_spec)

        # evaluate model
        with torch.no_grad():
            outputs = model(spec, return_feats=args['cnn_features'])       

        # run non-max suppression
        pred_nms, features = pp.run_nms(outputs, params, np.array([float(sampling_rate)]))
        pred_nms = pred_nms[0]
        pred_nms['start_times'] += chunk_time
        pred_nms['end_times'] += chunk_time

        # if we have a background class
        if pred_nms['class_probs'].shape[0] > len(params['class_names']):
            pred_nms['class_probs'] = pred_nms['class_probs'][:-1, :]

        predictions.append(pred_nms)

        # extract features - if there are any calls detected
        if (pred_nms['det_probs'].shape[0] > 0):
            if args['spec_features']:
                spec_feats.append(feats.get_feats(spec_np, pred_nms, params))

            if args['cnn_features']:
                cnn_feats.append(features[0])

            if args['spec_slices']:
                spec_slices.extend(feats.extract_spec_slices(spec_np, pred_nms, params))

    # convert the predictions into output dictionary
    file_id = os.path.basename(audio_file)
    predictions, spec_feats, cnn_feats, spec_slices =\
              du.merge_results(predictions, spec_feats, cnn_feats, spec_slices)
    results = du.convert_results(file_id, time_exp, duration_full, params,
                              predictions, spec_feats, cnn_feats, spec_slices)

    # summarize results
    if not args['quiet']:
        num_detections = len(results['pred_dict']['annotation'])
        print('{}'.format(num_detections) + ' call(s) detected above the threshold.')

    # print results for top n classes
    if not args['quiet'] and (num_detections > 0):
        class_overall = pp.overall_class_pred(predictions['det_probs'], predictions['class_probs'])
        print('species name'.ljust(30) + 'probablity present')
        for cc in np.argsort(class_overall)[::-1][:top_n]:
            print(params['class_names'][cc].ljust(30) + str(round(class_overall[cc], 3)))

    if return_raw_preds:
        return predictions
    else:
        return results

# %%
def _run_batdetect(model_obj, audio_file, model, params): #
    """
    Parameters:: 
        audio_file: a path containing the post-processed wav file.

    Returns:: a pd.Dataframe containing the bat calls detections
    """

    # Suppress output from this call
    text_trap = io.StringIO()
    sys.stdout = text_trap

    model_output = process_file(
        audio_file=audio_file,
        model=model,
        params=params,
        args= {
            'detection_threshold': model_obj.detection_threshold,
            'spec_slices': model_obj.spec_slices,
            'chunk_size': model_obj.chunk_size,
            'quiet': model_obj.quiet,
            'spec_features' : False,
            'cnn_features': model_obj.cnn_features,
        },
        time_exp=model_obj.time_expansion_factor,
    )
    annotations = model_output['pred_dict']['annotation']

    # Restore stdout
    sys.stdout = sys.__stdout__

    out_df = gen_empty_df()
    if annotations:
        out_df = pd.DataFrame.from_records(annotations) 
        # out_df['detection_confidence'] = out_df['det_prob']
        # out_df.drop(columns = ['class', 'class_prob', 'det_prob','individual'], inplace=True)
    return out_df


def apply_model(file_mapping):
    """
    Runs the batdetect2 model on a single provided audio segmens and corrects the offsets according the segment.

    Parameters
    ------------
    file_mappings : `List`
        - List of dictionaries generated by initialize_mappings()

    Returns
    ------------
    corrected_bd_dets : `pandas.DataFrame`
        - A DataFrame of detections that will also be saved in the provided output_dir under the above csv_name
        - 7 columns in this DataFrame: start_time, end_time, low_freq, high_freq, detection_confidence, event, input_file
        - Detections are always specified w.r.t their input_file; earliest start_time can be 0 and latest end_time can be 1795.
        - Events are always "Echolocation" as we are using a model that only detects search-phase calls.
    """

    bd_dets = _run_batdetect(file_mapping['model'], file_mapping['audio_seg']['audio_file'], 
                             file_mapping['loaded_model'], file_mapping['params'])
    corrected_bd_dets = pipeline._correct_annotation_offsets(
                                                            bd_dets,
                                                            file_mapping['original_file_name'],
                                                            file_mapping['audio_seg']['offset']
                                                            )

    return corrected_bd_dets

# %%
input = new_loaded_fp_mappings[:4]
num_rows = min(len(input), multiprocessing.cpu_count())
num_cols = len(input)
time_taken_test3 = np.zeros((num_rows, num_cols))
for i in range(num_rows):
    for j in range(num_cols):
        num_processes = int(i+1)
        pool = multiprocessing.Pool(processes=num_processes)
        chunksize_custom = int(j+1)
        print(f'Parsing {len(input)} chunks with {num_processes} processors and {chunksize_custom} chunks per processor')
        start = time.time()
        results = pool.map(apply_model, input, chunksize=chunksize_custom)
        bd_preds = gen_empty_df() 
        bd_preds = pd.concat(results, ignore_index=True)
        end = time.time()
        time_taken_test3[i,j] = end-start
# Out:
# Parsing 4 chunks with 1 processors and 1 chunks per processor
# Parsing 4 chunks with 1 processors and 2 chunks per processor
# Parsing 4 chunks with 1 processors and 3 chunks per processor
# Parsing 4 chunks with 1 processors and 4 chunks per processor
# Parsing 4 chunks with 2 processors and 1 chunks per processor
# Parsing 4 chunks with 2 processors and 2 chunks per processor
# Parsing 4 chunks with 2 processors and 3 chunks per processor
# Parsing 4 chunks with 2 processors and 4 chunks per processor
# Parsing 4 chunks with 3 processors and 1 chunks per processor
# Parsing 4 chunks with 3 processors and 2 chunks per processor
# Parsing 4 chunks with 3 processors and 3 chunks per processor
# Parsing 4 chunks with 3 processors and 4 chunks per processor
# Parsing 4 chunks with 4 processors and 1 chunks per processor
# Parsing 4 chunks with 4 processors and 2 chunks per processor
# Parsing 4 chunks with 4 processors and 3 chunks per processor
# Parsing 4 chunks with 4 processors and 4 chunks per processor

# %%
time_taken_test3
# Out:
# array([[44.1097858 , 41.70545864, 41.71527743, 40.44126439],
#        [20.72790313, 21.121315  , 30.66671848, 40.64292049],
#        [20.74765253, 21.23502469, 30.89642978, 41.44846439],
#        [11.22150445, 20.69071436, 31.43957376, 40.26735353]])

# %%
plt.plot(time_taken_test3.T, marker='.')
plt.xlabel('Chunksize (chunks per processor)')
plt.ylabel('Time taken (s)')
line_labs = []
for p in range(num_rows):
    line_labs+=[f'{int(p+1)} processes']
plt.legend(line_labs)
plt.xticks(np.arange(4), np.arange(4)+1)
plt.grid(which='both')
plt.show()

# %%
input = new_loaded_fp_mappings[:16]
num_rows = min(len(input), multiprocessing.cpu_count())
num_cols = len(input)
time_taken_test3 = np.zeros((num_rows, num_cols))
for i in range(num_rows):
    for j in range(num_cols):
        num_processes = int(i+1)
        pool = multiprocessing.Pool(processes=num_processes)
        chunksize_custom = int(j+1)
        print(f'Parsing {len(input)} chunks with {num_processes} processors and {chunksize_custom} chunks per processor')
        start = time.time()
        results = pool.map(apply_model, input, chunksize=chunksize_custom)
        bd_preds = gen_empty_df() 
        bd_preds = pd.concat(results, ignore_index=True)
        end = time.time()
        time_taken_test3[i,j] = end-start
# Out:
# Parsing 16 chunks with 1 processors and 1 chunks per processor
# Parsing 16 chunks with 1 processors and 2 chunks per processor
# Parsing 16 chunks with 1 processors and 3 chunks per processor
# Parsing 16 chunks with 1 processors and 4 chunks per processor
# Parsing 16 chunks with 1 processors and 5 chunks per processor
# Parsing 16 chunks with 1 processors and 6 chunks per processor
# Parsing 16 chunks with 1 processors and 7 chunks per processor
# Parsing 16 chunks with 1 processors and 8 chunks per processor
# Parsing 16 chunks with 1 processors and 9 chunks per processor
# Parsing 16 chunks with 1 processors and 10 chunks per processor
# Parsing 16 chunks with 1 processors and 11 chunks per processor
# Parsing 16 chunks with 1 processors and 12 chunks per processor
# Parsing 16 chunks with 1 processors and 13 chunks per processor
# Parsing 16 chunks with 1 processors and 14 chunks per processor
# Parsing 16 chunks with 1 processors and 15 chunks per processor
# Parsing 16 chunks with 1 processors and 16 chunks per processor
# Parsing 16 chunks with 2 processors and 1 chunks per processor
# Parsing 16 chunks with 2 processors and 2 chunks per processor
# Parsing 16 chunks with 2 processors and 3 chunks per processor
# Parsing 16 chunks with 2 processors and 4 chunks per processor
# Parsing 16 chunks with 2 processors and 5 chunks per processor
# Parsing 16 chunks with 2 processors and 6 chunks per processor
# Parsing 16 chunks with 2 processors and 7 chunks per processor
# Parsing 16 chunks with 2 processors and 8 chunks per processor
# Parsing 16 chunks with 2 processors and 9 chunks per processor
# Parsing 16 chunks with 2 processors and 10 chunks per processor
# Parsing 16 chunks with 2 processors and 11 chunks per processor
# Parsing 16 chunks with 2 processors and 12 chunks per processor
# Parsing 16 chunks with 2 processors and 13 chunks per processor
# Parsing 16 chunks with 2 processors and 14 chunks per processor
# Parsing 16 chunks with 2 processors and 15 chunks per processor
# Parsing 16 chunks with 2 processors and 16 chunks per processor
# Parsing 16 chunks with 3 processors and 1 chunks per processor
# Parsing 16 chunks with 3 processors and 2 chunks per processor
# Parsing 16 chunks with 3 processors and 3 chunks per processor
# Parsing 16 chunks with 3 processors and 4 chunks per processor
# Parsing 16 chunks with 3 processors and 5 chunks per processor
# Parsing 16 chunks with 3 processors and 6 chunks per processor
# Parsing 16 chunks with 3 processors and 7 chunks per processor
# Parsing 16 chunks with 3 processors and 8 chunks per processor
# Parsing 16 chunks with 3 processors and 9 chunks per processor
# Parsing 16 chunks with 3 processors and 10 chunks per processor
# Parsing 16 chunks with 3 processors and 11 chunks per processor
# Parsing 16 chunks with 3 processors and 12 chunks per processor
# Parsing 16 chunks with 3 processors and 13 chunks per processor
# Parsing 16 chunks with 3 processors and 14 chunks per processor
# Parsing 16 chunks with 3 processors and 15 chunks per processor
# Parsing 16 chunks with 3 processors and 16 chunks per processor
# Parsing 16 chunks with 4 processors and 1 chunks per processor
# Parsing 16 chunks with 4 processors and 2 chunks per processor
# Parsing 16 chunks with 4 processors and 3 chunks per processor
# Parsing 16 chunks with 4 processors and 4 chunks per processor
# Parsing 16 chunks with 4 processors and 5 chunks per processor
# Parsing 16 chunks with 4 processors and 6 chunks per processor
# Parsing 16 chunks with 4 processors and 7 chunks per processor
# Parsing 16 chunks with 4 processors and 8 chunks per processor
# Parsing 16 chunks with 4 processors and 9 chunks per processor
# Parsing 16 chunks with 4 processors and 10 chunks per processor
# Parsing 16 chunks with 4 processors and 11 chunks per processor
# Parsing 16 chunks with 4 processors and 12 chunks per processor
# Parsing 16 chunks with 4 processors and 13 chunks per processor
# Parsing 16 chunks with 4 processors and 14 chunks per processor
# Parsing 16 chunks with 4 processors and 15 chunks per processor
# Parsing 16 chunks with 4 processors and 16 chunks per processor
# Parsing 16 chunks with 5 processors and 1 chunks per processor
# Parsing 16 chunks with 5 processors and 2 chunks per processor
# Parsing 16 chunks with 5 processors and 3 chunks per processor
# Parsing 16 chunks with 5 processors and 4 chunks per processor
# Parsing 16 chunks with 5 processors and 5 chunks per processor
# Parsing 16 chunks with 5 processors and 6 chunks per processor
# Parsing 16 chunks with 5 processors and 7 chunks per processor
# Parsing 16 chunks with 5 processors and 8 chunks per processor
# Parsing 16 chunks with 5 processors and 9 chunks per processor
# Parsing 16 chunks with 5 processors and 10 chunks per processor
# Parsing 16 chunks with 5 processors and 11 chunks per processor
# Parsing 16 chunks with 5 processors and 12 chunks per processor
# Parsing 16 chunks with 5 processors and 13 chunks per processor
# Parsing 16 chunks with 5 processors and 14 chunks per processor
# Parsing 16 chunks with 5 processors and 15 chunks per processor
# Parsing 16 chunks with 5 processors and 16 chunks per processor
# Parsing 16 chunks with 6 processors and 1 chunks per processor
# Parsing 16 chunks with 6 processors and 2 chunks per processor
# Parsing 16 chunks with 6 processors and 3 chunks per processor
# Parsing 16 chunks with 6 processors and 4 chunks per processor
# Parsing 16 chunks with 6 processors and 5 chunks per processor
# Parsing 16 chunks with 6 processors and 6 chunks per processor
# Parsing 16 chunks with 6 processors and 7 chunks per processor
# Parsing 16 chunks with 6 processors and 8 chunks per processor
# Parsing 16 chunks with 6 processors and 9 chunks per processor
# Parsing 16 chunks with 6 processors and 10 chunks per processor
# Parsing 16 chunks with 6 processors and 11 chunks per processor
# Parsing 16 chunks with 6 processors and 12 chunks per processor
# Parsing 16 chunks with 6 processors and 13 chunks per processor
# Parsing 16 chunks with 6 processors and 14 chunks per processor
# Parsing 16 chunks with 6 processors and 15 chunks per processor
# Parsing 16 chunks with 6 processors and 16 chunks per processor
# Parsing 16 chunks with 7 processors and 1 chunks per processor
# Parsing 16 chunks with 7 processors and 2 chunks per processor
# Parsing 16 chunks with 7 processors and 3 chunks per processor
# Parsing 16 chunks with 7 processors and 4 chunks per processor
# Parsing 16 chunks with 7 processors and 5 chunks per processor
# Parsing 16 chunks with 7 processors and 6 chunks per processor
# Parsing 16 chunks with 7 processors and 7 chunks per processor
# Parsing 16 chunks with 7 processors and 8 chunks per processor
# Parsing 16 chunks with 7 processors and 9 chunks per processor
# Parsing 16 chunks with 7 processors and 10 chunks per processor
# Parsing 16 chunks with 7 processors and 11 chunks per processor
# Parsing 16 chunks with 7 processors and 12 chunks per processor
# Parsing 16 chunks with 7 processors and 13 chunks per processor
# Parsing 16 chunks with 7 processors and 14 chunks per processor
# Parsing 16 chunks with 7 processors and 15 chunks per processor
# Parsing 16 chunks with 7 processors and 16 chunks per processor
# Parsing 16 chunks with 8 processors and 1 chunks per processor
# Parsing 16 chunks with 8 processors and 2 chunks per processor
# Parsing 16 chunks with 8 processors and 3 chunks per processor
# Parsing 16 chunks with 8 processors and 4 chunks per processor
# Parsing 16 chunks with 8 processors and 5 chunks per processor
# Parsing 16 chunks with 8 processors and 6 chunks per processor
# Parsing 16 chunks with 8 processors and 7 chunks per processor
# Parsing 16 chunks with 8 processors and 8 chunks per processor
# Parsing 16 chunks with 8 processors and 9 chunks per processor
# Parsing 16 chunks with 8 processors and 10 chunks per processor
# Parsing 16 chunks with 8 processors and 11 chunks per processor
# Parsing 16 chunks with 8 processors and 12 chunks per processor
# Parsing 16 chunks with 8 processors and 13 chunks per processor
# Parsing 16 chunks with 8 processors and 14 chunks per processor
# Parsing 16 chunks with 8 processors and 15 chunks per processor
# Parsing 16 chunks with 8 processors and 16 chunks per processor
# Parsing 16 chunks with 9 processors and 1 chunks per processor
# Parsing 16 chunks with 9 processors and 2 chunks per processor
# Parsing 16 chunks with 9 processors and 3 chunks per processor
# Parsing 16 chunks with 9 processors and 4 chunks per processor
# Parsing 16 chunks with 9 processors and 5 chunks per processor
# Parsing 16 chunks with 9 processors and 6 chunks per processor
# Parsing 16 chunks with 9 processors and 7 chunks per processor
# Parsing 16 chunks with 9 processors and 8 chunks per processor
# Parsing 16 chunks with 9 processors and 9 chunks per processor
# Parsing 16 chunks with 9 processors and 10 chunks per processor
# Parsing 16 chunks with 9 processors and 11 chunks per processor
# Parsing 16 chunks with 9 processors and 12 chunks per processor
# Parsing 16 chunks with 9 processors and 13 chunks per processor
# Parsing 16 chunks with 9 processors and 14 chunks per processor
# Parsing 16 chunks with 9 processors and 15 chunks per processor
# Parsing 16 chunks with 9 processors and 16 chunks per processor
# Parsing 16 chunks with 10 processors and 1 chunks per processor
# Parsing 16 chunks with 10 processors and 2 chunks per processor
# Parsing 16 chunks with 10 processors and 3 chunks per processor
# Parsing 16 chunks with 10 processors and 4 chunks per processor
# Parsing 16 chunks with 10 processors and 5 chunks per processor
# Parsing 16 chunks with 10 processors and 6 chunks per processor
# Parsing 16 chunks with 10 processors and 7 chunks per processor
# Parsing 16 chunks with 10 processors and 8 chunks per processor
# Parsing 16 chunks with 10 processors and 9 chunks per processor
# Parsing 16 chunks with 10 processors and 10 chunks per processor
# Parsing 16 chunks with 10 processors and 11 chunks per processor
# Parsing 16 chunks with 10 processors and 12 chunks per processor
# Parsing 16 chunks with 10 processors and 13 chunks per processor
# Parsing 16 chunks with 10 processors and 14 chunks per processor
# Parsing 16 chunks with 10 processors and 15 chunks per processor
# Parsing 16 chunks with 10 processors and 16 chunks per processor
# Parsing 16 chunks with 11 processors and 1 chunks per processor
# Parsing 16 chunks with 11 processors and 2 chunks per processor
# Parsing 16 chunks with 11 processors and 3 chunks per processor
# Parsing 16 chunks with 11 processors and 4 chunks per processor
# Parsing 16 chunks with 11 processors and 5 chunks per processor
# Parsing 16 chunks with 11 processors and 6 chunks per processor
# Parsing 16 chunks with 11 processors and 7 chunks per processor
# Parsing 16 chunks with 11 processors and 8 chunks per processor
# Parsing 16 chunks with 11 processors and 9 chunks per processor
# Parsing 16 chunks with 11 processors and 10 chunks per processor
# Parsing 16 chunks with 11 processors and 11 chunks per processor
# Parsing 16 chunks with 11 processors and 12 chunks per processor
# Parsing 16 chunks with 11 processors and 13 chunks per processor
# Parsing 16 chunks with 11 processors and 14 chunks per processor
# Parsing 16 chunks with 11 processors and 15 chunks per processor
# Parsing 16 chunks with 11 processors and 16 chunks per processor
# Parsing 16 chunks with 12 processors and 1 chunks per processor
# Parsing 16 chunks with 12 processors and 2 chunks per processor
# Parsing 16 chunks with 12 processors and 3 chunks per processor
# Parsing 16 chunks with 12 processors and 4 chunks per processor
# Parsing 16 chunks with 12 processors and 5 chunks per processor
# Parsing 16 chunks with 12 processors and 6 chunks per processor
# Parsing 16 chunks with 12 processors and 7 chunks per processor
# Parsing 16 chunks with 12 processors and 8 chunks per processor
# Parsing 16 chunks with 12 processors and 9 chunks per processor
# Parsing 16 chunks with 12 processors and 10 chunks per processor
# Parsing 16 chunks with 12 processors and 11 chunks per processor
# Parsing 16 chunks with 12 processors and 12 chunks per processor
# Parsing 16 chunks with 12 processors and 13 chunks per processor
# Parsing 16 chunks with 12 processors and 14 chunks per processor
# Parsing 16 chunks with 12 processors and 15 chunks per processor
# Parsing 16 chunks with 12 processors and 16 chunks per processor
# Parsing 16 chunks with 13 processors and 1 chunks per processor
# Parsing 16 chunks with 13 processors and 2 chunks per processor
# Parsing 16 chunks with 13 processors and 3 chunks per processor
# Parsing 16 chunks with 13 processors and 4 chunks per processor
# Parsing 16 chunks with 13 processors and 5 chunks per processor
# Parsing 16 chunks with 13 processors and 6 chunks per processor
# Parsing 16 chunks with 13 processors and 7 chunks per processor
# Parsing 16 chunks with 13 processors and 8 chunks per processor
# Parsing 16 chunks with 13 processors and 9 chunks per processor
# Parsing 16 chunks with 13 processors and 10 chunks per processor
# Parsing 16 chunks with 13 processors and 11 chunks per processor
# Parsing 16 chunks with 13 processors and 12 chunks per processor
# Parsing 16 chunks with 13 processors and 13 chunks per processor
# Parsing 16 chunks with 13 processors and 14 chunks per processor
# Parsing 16 chunks with 13 processors and 15 chunks per processor
# Parsing 16 chunks with 13 processors and 16 chunks per processor
# Parsing 16 chunks with 14 processors and 1 chunks per processor
# Parsing 16 chunks with 14 processors and 2 chunks per processor
# Parsing 16 chunks with 14 processors and 3 chunks per processor
# Parsing 16 chunks with 14 processors and 4 chunks per processor
# Parsing 16 chunks with 14 processors and 5 chunks per processor
# Parsing 16 chunks with 14 processors and 6 chunks per processor
# Parsing 16 chunks with 14 processors and 7 chunks per processor
# Parsing 16 chunks with 14 processors and 8 chunks per processor
# Parsing 16 chunks with 14 processors and 9 chunks per processor
# Parsing 16 chunks with 14 processors and 10 chunks per processor
# Parsing 16 chunks with 14 processors and 11 chunks per processor
# Parsing 16 chunks with 14 processors and 12 chunks per processor
# Parsing 16 chunks with 14 processors and 13 chunks per processor
# Parsing 16 chunks with 14 processors and 14 chunks per processor
# Parsing 16 chunks with 14 processors and 15 chunks per processor
# Parsing 16 chunks with 14 processors and 16 chunks per processor
# Parsing 16 chunks with 15 processors and 1 chunks per processor
# Parsing 16 chunks with 15 processors and 2 chunks per processor
# Parsing 16 chunks with 15 processors and 3 chunks per processor
# Parsing 16 chunks with 15 processors and 4 chunks per processor
# Parsing 16 chunks with 15 processors and 5 chunks per processor
# Parsing 16 chunks with 15 processors and 6 chunks per processor
# Parsing 16 chunks with 15 processors and 7 chunks per processor
# Parsing 16 chunks with 15 processors and 8 chunks per processor
# Parsing 16 chunks with 15 processors and 9 chunks per processor
# Parsing 16 chunks with 15 processors and 10 chunks per processor
# Parsing 16 chunks with 15 processors and 11 chunks per processor
# Parsing 16 chunks with 15 processors and 12 chunks per processor
# Parsing 16 chunks with 15 processors and 13 chunks per processor
# Parsing 16 chunks with 15 processors and 14 chunks per processor
# Parsing 16 chunks with 15 processors and 15 chunks per processor
# Parsing 16 chunks with 15 processors and 16 chunks per processor
# Parsing 16 chunks with 16 processors and 1 chunks per processor
# Parsing 16 chunks with 16 processors and 2 chunks per processor
# Parsing 16 chunks with 16 processors and 3 chunks per processor
# Parsing 16 chunks with 16 processors and 4 chunks per processor
# Parsing 16 chunks with 16 processors and 5 chunks per processor
# Parsing 16 chunks with 16 processors and 6 chunks per processor
# Parsing 16 chunks with 16 processors and 7 chunks per processor
# Parsing 16 chunks with 16 processors and 8 chunks per processor
# Parsing 16 chunks with 16 processors and 9 chunks per processor
# Parsing 16 chunks with 16 processors and 10 chunks per processor
# Parsing 16 chunks with 16 processors and 11 chunks per processor
# Parsing 16 chunks with 16 processors and 12 chunks per processor
# Parsing 16 chunks with 16 processors and 13 chunks per processor
# Parsing 16 chunks with 16 processors and 14 chunks per processor
# Parsing 16 chunks with 16 processors and 15 chunks per processor
# Parsing 16 chunks with 16 processors and 16 chunks per processor

# %%
time_taken_test3
# Out:
# array([[165.77352953, 160.84104037, 156.53736663, 161.11377716,
#         156.62236094, 159.11930919, 156.74007106, 153.62603879,
#         153.65318179, 153.900985  , 158.98989272, 152.49517989,
#         162.30390859, 157.46443939, 156.30852842, 158.89336658],
#        [ 78.51744676,  78.6301527 ,  84.6977973 ,  79.34801364,
#          98.53740931,  95.16973901,  89.62143135,  78.56470871,
#          89.10045815,  98.20597649, 110.57920122, 118.12569308,
#         129.52027941, 131.2989049 , 136.16177487, 150.8216269 ],
#        [ 59.01740813,  59.86200404,  62.14483714,  79.88263535,
#          58.86357427,  61.03936267,  69.65591908,  79.74658561,
#          91.48618031,  98.48544049, 107.96752381, 117.78455663,
#         127.56521964, 137.95272946, 146.50853109, 153.32636905],
#        [ 41.76296949,  41.18852568,  58.62907887,  42.57659078,
#          50.47691345,  60.70567346,  70.02882147,  78.96954179,
#          88.51867986,  93.77641511, 108.17589545, 114.37264991,
#         126.20042276, 130.19703126, 145.29306984, 155.33648324],
#        [ 40.28072691,  41.22128725,  39.40656519,  41.51115513,
#          49.78407526,  60.17197156,  68.95119858,  78.86656761,
#          86.00577521,  91.85382199, 109.02874517, 112.73820877,
#         127.66565704, 139.0471952 , 144.74485683, 154.46095181],
#        [ 31.49578953,  40.67476296,  32.05505037,  43.14866662,
#          51.19335842,  60.80271411,  69.92641473,  80.9098413 ,
#          89.32945466,  99.62549257, 107.22051907, 116.73125315,
#         132.47418165, 136.59099197, 148.46523094, 158.68266153],
#        [ 32.1988945 ,  40.10860515,  32.30732822,  41.22634125,
#          50.84253478,  60.1371305 ,  68.6763432 ,  80.04107118,
#          89.2735877 ,  92.38387394, 107.19671059, 119.81477427,
#         126.69364929, 143.92536187, 145.87601566, 149.04588485],
#        [ 22.71511841,  22.41353893,  34.25437975,  44.19806862,
#          51.41961741,  61.69452548,  71.73633623,  80.57082176,
#          88.15960598,  97.7761786 , 102.92199564, 114.56895518,
#         125.11579514, 134.30793858, 144.76661038, 151.22975087],
#        [ 22.59066439,  21.83507013,  31.56945848,  41.4653995 ,
#          52.98256826,  60.05922246,  71.51347995,  80.15698266,
#          84.09984398,  98.94307613, 112.68380404, 116.55400324,
#         130.34867215, 135.59023404, 143.60366464, 155.23260999],
#        [ 22.6596303 ,  23.16360211,  31.87677693,  43.69346619,
#          50.47322702,  64.05617213,  69.92454815,  79.54537749,
#          85.30167484, 100.26725507, 109.77532339, 115.91210747,
#         125.98388481, 133.25151825, 144.40380812, 156.43509269],
#        [ 22.43934917,  23.34769177,  31.14558887,  42.04331827,
#          52.72267103,  61.72335577,  68.23429728,  80.68075991,
#          91.82703948,  94.52218699, 107.71573687, 116.07472801,
#         127.1051929 , 142.2242794 , 142.06637883, 153.39723182],
#        [ 23.20271158,  23.16290879,  32.72958565,  42.15158367,
#          49.8966856 ,  59.37772775,  70.77716064,  81.90937328,
#          88.77394056,  99.53258705,  99.57238674, 119.43066502,
#         125.00997114, 134.01971912, 140.82354999, 153.16877031],
#        [ 22.10456729,  22.39777875,  31.28722429,  41.55809665,
#          50.59214544,  60.65070844,  69.51808214,  78.84857655,
#          90.92086649,  95.45067286, 107.50439739, 119.32544017,
#         125.63524151, 137.17003059, 141.18410993, 155.38173652],
#        [ 23.75201011,  24.23356414,  32.22088456,  45.25103211,
#          54.99474859,  61.77456713,  71.60690784,  80.68206191,
#          89.57854748,  97.14296389, 109.71420979, 116.15568137,
#         120.92133021, 137.13369393, 145.85087109, 151.9075737 ],
#        [ 23.63826227,  24.14875484,  32.72932196,  40.87912226,
#          50.78476834,  60.78940821,  70.14327645,  80.52539015,
#          88.52826643,  95.82924199, 106.25967383, 117.31017828,
#         121.59736466, 134.18950343, 142.61246419, 146.01904535],
#        [ 16.4054904 ,  22.75417209,  36.58135891,  42.64321256,
#          52.38578272,  60.68045855,  70.82968068,  79.87605119,
#          88.37889218,  97.67701578, 111.2059269 , 116.96306729,
#         126.4130621 , 134.41832709, 147.26471567, 153.35230947]])

# %%
plt.figure(figsize=(8,6))
plt.plot(time_taken_test3.T, marker='.')
plt.xlabel('Chunksize (chunks per processor)')
plt.ylabel('Time taken (s)')
line_labs = []
for p in range(num_rows):
    line_labs+=[f'{int(p+1)} processes']
plt.legend(line_labs, ncols=2)
plt.xticks(np.arange(multiprocessing.cpu_count()), np.arange(multiprocessing.cpu_count())+1)
plt.grid(which='both')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.imshow(time_taken_test3)
plt.ylabel('Num_processes (processors assigned)')
plt.xlabel('Chunksize (chunks per processor)')
plt.yticks(np.arange(multiprocessing.cpu_count())-0.5, np.arange(multiprocessing.cpu_count())+1)
plt.xticks(np.arange(len(input))-0.5, np.arange(len(input))+1)
plt.grid(which='both')
plt.colorbar(label='Time taken (s)')
plt.show()
