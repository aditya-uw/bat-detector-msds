# %% [markdown]
# # Methods Notebook: Extracting Call Samples for KMeans Clustering

# %% [markdown]
# ## Imports Section:

# %%
import numpy as np
import pandas as pd
import random
import scipy
from scipy import stats
import datetime as dt
import dask.dataframe as dd

# %%
import librosa
import warnings

# %%
import glob
import matplotlib.pyplot as plt
from matplotlib import colors
import soundfile as sf
import matplotlib.patches as patches
from pathlib import Path

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
import sys

# append the path of the
# parent directory
sys.path.append('..')
sys.path.append('../src/')
sys.path.append('../src/models/bat_call_detector/batdetect2/')

import src.batdt2_pipeline as batdetect2_pipeline
import src.file_dealer as file_dealer

# %% [markdown]
# ## Function Definitions (most important functions are in `src/`)
# ### Below are the functions used for plotting and visualization

# %%
FREQ_COLORS = {'LF':'cyan', 'HF':'orange'}

# %%
def plot_audio_seg(audio_features, spec_features):
    audio_seg = audio_features['audio_seg']
    fs = audio_features['sample_rate']
    start = audio_features['start']
    duration = audio_features['duration']

    vmax = spec_features['vmax']
    vmin = spec_features['vmin']
    cmap = spec_features['cmap']
    nfft = spec_features['NFFT']

    plt.figure(figsize=(15, 5))
    plt.rcParams.update({'font.size': 24})
    plt.title(spec_features['plot_title'], fontsize=24)
    plt.specgram(audio_seg, NFFT=nfft, cmap=cmap, vmin=vmin, vmax=vmax)
    plt.yticks(ticks=np.linspace(0, 1, 6), labels=np.linspace(0, fs/2000, 6).astype('int'))
    plot_xtype = 'float'
    if (duration > 60):
        plot_xtype = 'int'
    plt.xticks(ticks=np.linspace(0, duration*(fs/2), 11), 
               labels=np.round(np.linspace(start, start+duration, 11, dtype=plot_xtype), 2), rotation=30)
    plt.ylabel("Frequency (kHz)")
    plt.xlabel("Time (s)")
    plt.show()


def plot_dets_over_audio(audio_features, spec_features, plot_dets):
    audio_seg = audio_features['audio_seg']
    fs = audio_features['sample_rate']
    start = audio_features['start']
    duration = audio_features['duration']

    vmax = spec_features['vmax']
    vmin = spec_features['vmin']
    cmap = spec_features['cmap']
    nfft = spec_features['NFFT']

    plt.figure(figsize=(10, 5))
    plt.rcParams.update({'font.size': 24})
    plt.title(spec_features['plot_title'], fontsize=24)
    plt.specgram(audio_seg, NFFT=nfft, cmap=cmap, vmin=vmin, vmax=vmax)

    ax = plt.gca()
    if len(plot_dets)>0:
        plot_dets = plot_dets[(plot_dets['start_time']>=start)&(plot_dets['end_time']<=(start+duration))]
        for i, row in plot_dets.iterrows():
            rect = patches.Rectangle(((row['start_time'] - start)*(fs/2), row['low_freq']/(fs/2)), 
                            (row['end_time'] - row['start_time'])*(fs/2), (row['high_freq'] - row['low_freq'])/(fs/2), 
                            linewidth=1.5, edgecolor=FREQ_COLORS[row['freq_group']], facecolor='none', alpha=0.8)
            ax.add_patch(rect)

    plt.yticks(ticks=np.linspace(0, 256e3/fs, 6), labels=np.linspace(0, 256e3/2000, 6).astype('int'))
    plt.ylabel("Frequency (kHz)")
    plot_xtype = 'float'
    if (duration > 60):
        plot_xtype = 'int'
    plt.xticks(ticks=np.linspace(0, duration*(fs/2), 6), 
               labels=np.linspace(0, duration, 6, dtype=plot_xtype), rotation=0)
    plt.xlabel("Time (s)")
    plt.twinx(ax=ax)
    plt.yticks(ticks=np.linspace(0, 256e3/fs, 6), labels=np.linspace(0, 256e3/2000, 6).astype('int'))
    plt.ylabel("Frequency (kHz)")
    plt.ylim(0, 256e3/fs)

    plt.show()

# %%
def convert_nabatdf_to_ravenprodf(df):
    raven_df = pd.DataFrame()
    raven_df['Begin Time (s)'] =  (df['peak_time_ms']-50)/1000
    raven_df['End Time (s)'] = (df['peak_time_ms']-40)/1000
    raven_df['Low Freq (Hz)'] = df['peak_freq_hz']-2000
    raven_df['High Freq (Hz)'] = df['peak_freq_hz']+2000
    raven_df['prediction'] = df['prediction']
    raven_df['score'] = df['score']
    raven_df.sort_values('Begin Time (s)', inplace=True)
    raven_df.insert(0, 'Selection', np.arange(len(raven_df)).astype(int)+1)

    raventxt_df = pd.DataFrame(np.repeat(raven_df.values, 2, axis=0))
    raventxt_df.columns = raven_df.columns
    raventxt_df['Selection'] = raventxt_df['Selection'].astype(int)
    raventxt_df.insert(1, 'Channel', [1]*raventxt_df.shape[0])
    views = np.array(['Waveform 1']*raventxt_df.shape[0], dtype='object')
    views[1::2] = 'Spectrogram 1'
    raventxt_df.insert(1, 'View', views)

    return raventxt_df

def convert_nabatdf_to_bd2df(df):
    bd2_df = pd.DataFrame()
    bd2_df['start_time'] = (df['peak_time_ms']-50)/1000
    bd2_df['end_time'] = (df['peak_time_ms']-40)/1000
    bd2_df['low_freq'] = df['peak_freq_hz']-2000
    bd2_df['high_freq'] = df['peak_freq_hz']+2000
    bd2_df['prediction'] = df['prediction']
    bd2_df['score'] = df['score']
    bd2_df.sort_values('start_time', inplace=True)
    
    return bd2_df

def convert_kaleidoscopedf_to_ravenprodf(df):
    raven_df = pd.DataFrame()
    raven_df['Begin Time (s)'] = df['OFFSET']
    raven_df['End Time (s)'] = df['OFFSET'] + df['DURATION']
    raven_df['Low Freq (Hz)'] = df['Fmin']
    raven_df['High Freq (Hz)'] = df['Fmax']
    raven_df['input_file'] = df['IN FILE']
    raven_df['input_dir'] = df['INDIR']
    raven_df['mean_freq'] = df['Fmean']
    if 'TOP1MATCH*' in df.columns:
        raven_df['TOP1MATCH*'] = df['TOP1MATCH*']
    if 'TOP1MATCH' in df.columns:
        raven_df['TOP1MATCH'] = df['TOP1MATCH']
    raven_df['TOP1DIST'] = df['TOP1DIST']
    raven_df['TOP2MATCH'] = df['TOP2MATCH']
    raven_df['TOP2DIST'] = df['TOP2DIST']
    raven_df['TOP3MATCH'] = df['TOP3MATCH']
    raven_df['TOP3DIST'] = df['TOP3DIST']
    raven_df.sort_values('Begin Time (s)', inplace=True)
    raven_df.insert(0, 'Selection', np.arange(len(raven_df)).astype(int)+1)

    raventxt_df = pd.DataFrame(np.repeat(raven_df.values, 2, axis=0))
    raventxt_df.columns = raven_df.columns
    raventxt_df['Selection'] = raventxt_df['Selection'].astype(int)
    raventxt_df.insert(1, 'Channel', [1]*raventxt_df.shape[0])
    views = np.array(['Waveform 1']*raventxt_df.shape[0], dtype='object')
    views[1::2] = 'Spectrogram 1'
    raventxt_df.insert(1, 'View', views)

    return raventxt_df

def convert_kaleidoscopedf_to_bd2df(df):
    bd2_df = pd.DataFrame()
    bd2_df['start_time'] = df['OFFSET']
    bd2_df['end_time'] = df['OFFSET'] + df['DURATION']
    bd2_df['low_freq'] = df['Fmin']
    bd2_df['high_freq'] = df['Fmax']
    bd2_df['input_file'] = df['IN FILE']
    bd2_df['input_dir'] = df['INDIR']
    bd2_df['mean_freq'] = df['Fmean']
    if 'TOP1MATCH*' in df.columns:
        bd2_df['TOP1MATCH*'] = df['TOP1MATCH*']
    if 'TOP1MATCH' in df.columns:
        bd2_df['TOP1MATCH'] = df['TOP1MATCH']
    bd2_df['TOP1DIST'] = df['TOP1DIST']
    bd2_df['TOP2MATCH'] = df['TOP2MATCH']
    bd2_df['TOP2DIST'] = df['TOP2DIST']
    bd2_df['TOP3MATCH'] = df['TOP3MATCH']
    bd2_df['TOP3DIST'] = df['TOP3DIST']
    bd2_df.sort_values('start_time', inplace=True)
    
    return bd2_df

def convert_raventxtdf_to_bd2df(raventxt_df):
    bd2_human_df = raventxt_df[1::2].copy()
    bd2_human_df = bd2_human_df.drop(columns=['Selection', 'View', 'Channel'])
    bd2_human_df.rename(columns={'Begin Time (s)':'start_time',
                                'End Time (s)':'end_time',
                                'Low Freq (Hz)':'low_freq',
                                'High Freq (Hz)':'high_freq',
                                'Manually-Verified Phonic Group':'freq_group',
                                'SNR NIST Quick (dB)':'snr_nist_quick_dB'}, inplace=True)
    bd2_human_df.sort_values('start_time', inplace=True)
    
    return bd2_human_df

# %%
wav_filename = '20220826_070000'
site = 'Central'
plot_file = Path(f'../../Documents/mila-human-wav-txt/{wav_filename}.WAV')

# %%
raventxt_human_df = pd.read_csv(f'{Path.home()}/Documents/mila-human-wav-txt/{wav_filename}_manually_verified_by_AK_with_groups.txt', sep='\t')
bd2_human_df = convert_raventxtdf_to_bd2df(raventxt_human_df)
bd2_human_df['freq_group'] = bd2_human_df['freq_group'].str.strip()
bd2_human_df.reset_index(inplace=True, drop=True)
bd2_human_df
# Out:
#        start_time     end_time   low_freq  high_freq  Delta Time (s)  \
# 0        1.729564     1.737108  44070.175  51087.719          0.0075
# 1        3.770500     3.777100  45234.000  54096.000          0.0066
# 2        3.911402     3.918947  43903.720  56927.790          0.0075
# 3        4.043419     4.050209  44281.690  58478.873          0.0068
# 4        4.161126     4.170934  43903.720  56507.659          0.0098
# ...           ...          ...        ...        ...             ...
# 4401  1787.774500  1787.784900  37500.000  46675.000          0.0104
# 4402  1787.959500  1787.969400  37500.000  45913.000          0.0099
# 4403  1788.212500  1788.221200  39218.000  48186.000          0.0087
# 4404  1788.413500  1788.422500  40078.000  49982.000          0.0090
# 4405  1788.495500  1788.503400  38359.000  47881.000          0.0079
#
#       snr_nist_quick_dB       Annotation  detection_confidence  \
# 0                 16.02  AK_echolocation                   NaN
# 1                 14.64     Echolocation                 0.512
# 2                 12.74  AK_echolocation                   NaN
# 3                 12.10  AK_echolocation                   NaN
# 4                 12.35  AK_echolocation                   NaN
# ...                 ...              ...                   ...
# 4401              16.86     Echolocation                 0.587
# 4402              14.98     Echolocation                 0.591
# 4403              13.74     Echolocation                 0.544
# 4404              14.89     Echolocation                 0.566
# 4405              12.56     Echolocation                 0.560
#
#                input_file freq_group
# 0                     NaN         HF
# 1     20220826_070000.WAV         HF
# 2                     NaN         HF
# 3                     NaN         HF
# 4                     NaN         HF
# ...                   ...        ...
# 4401  20220826_070000.WAV         HF
# 4402  20220826_070000.WAV         HF
# 4403  20220826_070000.WAV         HF
# 4404  20220826_070000.WAV         HF
# 4405  20220826_070000.WAV         HF
#
# [4406 rows x 10 columns]

# %%
bd2_human_df1 = raventxt_human_df[1::2].copy().reset_index(drop=True)
bd2_human_df1 = bd2_human_df1.drop(columns=['Selection', 'View', 'Channel', 'SNR NIST Quick (dB)'])

# %%
bd2_human_df2 = raventxt_human_df[::2].copy().reset_index(drop=True)
bd2_human_df2 = bd2_human_df2.drop(columns=['Selection', 'View', 'Channel', 'SNR NIST Quick (dB)'])

# %%
bd2_human_df2
# Out:
#       Begin Time (s)  End Time (s)  Low Freq (Hz)  High Freq (Hz)  \
# 0           1.729564      1.737108      44070.175       51087.719
# 1           3.770500      3.777100      45234.000       54096.000
# 2           3.911402      3.918947      43903.720       56927.790
# 3           4.043419      4.050209      44281.690       58478.873
# 4           4.161126      4.170934      43903.720       56507.659
# ...              ...           ...            ...             ...
# 4401     1787.774500   1787.784900      37500.000       46675.000
# 4402     1787.959500   1787.969400      37500.000       45913.000
# 4403     1788.212500   1788.221200      39218.000       48186.000
# 4404     1788.413500   1788.422500      40078.000       49982.000
# 4405     1788.495500   1788.503400      38359.000       47881.000
#
#       Delta Time (s)       Annotation  detection_confidence  \
# 0             0.0075  AK_echolocation                   NaN
# 1             0.0066     Echolocation                 0.512
# 2             0.0075  AK_echolocation                   NaN
# 3             0.0068  AK_echolocation                   NaN
# 4             0.0098  AK_echolocation                   NaN
# ...              ...              ...                   ...
# 4401          0.0104     Echolocation                 0.587
# 4402          0.0099     Echolocation                 0.591
# 4403          0.0087     Echolocation                 0.544
# 4404          0.0090     Echolocation                 0.566
# 4405          0.0079     Echolocation                 0.560
#
#                input_file Manually-Verified Phonic Group
# 0                     NaN                             HF
# 1     20220826_070000.WAV                             HF
# 2                     NaN                             HF
# 3                     NaN                             HF
# 4                     NaN                             HF
# ...                   ...                            ...
# 4401  20220826_070000.WAV                             HF
# 4402  20220826_070000.WAV                             HF
# 4403  20220826_070000.WAV                             HF
# 4404  20220826_070000.WAV                             HF
# 4405  20220826_070000.WAV                             HF
#
# [4406 rows x 9 columns]

# %%
bd2_human_df1.equals(bd2_human_df2)
# Out:
# True

# %%
bd2_human_df
# Out:
#        start_time     end_time   low_freq  high_freq  Delta Time (s)  \
# 0        1.729564     1.737108  44070.175  51087.719          0.0075
# 1        3.770500     3.777100  45234.000  54096.000          0.0066
# 2        3.911402     3.918947  43903.720  56927.790          0.0075
# 3        4.043419     4.050209  44281.690  58478.873          0.0068
# 4        4.161126     4.170934  43903.720  56507.659          0.0098
# ...           ...          ...        ...        ...             ...
# 4401  1787.774500  1787.784900  37500.000  46675.000          0.0104
# 4402  1787.959500  1787.969400  37500.000  45913.000          0.0099
# 4403  1788.212500  1788.221200  39218.000  48186.000          0.0087
# 4404  1788.413500  1788.422500  40078.000  49982.000          0.0090
# 4405  1788.495500  1788.503400  38359.000  47881.000          0.0079
#
#       snr_nist_quick_dB       Annotation  detection_confidence  \
# 0                 16.02  AK_echolocation                   NaN
# 1                 14.64     Echolocation                 0.512
# 2                 12.74  AK_echolocation                   NaN
# 3                 12.10  AK_echolocation                   NaN
# 4                 12.35  AK_echolocation                   NaN
# ...                 ...              ...                   ...
# 4401              16.86     Echolocation                 0.587
# 4402              14.98     Echolocation                 0.591
# 4403              13.74     Echolocation                 0.544
# 4404              14.89     Echolocation                 0.566
# 4405              12.56     Echolocation                 0.560
#
#                input_file freq_group
# 0                     NaN         HF
# 1     20220826_070000.WAV         HF
# 2                     NaN         HF
# 3                     NaN         HF
# 4                     NaN         HF
# ...                   ...        ...
# 4401  20220826_070000.WAV         HF
# 4402  20220826_070000.WAV         HF
# 4403  20220826_070000.WAV         HF
# 4404  20220826_070000.WAV         HF
# 4405  20220826_070000.WAV         HF
#
# [4406 rows x 10 columns]

# %%
audio_file = sf.SoundFile(plot_file)
fs = audio_file.samplerate
nyquist = fs/2
call_snrs = []
for i, row in bd2_human_df.iterrows():
    audio_seg, length_of_section = batdetect2_pipeline.get_section_of_call_in_file(row, audio_file)

    freq_pad = 2000
    low_freq_cutoff = row['low_freq']-freq_pad
    high_freq_cutoff = min(nyquist-1, row['high_freq']+freq_pad)
    band_limited_audio_seg = batdetect2_pipeline.bandpass_audio_signal(audio_seg, fs, low_freq_cutoff, high_freq_cutoff)

    signal = band_limited_audio_seg.copy()
    signal[:int(fs*(length_of_section))] = 0
    noise = band_limited_audio_seg - signal
    snr_call_signal = signal[-int(fs*length_of_section):]
    snr_noise_signal = noise[:int(fs*length_of_section)]

    snr = batdetect2_pipeline.get_snr_from_band_limited_signal(snr_call_signal, snr_noise_signal)
    call_snrs.append(snr)

# %%
bd2_human_df['adityas_method_snr_dB'] = call_snrs
bd2_human_df
# Out:
#        start_time     end_time   low_freq  high_freq  Delta Time (s)  \
# 0        1.729564     1.737108  44070.175  51087.719          0.0075
# 1        3.770500     3.777100  45234.000  54096.000          0.0066
# 2        3.911402     3.918947  43903.720  56927.790          0.0075
# 3        4.043419     4.050209  44281.690  58478.873          0.0068
# 4        4.161126     4.170934  43903.720  56507.659          0.0098
# ...           ...          ...        ...        ...             ...
# 4401  1787.774500  1787.784900  37500.000  46675.000          0.0104
# 4402  1787.959500  1787.969400  37500.000  45913.000          0.0099
# 4403  1788.212500  1788.221200  39218.000  48186.000          0.0087
# 4404  1788.413500  1788.422500  40078.000  49982.000          0.0090
# 4405  1788.495500  1788.503400  38359.000  47881.000          0.0079
#
#       snr_nist_quick_dB       Annotation  detection_confidence  \
# 0                 16.02  AK_echolocation                   NaN
# 1                 14.64     Echolocation                 0.512
# 2                 12.74  AK_echolocation                   NaN
# 3                 12.10  AK_echolocation                   NaN
# 4                 12.35  AK_echolocation                   NaN
# ...                 ...              ...                   ...
# 4401              16.86     Echolocation                 0.587
# 4402              14.98     Echolocation                 0.591
# 4403              13.74     Echolocation                 0.544
# 4404              14.89     Echolocation                 0.566
# 4405              12.56     Echolocation                 0.560
#
#                input_file freq_group  adityas_method_snr_dB
# 0                     NaN         HF               2.567162
# 1     20220826_070000.WAV         HF               6.879404
# 2                     NaN         HF               7.902035
# 3                     NaN         HF               1.782390
# 4                     NaN         HF               1.514990
# ...                   ...        ...                    ...
# 4401  20220826_070000.WAV         HF               9.656562
# 4402  20220826_070000.WAV         HF               6.562988
# 4403  20220826_070000.WAV         HF               8.990165
# 4404  20220826_070000.WAV         HF               5.589297
# 4405  20220826_070000.WAV         HF               4.144408
#
# [4406 rows x 11 columns]

# %%
def convert_df_ravenpro(df: pd.DataFrame):
    """
    Converts a dataframe to the format used by RavenPro
    """

    ravenpro_df = df.copy()

    ravenpro_df.rename(columns={
        "start_time": "Begin Time (s)",
        "end_time": "End Time (s)",
        "low_freq": "Low Freq (Hz)",
        "high_freq": "High Freq (Hz)",
        "event": "Annotation",
    }, inplace=True)

    ravenpro_df["Selection"] = np.arange(0, df.shape[0]).astype('int') + 1
    ravenpro_df["View"] = "Waveform 1"
    ravenpro_df["Channel"] = "1"

    return ravenpro_df

# %%
extension = ".txt"
sep = "\t"

convert_df_ravenpro(bd2_human_df).to_csv(f'{Path.home()}/Downloads/20220826_070000__comparing_ravenpro_SNR_with_aditya_SNR.txt', sep=sep, index=False)

# %%
def return_confusion_matrix_from_comparing_two_detectors(human_df, machine_df):
    false_positives = 0 ## machine made detection that human did not make
    true_positives = 0  ## machine made detection that human made
    true_negatives = 0  ## machine did not make detection that human also did not make
    false_negatives = 0 ## machine did not make detection that human made
    human_ind = 0
    machine_ind = 0

    while (human_ind < len(human_df))&(machine_ind < len(machine_df)):
        human_det = human_df.iloc[human_ind]
        machine_det = machine_df.iloc[machine_ind]

        machine_det_start_in_human_det_bounds = ((machine_det['start_time']>=human_det['start_time'])&(machine_det['start_time']<=human_det['end_time']))
        machine_det_end_in_human_det_bounds = ((machine_det['end_time']>=human_det['start_time'])&(machine_det['end_time']<=human_det['end_time']))
        human_det_start_in_machine_det_bounds = ((human_det['start_time']>=machine_det['start_time'])&(human_det['start_time']<=machine_det['end_time']))
        human_det_end_in_machine_det_bounds = ((human_det['end_time']>=machine_det['start_time'])&(human_det['end_time']<=machine_det['end_time']))
        machine_det_time_in_human_bounds = machine_det_start_in_human_det_bounds|machine_det_end_in_human_det_bounds
        human_det_time_in_machine_bounds = human_det_start_in_machine_det_bounds|human_det_end_in_machine_det_bounds

        machine_det_low_in_human_det_bounds = ((machine_det['low_freq']>=human_det['low_freq'])&(machine_det['low_freq']<=human_det['high_freq']))
        machine_det_high_in_human_det_bounds = ((machine_det['high_freq']>=human_det['low_freq'])&(machine_det['high_freq']<=human_det['high_freq']))
        human_det_low_in_machine_det_bounds = ((human_det['low_freq']>=machine_det['low_freq'])&(human_det['low_freq']<=machine_det['high_freq']))
        human_det_high_in_machine_det_bounds = ((human_det['high_freq']>=machine_det['low_freq'])&(human_det['high_freq']<=machine_det['high_freq']))
        machine_det_freq_in_human_bounds = machine_det_low_in_human_det_bounds|machine_det_high_in_human_det_bounds
        human_det_freq_in_machine_bounds = human_det_low_in_machine_det_bounds|human_det_high_in_machine_det_bounds

        machine_det_time_matches_human_time = (machine_det_time_in_human_bounds|human_det_time_in_machine_bounds)
        machine_det_freq_matches_human_time = (machine_det_freq_in_human_bounds|human_det_freq_in_machine_bounds)
        machine_detection_corresponds_to_human = machine_det_time_matches_human_time&machine_det_freq_matches_human_time

        if len(human_df) < 100:
            print(f'HI:{human_ind}, MI:{machine_ind}, TP:{true_positives}, FP:{false_positives}, FN:{false_negatives}, TN:{true_negatives}')
            print(f'Dets match time: {machine_det_time_matches_human_time}, Dets match freq: {machine_det_freq_matches_human_time}')

        if (machine_detection_corresponds_to_human):
            true_positives += 1
            machine_ind+=1
            human_ind+=1
        else:
            ## Machine detection is referring to call not detected by human (thus, it detected a non-bat call)
            false_positive_same_group_before_human_det = (machine_det['end_time']<=human_det['start_time'])&(machine_det_freq_matches_human_time)
            false_positive_diff_group_before_human_det = (machine_det['start_time']<=human_det['start_time'])&(~machine_det_freq_matches_human_time)

            false_negative_same_group_before_human_det = (machine_det['start_time']>human_det['end_time'])&(machine_det_freq_matches_human_time)
            false_negative_diff_group_before_human_det = (machine_det['start_time']>human_det['start_time'])&(~machine_det_freq_matches_human_time)

            if len(human_df) < 100:
                print(f'FP same group: {false_positive_same_group_before_human_det}, FP diff group: {false_positive_diff_group_before_human_det}')
                print(f'FN same group: {false_negative_same_group_before_human_det}, FN diff group: {false_negative_diff_group_before_human_det}')
            if (false_positive_same_group_before_human_det|false_positive_diff_group_before_human_det):
                false_positives += 1
                machine_ind+=1
            ## Machine has skipped a human-annotated call in detection (thus, it did not detect a bat call)
            elif (false_negative_same_group_before_human_det|false_negative_diff_group_before_human_det):
                false_negatives += 1
                human_ind+=1
            else:
                true_negatives += 1

    if (machine_ind<len(machine_df)):
        false_positives += (len(machine_df) - (machine_ind))
    if (human_ind<len(human_df)):
        false_negatives += (len(human_df) - (human_ind))

    assert((true_positives+false_negatives)==len(human_df))
    assert((false_positives+true_positives)==len(machine_df))

    return {'true_positives':true_positives, 'false_positives':false_positives, 'false_negatives':false_negatives, 'true_negatives':true_negatives}

# %% [markdown]
# ## Following the confusion matrix structure shown below

# %% [markdown]
# ![image](example_confusion_matrix.png)

# %%
# Below we filter our detections dataframe to only get the detections corresponding to the above audio file
audio_file = sf.SoundFile(plot_file)
fs = audio_file.samplerate
start = 360
duration = 15
audio_file.seek(int(fs*start))
audio_seg = audio_file.read(int(fs*duration))
vmin = -60
vmax = 0
audio_features = dict()
audio_features['file_path'] = Path(plot_file)
audio_features['audio_seg'] = audio_seg
audio_features['sample_rate'] = fs
audio_features['start'] = start
audio_features['duration'] = duration

spec_features = dict()
spec_features['NFFT'] = 1024 # When segments are short, NFFT should also be small to best see calls (must always be > 128)
spec_features['cmap'] = 'jet' # This colormap shows best contrast between noise and signals
spec_features['vmin'] = vmin
spec_features['vmax'] = vmax


spec_features['plot_title'] = f"{audio_features['file_path'].name} in {site}"
plot_dets_over_audio(audio_features, spec_features, pd.DataFrame())
spec_features['plot_title'] = f"Human-made detections"
plot_dets_over_audio(audio_features, spec_features, bd2_human_df)

plot_thresh = 0.20
args = dict()
args['chunk_size'] = 2
args['detection_threshold'] = 0.05

ones = int(args['detection_threshold'])
decimals = int(int(100*(args['detection_threshold'])) % 100)
threshold_tag = f"threshold{ones}p{decimals:02}"
save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{wav_filename}.csv")

save_dir = Path(f'20241231__group_threshold_sweep_results')
filepath = save_dir / save_loc
batdetect2_df = pd.read_csv(filepath, sep=',', index_col=0)
batdetect2_df.rename(columns={'KMEANS_CLASSES':'freq_group'}, inplace=True)
batdetect2_df_selected = batdetect2_df[batdetect2_df['det_prob']>=plot_thresh].copy()
spec_features['plot_title'] = f"Raw bd2 detections (threshold={plot_thresh})"
plot_dets_over_audio(audio_features, spec_features, batdetect2_df_selected)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 41
#      39 save_dir = Path(f'20241231__group_threshold_sweep_results')
#      40 filepath = save_dir / save_loc
# ---> 41 batdetect2_df = pd.read_csv(filepath, sep=',', index_col=0)
#      42 batdetect2_df.rename(columns={'KMEANS_CLASSES':'freq_group'}, inplace=True)
#      43 batdetect2_df_selected = batdetect2_df[batdetect2_df['det_prob']>=plot_thresh].copy()
#
# File ~/miniconda3/envs/bat_msds/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/bat_msds/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/bat_msds/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/bat_msds/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/bat_msds/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '20241231__group_threshold_sweep_results/bd2__threshold0p05_chunksize2_20220826_070000.csv'

# %%
file_sites = {'20220730_053000':'Carp',
 '20220826_070000':'Central',
 '20220727_083000':'Foliage',
 '20220829_090000':'Foliage'}

SITE_NAMES = {'Carp':'Carp Pond', 'Foliage':'Foliage', 'Central':'Central Pond'}

file_keys = list(file_sites.keys())
file_keys
# Out:
# ['20220730_053000', '20220826_070000', '20220727_083000', '20220829_090000']

# %%
def gather_evaluation_results_between_bd2_and_human(bd2_human_df, batdetect2_df_thresh):
    file_batdetect2_cf = return_confusion_matrix_from_comparing_two_detectors(bd2_human_df, batdetect2_df_thresh)
    row = pd.DataFrame([file_batdetect2_cf])
    row.insert(0, 'num_human_annotations', [len(bd2_human_df)])
    row.insert(0, 'num_bd2_detections', [len(batdetect2_df_thresh)])
    denom_precision = (file_batdetect2_cf['true_positives'] + file_batdetect2_cf['false_positives'])
    denom_recall = (file_batdetect2_cf['true_positives'] + file_batdetect2_cf['false_negatives'])
    if (denom_precision>0):
        precision = file_batdetect2_cf['true_positives'] / denom_precision
    else:
        precision = np.NaN
    if (denom_recall>0):
        recall = file_batdetect2_cf['true_positives'] / denom_recall
    else:
        recall = np.NaN
    row['precision'] = precision
    row['recall'] = recall

    return row

# %%
batdetect2_eval = pd.DataFrame()
batdetect2_eval_LF = pd.DataFrame()
batdetect2_eval_HF = pd.DataFrame()
for file_key in file_keys:
    print(file_key)
    wav_filename = file_key
    site = file_sites[file_key]
    plot_file = Path(f'{Path.home()}/Documents/mila-human-wav-txt/{wav_filename}.WAV')

    raventxt_human_df = pd.read_csv(f'{Path.home()}/Documents/mila-human-wav-txt/{wav_filename}_manually_verified_by_AK_with_groups.txt', sep='\t')
    bd2_human_df = convert_raventxtdf_to_bd2df(raventxt_human_df)
    bd2_human_df['freq_group'] = bd2_human_df['freq_group'].str.strip()
    bd2_human_df.reset_index(inplace=True, drop=True)

    save_dir = Path(f'20241229__group_threshold_sweep_results')
    args = dict()
    args['chunk_size'] = 2
    args['detection_threshold'] = 0.08
    ones = int(args['detection_threshold'])
    decimals = int(int(100*(args['detection_threshold'])) % 100)
    threshold_tag = f"threshold{ones}p{decimals:02}"
    save_loc = Path(f"bd2__{threshold_tag}_chunksize{int(args['chunk_size'])}_{wav_filename}.csv")
    filepath = save_dir / save_loc
    batdetect2_df = pd.read_csv(filepath, sep=',', index_col=0)
    batdetect2_df.rename(columns={'KMEANS_CLASSES':'freq_group'}, inplace=True)

    increment = 0.01
    thresholds = np.arange(0.08, 1.0+increment, increment)
    for i, val in enumerate(thresholds):
        thresh = round(val, 2)
        print(thresh)
        batdetect2_df_thresh = batdetect2_df[batdetect2_df['det_prob']>=thresh].copy()
        row = gather_evaluation_results_between_bd2_and_human(bd2_human_df, batdetect2_df_thresh)
        row.insert(0, 'detection_threshold', [thresh])
        row['input_file_name'] = f'{wav_filename}.WAV'
        row['site_name'] = SITE_NAMES[site]
        batdetect2_eval = pd.concat([batdetect2_eval, row])
        assert(len(batdetect2_df_thresh['freq_group'].unique())<=2)

        bd2_human_df_LF = bd2_human_df[bd2_human_df['freq_group']=='LF'].copy()
        batdetect2_df_thresh_LF = batdetect2_df_thresh[batdetect2_df_thresh['freq_group']=='LF'].copy()
        row_LF = gather_evaluation_results_between_bd2_and_human(bd2_human_df_LF, batdetect2_df_thresh_LF)
        row_LF.insert(0, 'detection_threshold', [thresh])
        row_LF['input_file_name'] = f'{wav_filename}.WAV'
        row_LF['site_name'] = SITE_NAMES[site]
        batdetect2_eval_LF = pd.concat([batdetect2_eval_LF, row_LF])

        bd2_human_df_HF = bd2_human_df[bd2_human_df['freq_group']=='HF'].copy()
        batdetect2_df_thresh_HF = batdetect2_df_thresh[batdetect2_df_thresh['freq_group']=='HF'].copy()
        row_HF = gather_evaluation_results_between_bd2_and_human(bd2_human_df_HF, batdetect2_df_thresh_HF)
        row_HF.insert(0, 'detection_threshold', [thresh])
        row_HF['input_file_name'] = f'{wav_filename}.WAV'
        row_HF['site_name'] = SITE_NAMES[site]
        batdetect2_eval_HF = pd.concat([batdetect2_eval_HF, row_HF])
# Out:
# 20220730_053000
# 0.08
# 0.09
# 0.1
# 0.11
# 0.12
# 0.13
# 0.14
# 0.15
# 0.16
# 0.17
# 0.18
# 0.19
# 0.2
# 0.21
# 0.22
# 0.23
# 0.24
# 0.25
# 0.26
# 0.27
# 0.28
# 0.29
# 0.3
# 0.31
# 0.32
# 0.33
# 0.34
# 0.35
# 0.36
# 0.37
# 0.38
# 0.39
# 0.4
# 0.41
# 0.42
# 0.43
# 0.44
# 0.45
# 0.46
# 0.47
# 0.48
# 0.49
# 0.5
# 0.51
# 0.52
# 0.53
# 0.54
# 0.55
# 0.56
# 0.57
# 0.58
# 0.59
# 0.6
# 0.61
# 0.62
# 0.63
# 0.64
# 0.65
# 0.66
# 0.67
# 0.68
# 0.69
# 0.7
# 0.71
# 0.72
# 0.73
# 0.74
# 0.75
# 0.76
# 0.77
# 0.78
# 0.79
# 0.8
# 0.81
# 0.82
# 0.83
# 0.84
# 0.85
# 0.86
# 0.87
# 0.88
# 0.89
# 0.9
# 0.91
# 0.92
# 0.93
# 0.94
# 0.95
# 0.96
# 0.97
# 0.98
# 0.99
# 1.0
# 20220826_070000
# 0.08
# 0.09
# 0.1
# 0.11
# 0.12
# 0.13
# 0.14
# 0.15
# 0.16
# 0.17
# 0.18
# 0.19
# 0.2
# 0.21
# 0.22
# 0.23
# 0.24
# 0.25
# 0.26
# 0.27
# 0.28
# 0.29
# 0.3
# 0.31
# 0.32
# 0.33
# 0.34
# 0.35
# 0.36
# 0.37
# 0.38
# 0.39
# 0.4
# 0.41
# 0.42
# 0.43
# 0.44
# 0.45
# 0.46
# 0.47
# 0.48
# 0.49
# 0.5
# 0.51
# 0.52
# 0.53
# 0.54
# 0.55
# 0.56
# 0.57
# 0.58
# 0.59
# 0.6
# 0.61
# 0.62
# 0.63
# 0.64
# 0.65
# 0.66
# 0.67
# 0.68
# 0.69
# 0.7
# 0.71
# 0.72
# 0.73
# 0.74
# 0.75
# 0.76
# 0.77
# 0.78
# 0.79
# 0.8
# 0.81
# 0.82
# 0.83
# 0.84
# 0.85
# 0.86
# 0.87
# 0.88
# 0.89
# 0.9
# 0.91
# 0.92
# 0.93
# 0.94
# 0.95
# 0.96
# 0.97
# 0.98
# 0.99
# 1.0
# 20220727_083000
# 0.08
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:7, TP:0, FP:7, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:8, TP:0, FP:8, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:9, TP:0, FP:9, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:10, TP:0, FP:10, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:11, TP:0, FP:11, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:12, TP:0, FP:12, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:13, TP:0, FP:13, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:14, TP:0, FP:14, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:15, TP:0, FP:15, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:16, TP:0, FP:16, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:17, TP:0, FP:17, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:18, TP:0, FP:18, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:19, TP:0, FP:19, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:20, TP:0, FP:20, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:21, TP:0, FP:21, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:22, TP:0, FP:22, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:23, TP:0, FP:23, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:24, TP:0, FP:24, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:25, TP:0, FP:25, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:26, TP:0, FP:26, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:27, TP:0, FP:27, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:28, TP:0, FP:28, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:29, TP:0, FP:29, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:30, TP:0, FP:30, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:31, TP:0, FP:31, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:32, TP:0, FP:32, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:33, TP:0, FP:33, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:34, TP:0, FP:34, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:35, TP:0, FP:35, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:36, TP:0, FP:36, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:37, TP:0, FP:37, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:38, TP:0, FP:38, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:39, TP:0, FP:39, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:40, TP:0, FP:40, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:41, TP:0, FP:41, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:42, TP:0, FP:42, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:43, TP:0, FP:43, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:44, TP:0, FP:44, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:45, TP:0, FP:45, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:46, TP:0, FP:46, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:47, TP:0, FP:47, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:48, TP:0, FP:48, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:49, TP:0, FP:49, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:50, TP:0, FP:50, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:51, TP:0, FP:51, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:52, TP:0, FP:52, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:53, TP:0, FP:53, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:54, TP:0, FP:54, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:55, TP:0, FP:55, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:56, TP:0, FP:56, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:57, TP:0, FP:57, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:58, TP:0, FP:58, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:59, TP:0, FP:59, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:60, TP:0, FP:60, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:61, TP:0, FP:61, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:62, TP:0, FP:62, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:63, TP:0, FP:63, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:64, TP:0, FP:64, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:65, TP:0, FP:65, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:66, TP:0, FP:66, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:67, TP:0, FP:67, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:68, TP:0, FP:68, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:69, TP:0, FP:69, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:70, TP:0, FP:70, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:71, TP:0, FP:71, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:72, TP:0, FP:72, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:73, TP:0, FP:73, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:74, TP:0, FP:74, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:75, TP:0, FP:75, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:76, TP:0, FP:76, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:77, TP:0, FP:77, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:78, TP:0, FP:78, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:79, TP:0, FP:79, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:80, TP:0, FP:80, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:81, TP:0, FP:81, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:82, TP:0, FP:82, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:83, TP:0, FP:83, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:84, TP:0, FP:84, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:85, TP:0, FP:85, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:86, TP:0, FP:86, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:87, TP:0, FP:87, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:88, TP:0, FP:88, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:89, TP:0, FP:89, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:90, TP:0, FP:90, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:91, TP:0, FP:91, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:92, TP:0, FP:92, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:93, TP:0, FP:93, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:94, TP:0, FP:94, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:95, TP:0, FP:95, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:96, TP:0, FP:96, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:97, TP:0, FP:97, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:98, TP:0, FP:98, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:99, TP:0, FP:99, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:100, TP:0, FP:100, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:101, TP:0, FP:101, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:102, TP:0, FP:102, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:103, TP:0, FP:103, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:104, TP:0, FP:104, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:105, TP:0, FP:105, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:106, TP:0, FP:106, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# HI:1, MI:107, TP:1, FP:106, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:1, MI:108, TP:1, FP:107, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:2, MI:108, TP:1, FP:107, FN:1, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:3, MI:108, TP:1, FP:107, FN:2, TN:0
# Dets match time: True, Dets match freq: True
# HI:4, MI:109, TP:2, FP:107, FN:2, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:5, MI:109, TP:2, FP:107, FN:3, TN:0
# Dets match time: True, Dets match freq: True
# HI:6, MI:110, TP:3, FP:107, FN:3, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:6, MI:111, TP:3, FP:108, FN:3, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:7, MI:111, TP:3, FP:108, FN:4, TN:0
# Dets match time: True, Dets match freq: True
# HI:8, MI:112, TP:4, FP:108, FN:4, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:8, MI:113, TP:4, FP:109, FN:4, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:8, MI:114, TP:4, FP:110, FN:4, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: False
# FN same group: False, FN diff group: True
# HI:9, MI:114, TP:4, FP:110, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:115, TP:4, FP:111, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:116, TP:4, FP:112, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:117, TP:4, FP:113, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:118, TP:4, FP:114, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:119, TP:4, FP:115, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:120, TP:4, FP:116, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:121, TP:4, FP:117, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:122, TP:4, FP:118, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:123, TP:4, FP:119, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:9, MI:124, TP:4, FP:120, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:125, TP:4, FP:121, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:126, TP:4, FP:122, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:127, TP:4, FP:123, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:128, TP:4, FP:124, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:129, TP:4, FP:125, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:130, TP:4, FP:126, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:9, MI:131, TP:4, FP:127, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:132, TP:4, FP:128, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:133, TP:4, FP:129, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:10, MI:134, TP:5, FP:129, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:11, MI:135, TP:6, FP:129, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:136, TP:6, FP:130, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:137, TP:6, FP:131, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:138, TP:6, FP:132, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:139, TP:6, FP:133, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:140, TP:6, FP:134, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:141, TP:6, FP:135, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:142, TP:6, FP:136, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:143, TP:6, FP:137, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:144, TP:6, FP:138, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:145, TP:6, FP:139, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:146, TP:6, FP:140, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:147, TP:6, FP:141, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:148, TP:6, FP:142, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:149, TP:6, FP:143, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:150, TP:6, FP:144, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:151, TP:6, FP:145, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:152, TP:6, FP:146, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:153, TP:6, FP:147, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:154, TP:6, FP:148, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:155, TP:6, FP:149, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:156, TP:6, FP:150, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:157, TP:6, FP:151, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:158, TP:6, FP:152, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:159, TP:6, FP:153, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:160, TP:6, FP:154, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:161, TP:6, FP:155, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:162, TP:6, FP:156, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:163, TP:6, FP:157, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:164, TP:6, FP:158, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:165, TP:6, FP:159, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:166, TP:6, FP:160, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:167, TP:6, FP:161, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:168, TP:6, FP:162, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:169, TP:6, FP:163, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:170, TP:6, FP:164, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:171, TP:6, FP:165, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:11, MI:172, TP:6, FP:166, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:12, MI:173, TP:7, FP:166, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:13, MI:174, TP:8, FP:166, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:13, MI:175, TP:8, FP:167, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:14, MI:176, TP:9, FP:167, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:15, MI:177, TP:10, FP:167, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# 0.09
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:7, TP:0, FP:7, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:8, TP:0, FP:8, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:9, TP:0, FP:9, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:10, TP:0, FP:10, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:11, TP:0, FP:11, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:12, TP:0, FP:12, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:13, TP:0, FP:13, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:14, TP:0, FP:14, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:15, TP:0, FP:15, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:16, TP:0, FP:16, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:17, TP:0, FP:17, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:18, TP:0, FP:18, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:19, TP:0, FP:19, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:20, TP:0, FP:20, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:21, TP:0, FP:21, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:22, TP:0, FP:22, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:23, TP:0, FP:23, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:24, TP:0, FP:24, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:25, TP:0, FP:25, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:26, TP:0, FP:26, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:27, TP:0, FP:27, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:28, TP:0, FP:28, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:29, TP:0, FP:29, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:30, TP:0, FP:30, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:31, TP:0, FP:31, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:32, TP:0, FP:32, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:33, TP:0, FP:33, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:34, TP:0, FP:34, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:35, TP:0, FP:35, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:36, TP:0, FP:36, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:37, TP:0, FP:37, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:38, TP:0, FP:38, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:39, TP:0, FP:39, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:40, TP:0, FP:40, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:41, TP:0, FP:41, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:42, TP:0, FP:42, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:43, TP:0, FP:43, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:44, TP:0, FP:44, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:45, TP:0, FP:45, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:46, TP:0, FP:46, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:47, TP:0, FP:47, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:48, TP:0, FP:48, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:49, TP:0, FP:49, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:50, TP:0, FP:50, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:51, TP:0, FP:51, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:52, TP:0, FP:52, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:53, TP:0, FP:53, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:54, TP:0, FP:54, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:55, TP:0, FP:55, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:56, TP:0, FP:56, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:57, TP:0, FP:57, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:58, TP:0, FP:58, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:59, TP:0, FP:59, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:60, TP:0, FP:60, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:61, TP:0, FP:61, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:62, TP:0, FP:62, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:63, TP:0, FP:63, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:64, TP:0, FP:64, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:65, TP:0, FP:65, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:66, TP:0, FP:66, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:67, TP:0, FP:67, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:68, TP:0, FP:68, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:69, TP:0, FP:69, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:70, TP:0, FP:70, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:71, TP:0, FP:71, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:72, TP:0, FP:72, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:73, TP:0, FP:73, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:74, TP:0, FP:74, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:75, TP:0, FP:75, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:1, MI:75, TP:0, FP:75, FN:1, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:1, MI:76, TP:0, FP:76, FN:1, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:2, MI:76, TP:0, FP:76, FN:2, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:3, MI:76, TP:0, FP:76, FN:3, TN:0
# Dets match time: True, Dets match freq: True
# HI:4, MI:77, TP:1, FP:76, FN:3, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:5, MI:77, TP:1, FP:76, FN:4, TN:0
# Dets match time: True, Dets match freq: True
# HI:6, MI:78, TP:2, FP:76, FN:4, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:6, MI:79, TP:2, FP:77, FN:4, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:7, MI:79, TP:2, FP:77, FN:5, TN:0
# Dets match time: True, Dets match freq: True
# HI:8, MI:80, TP:3, FP:77, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:8, MI:81, TP:3, FP:78, FN:5, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:8, MI:82, TP:3, FP:79, FN:5, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: False
# FN same group: False, FN diff group: True
# HI:9, MI:82, TP:3, FP:79, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:83, TP:3, FP:80, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:84, TP:3, FP:81, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:85, TP:3, FP:82, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:86, TP:3, FP:83, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:87, TP:3, FP:84, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:88, TP:3, FP:85, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:89, TP:3, FP:86, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:90, TP:3, FP:87, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:91, TP:3, FP:88, FN:6, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:9, MI:92, TP:3, FP:89, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:9, MI:93, TP:3, FP:90, FN:6, TN:0
# Dets match time: True, Dets match freq: True
# HI:10, MI:94, TP:4, FP:90, FN:6, TN:0
# Dets match time: True, Dets match freq: True
# HI:11, MI:95, TP:5, FP:90, FN:6, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:11, MI:96, TP:5, FP:91, FN:6, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# ...
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:26, TP:0, FP:26, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:27, TP:0, FP:27, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# HI:1, MI:28, TP:1, FP:27, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:2, MI:28, TP:1, FP:27, FN:1, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# 0.14
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:7, TP:0, FP:7, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:8, TP:0, FP:8, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:9, TP:0, FP:9, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:10, TP:0, FP:10, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:11, TP:0, FP:11, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:12, TP:0, FP:12, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:13, TP:0, FP:13, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:14, TP:0, FP:14, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:15, TP:0, FP:15, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:16, TP:0, FP:16, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:17, TP:0, FP:17, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:18, TP:0, FP:18, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:19, TP:0, FP:19, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# HI:1, MI:20, TP:1, FP:19, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# HI:2, MI:20, TP:1, FP:19, FN:1, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: False, FP diff group: False
# FN same group: True, FN diff group: False
# 0.15
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:7, TP:0, FP:7, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:8, TP:0, FP:8, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:9, TP:0, FP:9, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:10, TP:0, FP:10, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:11, TP:0, FP:11, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:12, TP:0, FP:12, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:13, TP:0, FP:13, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.16
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:7, TP:0, FP:7, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:8, TP:0, FP:8, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:9, TP:0, FP:9, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:10, TP:0, FP:10, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:11, TP:0, FP:11, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:12, TP:0, FP:12, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:13, TP:0, FP:13, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.17
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:7, TP:0, FP:7, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.18
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:6, TP:0, FP:6, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.19
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.2
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:5, TP:0, FP:5, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.21
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: False, Dets match freq: True
# FP same group: True, FP diff group: False
# FN same group: False, FN diff group: False
# HI:0, MI:3, TP:0, FP:3, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:4, TP:0, FP:4, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.22
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:2, TP:0, FP:2, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.23
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: False, Dets match freq: False
# FP same group: False, FP diff group: True
# FN same group: False, FN diff group: False
# HI:0, MI:1, TP:0, FP:1, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.24
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.25
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.26
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.27
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.28
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.29
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.3
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.31
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.32
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.33
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.34
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.35
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.36
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.37
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.38
# HI:0, MI:0, TP:0, FP:0, FN:0, TN:0
# Dets match time: True, Dets match freq: True
# 0.39
# 0.4
# 0.41
# 0.42
# 0.43
# 0.44
# 0.45
# 0.46
# 0.47
# 0.48
# 0.49
# 0.5
# 0.51
# 0.52
# 0.53
# 0.54
# 0.55
# 0.56
# 0.57
# 0.58
# 0.59
# 0.6
# 0.61
# 0.62
# 0.63
# 0.64
# 0.65
# 0.66
# 0.67
# 0.68
# 0.69
# 0.7
# 0.71
# 0.72
# 0.73
# 0.74
# 0.75
# 0.76
# 0.77
# 0.78
# 0.79
# 0.8
# 0.81
# 0.82
# 0.83
# 0.84
# 0.85
# 0.86
# 0.87
# 0.88
# 0.89
# 0.9
# 0.91
# 0.92
# 0.93
# 0.94
# 0.95
# 0.96
# 0.97
# 0.98
# 0.99
# 1.0

# %%
batdetect2_eval = batdetect2_eval.reset_index(drop=True)
batdetect2_eval_LF = batdetect2_eval_LF.reset_index(drop=True)
batdetect2_eval_HF = batdetect2_eval_HF.reset_index(drop=True)

# %%
batdetect2_eval.to_csv(save_dir / '20241229__bd2_eval_results_per_thresh_and_file.csv')
batdetect2_eval_LF.to_csv(save_dir / '20241229__bd2_LFeval_results_per_thresh_and_file.csv')
batdetect2_eval_HF.to_csv(save_dir / '20241229__bd2_HFeval_results_per_thresh_and_file.csv')

# %%
batdetect2_eval = pd.read_csv(save_dir / '20241229__bd2_eval_results_per_thresh_and_file.csv', index_col=0)
batdetect2_eval_LF = pd.read_csv(save_dir / '20241229__bd2_LFeval_results_per_thresh_and_file.csv', index_col=0)
batdetect2_eval_HF = pd.read_csv(save_dir / '20241229__bd2_HFeval_results_per_thresh_and_file.csv', index_col=0)

# %%
plt.figure(figsize=(6,6))
plt.rcParams.update({'font.size':14})
plt.title(f'4 UBNA files precision vs. recall')
precisions_per_thresh = batdetect2_eval['precision']
recalls_per_thresh = batdetect2_eval['recall']
plt.plot(recalls_per_thresh, precisions_per_thresh, marker='.')
for file in batdetect2_eval['input_file_name'].unique():
    batdetect2_eval_file = batdetect2_eval[batdetect2_eval['input_file_name']==file].copy()
    file_precisions = batdetect2_eval_file['precision']
    file_recalls = batdetect2_eval_file['recall']
    common_max = (file_precisions * file_recalls).argmax()
    plt.scatter(file_recalls.iloc[common_max], file_precisions.iloc[common_max], color='r', label=f'Threshold={round(thresholds[common_max], 3)}', zorder=2)
plt.grid(which='both')
plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.rcParams.update({'font.size':14})
plt.title(f'4 UBNA files precision vs. recall (LF)')
precisions_per_thresh = batdetect2_eval_LF['precision']
recalls_per_thresh = batdetect2_eval_LF['recall']
plt.plot(recalls_per_thresh, precisions_per_thresh, marker='.')
for file in batdetect2_eval_LF['input_file_name'].unique():
    batdetect2_eval_file = batdetect2_eval_LF[batdetect2_eval_LF['input_file_name']==file].copy()
    file_precisions = batdetect2_eval_file['precision']
    file_recalls = batdetect2_eval_file['recall']
    common_max = (file_precisions * file_recalls).argmax()
    plt.scatter(file_recalls.iloc[common_max], file_precisions.iloc[common_max], color='r', label=f'Threshold={round(thresholds[common_max], 3)}', zorder=2)
plt.grid(which='both')
plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.rcParams.update({'font.size':14})
plt.title(f'4 UBNA files precision vs. recall (HF)')
precisions_per_thresh = batdetect2_eval_HF['precision']
recalls_per_thresh = batdetect2_eval_HF['recall']
plt.plot(recalls_per_thresh, precisions_per_thresh, marker='.')
for file in batdetect2_eval_HF['input_file_name'].unique():
    batdetect2_eval_file = batdetect2_eval_HF[batdetect2_eval_HF['input_file_name']==file].copy()
    file_precisions = batdetect2_eval_file['precision']
    file_recalls = batdetect2_eval_file['recall']
    common_max = (file_precisions * file_recalls).argmax()
    plt.scatter(file_recalls.iloc[common_max], file_precisions.iloc[common_max], color='r', label=f'Threshold={round(thresholds[common_max], 3)}', zorder=2)
plt.grid(which='both')
plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show()
